# %%
 # %matplotlib inline
import pickle
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
from sklearn.model_selection import KFold
from IPython.display import HTML, display
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('./KB_mxxg/comb_pre_to_cat2.csv')

# %%
data = data.drop(['Unnamed: 0', 'Unnamed: 0.1'], 1)

# %%
def gucode(path):
    gucode = {}
    df = pd.read_csv(path, sep=':',names=['name', 'code'])
    for i,code in enumerate(df['code']):
        gucode[code] = df['name'][i]
    return gucode

gucode = gucode('./KB_mxxg/gucode.txt')

# %%
gucode
# Out:
# {11110: '종로구',
#  11140: '중구',
#  11170: '용산구',
#  11200: '성동구',
#  11215: '광진구',
#  11230: '동대문구',
#  11260: '중랑구',
#  11290: '성북구',
#  11305: '강북구',
#  11320: '도봉구',
#  11350: '노원구',
#  11380: '은평구',
#  11410: '서대문구',
#  11440: '마포구',
#  11470: '양천구',
#  11500: '강서구',
#  11530: '구로구',
#  11545: '금천구',
#  11560: '영등포구',
#  11590: '동작구',
#  11620: '관악구',
#  11650: '서초구',
#  11680: '강남구',
#  11710: '송파구',
#  11740: '강동구'}

# %%
def idx_custom(custom_data, year_range, year_idx, code):
    custom_data = custom_data.iloc[year_idx]
    custom_data = custom_data.reset_index(drop=True)
    print('Only {} data in {} year(s)'.format(gucode[code], year_range))
    print('Data size : {}'.format(len(custom_data)))
    
    return custom_data, gucode[code]

# %%
def custom_data(code):
    #input gu-code & year
    min_year = int(input('start year: '))
    max_year = int(input('end year: '))
    
    gu_idx = np.where(data[str(code)]==1)[0]
    
    custom_data = data.iloc[gu_idx] #원하는 구만 잘라냄
    custom_data = custom_data.reset_index(drop=True) #index 0부터 다시 초기화
    year_range = []
    
    if max_year >= min_year:
        
        for year in range(min_year, max_year + 1):
            year_range.append(year)
            
        tmp = [np.where(custom_data['d_yr'] == year)[0] for year in year_range]
        year_idx = np.concatenate(tmp)

        return idx_custom(custom_data, year_range, year_idx, code)
        
    elif max_year == min_year:
        year_range.append(min_year)
        year_idx = np.where(custom_data['d_yr'] == year_range[0])[0]
        
        return idx_custom(custom_data,year_range, year_idx, code)
    else:
        return 0

# %%
seocho, gu_name = custom_data(11650)
# Out:
# start year: 2010
# end year: 2018
# Only 서초구 data in [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018] year(s)
# Data size : 10045

# %%
def datasplit(data):
    data = data.sample(frac=1).reset_index(drop=True) #shuffle
    data = data.reset_index(drop=True) #index 초기화
    
    train_len = int(len(data)*0.8)
    
    train = data.loc[:train_len-1]
    train = train.sample(frac=1).reset_index(drop=True) #shuffle
    train = train.reset_index(drop=True) #index 초기화
    
    test = data.loc[train_len:]
    test = test.sample(frac=1).reset_index(drop=True) #shuffle
    test = test.reset_index(drop=True)
    
    print ('{} data is splitted into {} train / {} test data'.format(len(data),len(train), len(test)))
    return train, test

# %%
train, test = datasplit(seocho)
# Out:
# 10045 data is splitted into 8036 train / 2009 test data

# %%
def make_x_y(data):
    x = data.drop(['price', 'avg_price'],1)
    y = data['price'].values
    
    print('Done')
    return x,y

# %%
x_train, y_train = make_x_y(train)
x_test, y_test = make_x_y(test)
# Out:
# Done
# Done

# %%
def johnson(y):
    gamma, eta, epsilon, lbda = stats.johnsonsu.fit(y)
    yt = gamma + eta*np.arcsinh((y-epsilon)/lbda)
    return yt, gamma, eta, epsilon, lbda

def johnson_inverse(y, gamma, eta, epsilon, lbda):
    return lbda*np.sinh((y-gamma)/eta) + epsilon

yt, g, et, ep, l = johnson(y_train) #정규분포화
yt2 = johnson_inverse(yt, g, et, ep, l) #inverse 정규분포화
plt.figure(1)
sns.distplot(yt)
plt.figure(2)
sns.distplot(yt2)
# Out:
# /Users/tax_k/anaconda3/envs/DL/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import regularizers,optimizers,losses
from keras.layers.normalization import BatchNormalization

import datetime
import os
# Out:
# Using TensorFlow backend.

# %%
# path where all models are saved
now = datetime.datetime.now()
ymd = (str(now.year) + str(now.month) + str(now.day))

BASE_PATH = './'+gu_name+'_model_'+ymd+'/'
MODEL_NAME = 'MLP_rmse'
CURR_PATH = BASE_PATH + MODEL_NAME + "/"

if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

def create_checkpoint(model_name):
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, 'val_loss-{val_loss:.6f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               patience=50)

# %%
def custom_loss(y_true,y_pred):
    import keras.backend as K
    #loss = K.mean((y_true - y_pred)**2, axis=-1)
    loss = K.mean(K.abs(y_pred - y_true), axis=-1)
    '''
    def _logcosh(x):
        return x + K.softplus(-2. * x) - K.log(2.)
    loss= K.mean(_logcosh(y_pred - y_true), axis=-1)
    '''
    return loss

# %%
def rmse(y_true,y_pred):
    import keras.backend as K
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
def rmsle(y_true, y_pred):
    import keras.backend as K
    first_log = K.log(y_pred + 1)
    second_log = K.log(y_true + 1)
    loss= K.sqrt(K.mean(K.square(first_log - second_log)))
    return loss

# %%
def rmsle_for_eval(y_true, y_pred):
    return np.sqrt(np.mean(np.square(np.log(y_pred+1)-np.log(y_true+1))))

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
adam = optimizers.Adam(lr=0.0009, decay=0.0001)

# %%
def Model(x_train, y_train, batch_size, max_epochs):
    model = Sequential()
    model.add(Dense(128, activation='relu', input_dim=114))
    model.add(BatchNormalization())
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(16, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(8, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer=adam,
                  loss=rmse,
                  metrics=['accuracy'])

    model.summary()
    
    checkloss = create_checkpoint(MODEL_NAME)
    
    # Validation_split으로 validation 얼마나 해줄건지 정해중!
    history = model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=max_epochs,
                  validation_split = 0.1,
                  shuffle=True,
                  callbacks=[checkloss, early_stopping])
    
    return model, history

# %%
model = Model(x_train, yt, 16, 5000)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 128)               14720
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                528
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16)                64
# _________________________________________________________________
# dense_11 (Dense)             (None, 8)                 136
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8)                 32
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 26,721
# Trainable params: 26,225
# Non-trainable params: 496
# _________________________________________________________________
# Train on 7232 samples, validate on 804 samples
# Epoch 1/5000
# 7232/7232 [==============================] - 4s 487us/step - loss: 0.8511 - acc: 0.0000e+00 - val_loss: 0.7426 - val_acc: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.74259, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.742595.hdf5
# Epoch 2/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.7705 - acc: 0.0000e+00 - val_loss: 0.7272 - val_acc: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.74259 to 0.72718, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.727179.hdf5
# Epoch 3/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.7132 - acc: 0.0000e+00 - val_loss: 0.7501 - val_acc: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 0.72718
# Epoch 4/5000
# 7232/7232 [==============================] - 2s 268us/step - loss: 0.6625 - acc: 0.0000e+00 - val_loss: 0.7307 - val_acc: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 0.72718
# Epoch 5/5000
# 7232/7232 [==============================] - 2s 247us/step - loss: 0.6421 - acc: 0.0000e+00 - val_loss: 0.7546 - val_acc: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.72718
# Epoch 6/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.6228 - acc: 0.0000e+00 - val_loss: 0.6057 - val_acc: 0.0000e+00
#
# Epoch 00006: val_loss improved from 0.72718 to 0.60574, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.605737.hdf5
# Epoch 7/5000
# 7232/7232 [==============================] - 2s 242us/step - loss: 0.6134 - acc: 0.0000e+00 - val_loss: 0.5581 - val_acc: 0.0000e+00
#
# Epoch 00007: val_loss improved from 0.60574 to 0.55814, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.558135.hdf5
# Epoch 8/5000
# 7232/7232 [==============================] - 2s 280us/step - loss: 0.5961 - acc: 0.0000e+00 - val_loss: 0.5421 - val_acc: 0.0000e+00
#
# Epoch 00008: val_loss improved from 0.55814 to 0.54208, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.542081.hdf5
# Epoch 9/5000
# 7232/7232 [==============================] - 2s 231us/step - loss: 0.5932 - acc: 0.0000e+00 - val_loss: 0.9931 - val_acc: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 0.54208
# Epoch 10/5000
# 7232/7232 [==============================] - 2s 230us/step - loss: 0.5863 - acc: 0.0000e+00 - val_loss: 0.5901 - val_acc: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 0.54208
# Epoch 11/5000
# 7232/7232 [==============================] - 2s 238us/step - loss: 0.5772 - acc: 0.0000e+00 - val_loss: 0.6035 - val_acc: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 0.54208
# Epoch 12/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.5664 - acc: 0.0000e+00 - val_loss: 0.6523 - val_acc: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 0.54208
# Epoch 13/5000
# 7232/7232 [==============================] - 2s 216us/step - loss: 0.5640 - acc: 0.0000e+00 - val_loss: 0.7553 - val_acc: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 0.54208
# Epoch 14/5000
# 7232/7232 [==============================] - 2s 229us/step - loss: 0.5680 - acc: 0.0000e+00 - val_loss: 0.6628 - val_acc: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 0.54208
# Epoch 15/5000
# 7232/7232 [==============================] - 2s 216us/step - loss: 0.5585 - acc: 0.0000e+00 - val_loss: 0.6041 - val_acc: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 0.54208
# Epoch 16/5000
# 7232/7232 [==============================] - 2s 217us/step - loss: 0.5412 - acc: 0.0000e+00 - val_loss: 0.7773 - val_acc: 0.0000e+00
#
# Epoch 00016: val_loss did not improve from 0.54208
# Epoch 17/5000
# 7232/7232 [==============================] - 2s 214us/step - loss: 0.5353 - acc: 0.0000e+00 - val_loss: 0.6868 - val_acc: 0.0000e+00
#
# Epoch 00017: val_loss did not improve from 0.54208
# Epoch 18/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.5293 - acc: 0.0000e+00 - val_loss: 0.8019 - val_acc: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 0.54208
# Epoch 19/5000
# 7232/7232 [==============================] - 2s 293us/step - loss: 0.5228 - acc: 0.0000e+00 - val_loss: 0.8009 - val_acc: 0.0000e+00
#
# Epoch 00019: val_loss did not improve from 0.54208
# Epoch 20/5000
# 7232/7232 [==============================] - 2s 272us/step - loss: 0.5190 - acc: 0.0000e+00 - val_loss: 0.8710 - val_acc: 0.0000e+00
#
# Epoch 00020: val_loss did not improve from 0.54208
# Epoch 21/5000
# 7232/7232 [==============================] - 2s 232us/step - loss: 0.5174 - acc: 0.0000e+00 - val_loss: 0.7955 - val_acc: 0.0000e+00
#
# Epoch 00021: val_loss did not improve from 0.54208
# Epoch 22/5000
# 7232/7232 [==============================] - 2s 222us/step - loss: 0.5034 - acc: 0.0000e+00 - val_loss: 0.7978 - val_acc: 0.0000e+00
#
# Epoch 00022: val_loss did not improve from 0.54208
# Epoch 23/5000
# 7232/7232 [==============================] - 2s 233us/step - loss: 0.5022 - acc: 0.0000e+00 - val_loss: 0.7547 - val_acc: 0.0000e+00
#
# Epoch 00023: val_loss did not improve from 0.54208
# Epoch 24/5000
# 7232/7232 [==============================] - 2s 229us/step - loss: 0.5061 - acc: 0.0000e+00 - val_loss: 0.8050 - val_acc: 0.0000e+00
#
# Epoch 00024: val_loss did not improve from 0.54208
# Epoch 25/5000
# 7232/7232 [==============================] - 2s 232us/step - loss: 0.5014 - acc: 0.0000e+00 - val_loss: 0.9127 - val_acc: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 0.54208
# Epoch 26/5000
# 7232/7232 [==============================] - 2s 218us/step - loss: 0.4940 - acc: 0.0000e+00 - val_loss: 0.8926 - val_acc: 0.0000e+00
#
# Epoch 00026: val_loss did not improve from 0.54208
# Epoch 27/5000
# 7232/7232 [==============================] - 2s 224us/step - loss: 0.4931 - acc: 0.0000e+00 - val_loss: 0.7019 - val_acc: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 0.54208
# Epoch 28/5000
# 7232/7232 [==============================] - 2s 226us/step - loss: 0.4925 - acc: 0.0000e+00 - val_loss: 0.6563 - val_acc: 0.0000e+00
#
# Epoch 00028: val_loss did not improve from 0.54208
# Epoch 29/5000
# 7232/7232 [==============================] - 2s 231us/step - loss: 0.4908 - acc: 0.0000e+00 - val_loss: 0.6140 - val_acc: 0.0000e+00
#
# Epoch 00029: val_loss did not improve from 0.54208
# Epoch 30/5000
# 7232/7232 [==============================] - 2s 229us/step - loss: 0.4732 - acc: 0.0000e+00 - val_loss: 0.6576 - val_acc: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 0.54208
# Epoch 31/5000
# 7232/7232 [==============================] - 2s 245us/step - loss: 0.4809 - acc: 0.0000e+00 - val_loss: 0.5889 - val_acc: 0.0000e+00
#
# Epoch 00031: val_loss did not improve from 0.54208
# Epoch 32/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.4771 - acc: 0.0000e+00 - val_loss: 0.5223 - val_acc: 0.0000e+00
#
# Epoch 00032: val_loss improved from 0.54208 to 0.52232, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.522321.hdf5
# Epoch 33/5000
# 7232/7232 [==============================] - 2s 255us/step - loss: 0.4709 - acc: 0.0000e+00 - val_loss: 0.5649 - val_acc: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 0.52232
# Epoch 34/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.4746 - acc: 0.0000e+00 - val_loss: 0.6037 - val_acc: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 0.52232
# Epoch 35/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.4746 - acc: 0.0000e+00 - val_loss: 0.6078 - val_acc: 0.0000e+00
#
# Epoch 00035: val_loss did not improve from 0.52232
# Epoch 36/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.4681 - acc: 0.0000e+00 - val_loss: 0.6104 - val_acc: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 0.52232
# Epoch 37/5000
# 7232/7232 [==============================] - 2s 230us/step - loss: 0.4650 - acc: 0.0000e+00 - val_loss: 0.4474 - val_acc: 0.0000e+00
#
# Epoch 00037: val_loss improved from 0.52232 to 0.44742, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.447422.hdf5
# Epoch 38/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.4666 - acc: 0.0000e+00 - val_loss: 0.6253 - val_acc: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 0.44742
# Epoch 39/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.4663 - acc: 0.0000e+00 - val_loss: 0.5027 - val_acc: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 0.44742
# Epoch 40/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.4582 - acc: 0.0000e+00 - val_loss: 0.4049 - val_acc: 0.0000e+00
#
# Epoch 00040: val_loss improved from 0.44742 to 0.40494, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.404938.hdf5
# Epoch 41/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.4557 - acc: 0.0000e+00 - val_loss: 0.5034 - val_acc: 0.0000e+00
#
# Epoch 00041: val_loss did not improve from 0.40494
# Epoch 42/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.4513 - acc: 0.0000e+00 - val_loss: 0.4988 - val_acc: 0.0000e+00
#
# Epoch 00042: val_loss did not improve from 0.40494
# Epoch 43/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.4536 - acc: 0.0000e+00 - val_loss: 0.4743 - val_acc: 0.0000e+00
#
# Epoch 00043: val_loss did not improve from 0.40494
# Epoch 44/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.4434 - acc: 0.0000e+00 - val_loss: 0.4654 - val_acc: 0.0000e+00
#
# Epoch 00044: val_loss did not improve from 0.40494
# Epoch 45/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.4470 - acc: 0.0000e+00 - val_loss: 0.5157 - val_acc: 0.0000e+00
#
# Epoch 00045: val_loss did not improve from 0.40494
# Epoch 46/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.4347 - acc: 0.0000e+00 - val_loss: 0.3873 - val_acc: 0.0000e+00
#
# Epoch 00046: val_loss improved from 0.40494 to 0.38727, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.387271.hdf5
# Epoch 47/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.4476 - acc: 0.0000e+00 - val_loss: 0.5511 - val_acc: 0.0000e+00
#
# Epoch 00047: val_loss did not improve from 0.38727
# Epoch 48/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.4414 - acc: 0.0000e+00 - val_loss: 0.4220 - val_acc: 0.0000e+00
#
# Epoch 00048: val_loss did not improve from 0.38727
# Epoch 49/5000
# 7232/7232 [==============================] - 2s 226us/step - loss: 0.4410 - acc: 0.0000e+00 - val_loss: 0.4187 - val_acc: 0.0000e+00
#
# Epoch 00049: val_loss did not improve from 0.38727
# Epoch 50/5000
# 7232/7232 [==============================] - 2s 236us/step - loss: 0.4458 - acc: 0.0000e+00 - val_loss: 0.4685 - val_acc: 0.0000e+00
#
# Epoch 00050: val_loss did not improve from 0.38727
# Epoch 51/5000
# 7232/7232 [==============================] - 2s 232us/step - loss: 0.4503 - acc: 0.0000e+00 - val_loss: 0.3496 - val_acc: 0.0000e+00
#
# Epoch 00051: val_loss improved from 0.38727 to 0.34963, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.349627.hdf5
# Epoch 52/5000
# 7232/7232 [==============================] - 2s 298us/step - loss: 0.4456 - acc: 0.0000e+00 - val_loss: 0.3878 - val_acc: 0.0000e+00
#
# Epoch 00052: val_loss did not improve from 0.34963
# Epoch 53/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.4420 - acc: 0.0000e+00 - val_loss: 0.4301 - val_acc: 0.0000e+00
#
# Epoch 00053: val_loss did not improve from 0.34963
# Epoch 54/5000
# 7232/7232 [==============================] - 2s 234us/step - loss: 0.4341 - acc: 0.0000e+00 - val_loss: 0.3943 - val_acc: 0.0000e+00
#
# Epoch 00054: val_loss did not improve from 0.34963
# Epoch 55/5000
# 7232/7232 [==============================] - 2s 266us/step - loss: 0.4369 - acc: 0.0000e+00 - val_loss: 0.4416 - val_acc: 0.0000e+00
#
# Epoch 00055: val_loss did not improve from 0.34963
# Epoch 56/5000
# 7232/7232 [==============================] - 2s 250us/step - loss: 0.4242 - acc: 0.0000e+00 - val_loss: 0.4592 - val_acc: 0.0000e+00
#
# Epoch 00056: val_loss did not improve from 0.34963
# Epoch 57/5000
# 7232/7232 [==============================] - 2s 237us/step - loss: 0.4252 - acc: 0.0000e+00 - val_loss: 0.3382 - val_acc: 0.0000e+00
#
# Epoch 00057: val_loss improved from 0.34963 to 0.33819, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.338185.hdf5
# Epoch 58/5000
# 7232/7232 [==============================] - 2s 228us/step - loss: 0.4376 - acc: 0.0000e+00 - val_loss: 0.3921 - val_acc: 0.0000e+00
#
# Epoch 00058: val_loss did not improve from 0.33819
# Epoch 59/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.4367 - acc: 0.0000e+00 - val_loss: 0.3500 - val_acc: 0.0000e+00
#
# Epoch 00059: val_loss did not improve from 0.33819
# Epoch 60/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.4296 - acc: 0.0000e+00 - val_loss: 0.3459 - val_acc: 0.0000e+00
#
# Epoch 00060: val_loss did not improve from 0.33819
# Epoch 61/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.4379 - acc: 0.0000e+00 - val_loss: 0.3668 - val_acc: 0.0000e+00
#
# Epoch 00061: val_loss did not improve from 0.33819
# Epoch 62/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.4230 - acc: 0.0000e+00 - val_loss: 0.4648 - val_acc: 0.0000e+00
#
# Epoch 00062: val_loss did not improve from 0.33819
# Epoch 63/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.4302 - acc: 0.0000e+00 - val_loss: 0.3484 - val_acc: 0.0000e+00
#
# Epoch 00063: val_loss did not improve from 0.33819
# Epoch 64/5000
# 7232/7232 [==============================] - 2s 224us/step - loss: 0.4287 - acc: 0.0000e+00 - val_loss: 0.4503 - val_acc: 0.0000e+00
#
# Epoch 00064: val_loss did not improve from 0.33819
# Epoch 65/5000
# 7232/7232 [==============================] - 2s 223us/step - loss: 0.4282 - acc: 0.0000e+00 - val_loss: 0.4567 - val_acc: 0.0000e+00
#
# Epoch 00065: val_loss did not improve from 0.33819
# Epoch 66/5000
# 7232/7232 [==============================] - 2s 237us/step - loss: 0.4258 - acc: 0.0000e+00 - val_loss: 0.3855 - val_acc: 0.0000e+00
#
# Epoch 00066: val_loss did not improve from 0.33819
# Epoch 67/5000
# 7232/7232 [==============================] - 2s 247us/step - loss: 0.4215 - acc: 0.0000e+00 - val_loss: 0.3467 - val_acc: 0.0000e+00
#
# Epoch 00067: val_loss did not improve from 0.33819
# Epoch 68/5000
# 7232/7232 [==============================] - 2s 251us/step - loss: 0.4118 - acc: 0.0000e+00 - val_loss: 0.3508 - val_acc: 0.0000e+00
#
# Epoch 00068: val_loss did not improve from 0.33819
# Epoch 69/5000
# 7232/7232 [==============================] - 2s 274us/step - loss: 0.4236 - acc: 0.0000e+00 - val_loss: 0.3397 - val_acc: 0.0000e+00
#
# Epoch 00069: val_loss did not improve from 0.33819
# Epoch 70/5000
# 7232/7232 [==============================] - 2s 276us/step - loss: 0.4190 - acc: 0.0000e+00 - val_loss: 0.3546 - val_acc: 0.0000e+00
#
# Epoch 00070: val_loss did not improve from 0.33819
# Epoch 71/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.4193 - acc: 0.0000e+00 - val_loss: 0.3565 - val_acc: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 0.33819
# Epoch 72/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.4193 - acc: 0.0000e+00 - val_loss: 0.3449 - val_acc: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 0.33819
# Epoch 73/5000
# 7232/7232 [==============================] - 2s 260us/step - loss: 0.4048 - acc: 0.0000e+00 - val_loss: 0.3933 - val_acc: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 0.33819
# Epoch 74/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.4172 - acc: 0.0000e+00 - val_loss: 0.3761 - val_acc: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 0.33819
# Epoch 75/5000
# 7232/7232 [==============================] - 2s 264us/step - loss: 0.4197 - acc: 0.0000e+00 - val_loss: 0.4147 - val_acc: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 0.33819
# Epoch 76/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.4101 - acc: 0.0000e+00 - val_loss: 0.4453 - val_acc: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 0.33819
# Epoch 77/5000
# 7232/7232 [==============================] - 2s 253us/step - loss: 0.4108 - acc: 0.0000e+00 - val_loss: 0.3870 - val_acc: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 0.33819
# Epoch 78/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.4063 - acc: 0.0000e+00 - val_loss: 0.3784 - val_acc: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 0.33819
# Epoch 79/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.4095 - acc: 0.0000e+00 - val_loss: 0.4168 - val_acc: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 0.33819
# Epoch 80/5000
# 7232/7232 [==============================] - 2s 262us/step - loss: 0.4209 - acc: 0.0000e+00 - val_loss: 0.3629 - val_acc: 0.0000e+00
#
# Epoch 00080: val_loss did not improve from 0.33819
# Epoch 81/5000
# 7232/7232 [==============================] - 2s 263us/step - loss: 0.4094 - acc: 0.0000e+00 - val_loss: 0.3405 - val_acc: 0.0000e+00
#
# Epoch 00081: val_loss did not improve from 0.33819
# Epoch 82/5000
# 7232/7232 [==============================] - 2s 279us/step - loss: 0.4050 - acc: 0.0000e+00 - val_loss: 0.4845 - val_acc: 0.0000e+00
#
# Epoch 00082: val_loss did not improve from 0.33819
# Epoch 83/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.4109 - acc: 0.0000e+00 - val_loss: 0.3975 - val_acc: 0.0000e+00
#
# Epoch 00083: val_loss did not improve from 0.33819
# Epoch 84/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.4077 - acc: 0.0000e+00 - val_loss: 0.3118 - val_acc: 0.0000e+00
#
# Epoch 00084: val_loss improved from 0.33819 to 0.31182, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.311822.hdf5
# Epoch 85/5000
# 7232/7232 [==============================] - 2s 293us/step - loss: 0.3978 - acc: 0.0000e+00 - val_loss: 0.3328 - val_acc: 0.0000e+00
#
# Epoch 00085: val_loss did not improve from 0.31182
# Epoch 86/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.3972 - acc: 0.0000e+00 - val_loss: 0.4021 - val_acc: 0.0000e+00
#
# Epoch 00086: val_loss did not improve from 0.31182
# Epoch 87/5000
# 7232/7232 [==============================] - 2s 273us/step - loss: 0.3975 - acc: 0.0000e+00 - val_loss: 0.4707 - val_acc: 0.0000e+00
#
# Epoch 00087: val_loss did not improve from 0.31182
# Epoch 88/5000
# 7232/7232 [==============================] - 2s 289us/step - loss: 0.3991 - acc: 0.0000e+00 - val_loss: 0.3981 - val_acc: 0.0000e+00
#
# Epoch 00088: val_loss did not improve from 0.31182
# Epoch 89/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3965 - acc: 0.0000e+00 - val_loss: 0.3604 - val_acc: 0.0000e+00
#
# Epoch 00089: val_loss did not improve from 0.31182
# Epoch 90/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.4020 - acc: 0.0000e+00 - val_loss: 0.5175 - val_acc: 0.0000e+00
#
# Epoch 00090: val_loss did not improve from 0.31182
# Epoch 91/5000
# 7232/7232 [==============================] - 2s 233us/step - loss: 0.3987 - acc: 0.0000e+00 - val_loss: 0.3843 - val_acc: 0.0000e+00
#
# Epoch 00091: val_loss did not improve from 0.31182
# Epoch 92/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.3873 - acc: 0.0000e+00 - val_loss: 0.4553 - val_acc: 0.0000e+00
#
# Epoch 00092: val_loss did not improve from 0.31182
# Epoch 93/5000
# 7232/7232 [==============================] - 2s 238us/step - loss: 0.3985 - acc: 0.0000e+00 - val_loss: 0.3248 - val_acc: 0.0000e+00
#
# Epoch 00093: val_loss did not improve from 0.31182
# Epoch 94/5000
# 7232/7232 [==============================] - 2s 234us/step - loss: 0.3849 - acc: 0.0000e+00 - val_loss: 0.3631 - val_acc: 0.0000e+00
#
# Epoch 00094: val_loss did not improve from 0.31182
# Epoch 95/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3864 - acc: 0.0000e+00 - val_loss: 0.3009 - val_acc: 0.0000e+00
#
# Epoch 00095: val_loss improved from 0.31182 to 0.30089, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.300887.hdf5
# Epoch 96/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3961 - acc: 0.0000e+00 - val_loss: 0.4070 - val_acc: 0.0000e+00
#
# Epoch 00096: val_loss did not improve from 0.30089
# Epoch 97/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.3833 - acc: 0.0000e+00 - val_loss: 0.3044 - val_acc: 0.0000e+00
#
# Epoch 00097: val_loss did not improve from 0.30089
# Epoch 98/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3779 - acc: 0.0000e+00 - val_loss: 0.3554 - val_acc: 0.0000e+00
#
# Epoch 00098: val_loss did not improve from 0.30089
# Epoch 99/5000
# 7232/7232 [==============================] - 2s 245us/step - loss: 0.3852 - acc: 0.0000e+00 - val_loss: 0.3193 - val_acc: 0.0000e+00
#
# Epoch 00099: val_loss did not improve from 0.30089
# Epoch 100/5000
# 7232/7232 [==============================] - 2s 227us/step - loss: 0.3899 - acc: 0.0000e+00 - val_loss: 0.4467 - val_acc: 0.0000e+00
#
# Epoch 00100: val_loss did not improve from 0.30089
# Epoch 101/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.3857 - acc: 0.0000e+00 - val_loss: 0.3182 - val_acc: 0.0000e+00
#
# Epoch 00101: val_loss did not improve from 0.30089
# Epoch 102/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.3823 - acc: 0.0000e+00 - val_loss: 0.4100 - val_acc: 0.0000e+00
#
# Epoch 00102: val_loss did not improve from 0.30089
# Epoch 103/5000
# 7232/7232 [==============================] - 2s 227us/step - loss: 0.3836 - acc: 0.0000e+00 - val_loss: 0.3629 - val_acc: 0.0000e+00
#
# Epoch 00103: val_loss did not improve from 0.30089
# Epoch 104/5000
# 7232/7232 [==============================] - 2s 228us/step - loss: 0.3882 - acc: 0.0000e+00 - val_loss: 0.3445 - val_acc: 0.0000e+00
#
# Epoch 00104: val_loss did not improve from 0.30089
# Epoch 105/5000
# 7232/7232 [==============================] - 2s 230us/step - loss: 0.3816 - acc: 0.0000e+00 - val_loss: 0.4882 - val_acc: 0.0000e+00
#
# Epoch 00105: val_loss did not improve from 0.30089
# Epoch 106/5000
# 7232/7232 [==============================] - 2s 222us/step - loss: 0.3858 - acc: 0.0000e+00 - val_loss: 0.2982 - val_acc: 0.0000e+00
#
# Epoch 00106: val_loss improved from 0.30089 to 0.29821, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.298207.hdf5
# Epoch 107/5000
# 7232/7232 [==============================] - 2s 223us/step - loss: 0.3903 - acc: 0.0000e+00 - val_loss: 0.3395 - val_acc: 0.0000e+00
#
# Epoch 00107: val_loss did not improve from 0.29821
# Epoch 108/5000
# 7232/7232 [==============================] - 2s 232us/step - loss: 0.3793 - acc: 0.0000e+00 - val_loss: 0.3294 - val_acc: 0.0000e+00
#
# Epoch 00108: val_loss did not improve from 0.29821
# Epoch 109/5000
# 7232/7232 [==============================] - 2s 231us/step - loss: 0.3939 - acc: 0.0000e+00 - val_loss: 0.3251 - val_acc: 0.0000e+00
#
# Epoch 00109: val_loss did not improve from 0.29821
# Epoch 110/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.3791 - acc: 0.0000e+00 - val_loss: 0.3287 - val_acc: 0.0000e+00
#
# Epoch 00110: val_loss did not improve from 0.29821
# Epoch 111/5000
# 7232/7232 [==============================] - 2s 264us/step - loss: 0.3717 - acc: 0.0000e+00 - val_loss: 0.3101 - val_acc: 0.0000e+00
#
# Epoch 00111: val_loss did not improve from 0.29821
# Epoch 112/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.3716 - acc: 0.0000e+00 - val_loss: 0.3117 - val_acc: 0.0000e+00
#
# Epoch 00112: val_loss did not improve from 0.29821
# Epoch 113/5000
# 7232/7232 [==============================] - 2s 253us/step - loss: 0.3729 - acc: 0.0000e+00 - val_loss: 0.4109 - val_acc: 0.0000e+00
#
# Epoch 00113: val_loss did not improve from 0.29821
# Epoch 114/5000
# 7232/7232 [==============================] - 2s 255us/step - loss: 0.3740 - acc: 0.0000e+00 - val_loss: 0.2736 - val_acc: 0.0000e+00
#
# Epoch 00114: val_loss improved from 0.29821 to 0.27357, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.273566.hdf5
# Epoch 115/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.3782 - acc: 0.0000e+00 - val_loss: 0.4902 - val_acc: 0.0000e+00
#
# Epoch 00115: val_loss did not improve from 0.27357
# Epoch 116/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.3736 - acc: 0.0000e+00 - val_loss: 0.6850 - val_acc: 0.0000e+00
#
# Epoch 00116: val_loss did not improve from 0.27357
# Epoch 117/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.3710 - acc: 0.0000e+00 - val_loss: 0.3340 - val_acc: 0.0000e+00
#
# Epoch 00117: val_loss did not improve from 0.27357
# Epoch 118/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.3724 - acc: 0.0000e+00 - val_loss: 0.3757 - val_acc: 0.0000e+00
#
# Epoch 00118: val_loss did not improve from 0.27357
# Epoch 119/5000
# 7232/7232 [==============================] - 2s 265us/step - loss: 0.3755 - acc: 0.0000e+00 - val_loss: 0.5199 - val_acc: 0.0000e+00
#
# Epoch 00119: val_loss did not improve from 0.27357
# Epoch 120/5000
# 7232/7232 [==============================] - 2s 263us/step - loss: 0.3749 - acc: 0.0000e+00 - val_loss: 0.3185 - val_acc: 0.0000e+00
#
# Epoch 00120: val_loss did not improve from 0.27357
# Epoch 121/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.3794 - acc: 0.0000e+00 - val_loss: 0.4089 - val_acc: 0.0000e+00
#
# Epoch 00121: val_loss did not improve from 0.27357
# Epoch 122/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3774 - acc: 0.0000e+00 - val_loss: 0.2976 - val_acc: 0.0000e+00
#
# Epoch 00122: val_loss did not improve from 0.27357
# Epoch 123/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3831 - acc: 0.0000e+00 - val_loss: 0.3558 - val_acc: 0.0000e+00
#
# Epoch 00123: val_loss did not improve from 0.27357
# Epoch 124/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.3804 - acc: 0.0000e+00 - val_loss: 0.2982 - val_acc: 0.0000e+00
#
# Epoch 00124: val_loss did not improve from 0.27357
# Epoch 125/5000
# 7232/7232 [==============================] - 2s 251us/step - loss: 0.3677 - acc: 0.0000e+00 - val_loss: 0.3127 - val_acc: 0.0000e+00
#
# Epoch 00125: val_loss did not improve from 0.27357
# Epoch 126/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3769 - acc: 0.0000e+00 - val_loss: 0.3504 - val_acc: 0.0000e+00
#
# Epoch 00126: val_loss did not improve from 0.27357
# Epoch 127/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.3824 - acc: 0.0000e+00 - val_loss: 0.6271 - val_acc: 0.0000e+00
#
# Epoch 00127: val_loss did not improve from 0.27357
# Epoch 128/5000
# 7232/7232 [==============================] - 2s 272us/step - loss: 0.3681 - acc: 0.0000e+00 - val_loss: 0.3285 - val_acc: 0.0000e+00
#
# Epoch 00128: val_loss did not improve from 0.27357
# Epoch 129/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3737 - acc: 0.0000e+00 - val_loss: 0.3516 - val_acc: 0.0000e+00
#
# Epoch 00129: val_loss did not improve from 0.27357
# Epoch 130/5000
# 7232/7232 [==============================] - 2s 274us/step - loss: 0.3734 - acc: 0.0000e+00 - val_loss: 0.3214 - val_acc: 0.0000e+00
#
# Epoch 00130: val_loss did not improve from 0.27357
# Epoch 131/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.3678 - acc: 0.0000e+00 - val_loss: 0.3209 - val_acc: 0.0000e+00
#
# Epoch 00131: val_loss did not improve from 0.27357
# Epoch 132/5000
# 7232/7232 [==============================] - 2s 247us/step - loss: 0.3622 - acc: 0.0000e+00 - val_loss: 0.4548 - val_acc: 0.0000e+00
#
# Epoch 00132: val_loss did not improve from 0.27357
# Epoch 133/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3648 - acc: 0.0000e+00 - val_loss: 0.2851 - val_acc: 0.0000e+00
#
# Epoch 00133: val_loss did not improve from 0.27357
# Epoch 134/5000
# 7232/7232 [==============================] - 2s 232us/step - loss: 0.3775 - acc: 0.0000e+00 - val_loss: 0.2662 - val_acc: 0.0000e+00
#
# Epoch 00134: val_loss improved from 0.27357 to 0.26623, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.266231.hdf5
# Epoch 135/5000
# 7232/7232 [==============================] - 2s 230us/step - loss: 0.3626 - acc: 0.0000e+00 - val_loss: 0.2803 - val_acc: 0.0000e+00
#
# Epoch 00135: val_loss did not improve from 0.26623
# Epoch 136/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.3693 - acc: 0.0000e+00 - val_loss: 0.2772 - val_acc: 0.0000e+00
#
# Epoch 00136: val_loss did not improve from 0.26623
# Epoch 137/5000
# 7232/7232 [==============================] - 2s 236us/step - loss: 0.3720 - acc: 0.0000e+00 - val_loss: 0.3225 - val_acc: 0.0000e+00
#
# Epoch 00137: val_loss did not improve from 0.26623
# Epoch 138/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.3756 - acc: 0.0000e+00 - val_loss: 0.2897 - val_acc: 0.0000e+00
#
# Epoch 00138: val_loss did not improve from 0.26623
# Epoch 139/5000
# 7232/7232 [==============================] - 2s 221us/step - loss: 0.3684 - acc: 0.0000e+00 - val_loss: 0.3213 - val_acc: 0.0000e+00
#
# Epoch 00139: val_loss did not improve from 0.26623
# Epoch 140/5000
# 7232/7232 [==============================] - 2s 255us/step - loss: 0.3685 - acc: 0.0000e+00 - val_loss: 0.3179 - val_acc: 0.0000e+00
#
# Epoch 00140: val_loss did not improve from 0.26623
# Epoch 141/5000
# 7232/7232 [==============================] - 2s 264us/step - loss: 0.3755 - acc: 0.0000e+00 - val_loss: 0.2816 - val_acc: 0.0000e+00
#
# Epoch 00141: val_loss did not improve from 0.26623
# Epoch 142/5000
# 7232/7232 [==============================] - 2s 247us/step - loss: 0.3616 - acc: 0.0000e+00 - val_loss: 0.3308 - val_acc: 0.0000e+00
#
# Epoch 00142: val_loss did not improve from 0.26623
# Epoch 143/5000
# 7232/7232 [==============================] - 2s 228us/step - loss: 0.3620 - acc: 0.0000e+00 - val_loss: 0.3261 - val_acc: 0.0000e+00
#
# Epoch 00143: val_loss did not improve from 0.26623
# Epoch 144/5000
# 7232/7232 [==============================] - 2s 226us/step - loss: 0.3620 - acc: 0.0000e+00 - val_loss: 0.2671 - val_acc: 0.0000e+00
#
# Epoch 00144: val_loss did not improve from 0.26623
# Epoch 145/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.3646 - acc: 0.0000e+00 - val_loss: 0.2764 - val_acc: 0.0000e+00
#
# Epoch 00145: val_loss did not improve from 0.26623
# Epoch 146/5000
# 7232/7232 [==============================] - 2s 222us/step - loss: 0.3592 - acc: 0.0000e+00 - val_loss: 0.2850 - val_acc: 0.0000e+00
#
# Epoch 00146: val_loss did not improve from 0.26623
# Epoch 147/5000
# 7232/7232 [==============================] - 2s 227us/step - loss: 0.3606 - acc: 0.0000e+00 - val_loss: 0.2943 - val_acc: 0.0000e+00
#
# Epoch 00147: val_loss did not improve from 0.26623
# Epoch 148/5000
# 7232/7232 [==============================] - 2s 236us/step - loss: 0.3572 - acc: 0.0000e+00 - val_loss: 0.3248 - val_acc: 0.0000e+00
#
# Epoch 00148: val_loss did not improve from 0.26623
# Epoch 149/5000
# 7232/7232 [==============================] - 2s 222us/step - loss: 0.3550 - acc: 0.0000e+00 - val_loss: 0.3164 - val_acc: 0.0000e+00
#
# Epoch 00149: val_loss did not improve from 0.26623
# Epoch 150/5000
# 7232/7232 [==============================] - 2s 253us/step - loss: 0.3606 - acc: 0.0000e+00 - val_loss: 0.3141 - val_acc: 0.0000e+00
#
# Epoch 00150: val_loss did not improve from 0.26623
# Epoch 151/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.3660 - acc: 0.0000e+00 - val_loss: 0.3025 - val_acc: 0.0000e+00
#
# Epoch 00151: val_loss did not improve from 0.26623
# Epoch 152/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.3647 - acc: 0.0000e+00 - val_loss: 0.2962 - val_acc: 0.0000e+00
#
# Epoch 00152: val_loss did not improve from 0.26623
# Epoch 153/5000
# 7232/7232 [==============================] - 2s 263us/step - loss: 0.3638 - acc: 0.0000e+00 - val_loss: 0.2963 - val_acc: 0.0000e+00
#
# Epoch 00153: val_loss did not improve from 0.26623
# Epoch 154/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3586 - acc: 0.0000e+00 - val_loss: 0.3318 - val_acc: 0.0000e+00
#
# Epoch 00154: val_loss did not improve from 0.26623
# Epoch 155/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.3535 - acc: 0.0000e+00 - val_loss: 0.3307 - val_acc: 0.0000e+00
#
# Epoch 00155: val_loss did not improve from 0.26623
# Epoch 156/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3556 - acc: 0.0000e+00 - val_loss: 0.2680 - val_acc: 0.0000e+00
#
# Epoch 00156: val_loss did not improve from 0.26623
# Epoch 157/5000
# 7232/7232 [==============================] - 2s 274us/step - loss: 0.3554 - acc: 0.0000e+00 - val_loss: 0.2737 - val_acc: 0.0000e+00
#
# Epoch 00157: val_loss did not improve from 0.26623
# Epoch 158/5000
# 7232/7232 [==============================] - 2s 279us/step - loss: 0.3537 - acc: 0.0000e+00 - val_loss: 0.3028 - val_acc: 0.0000e+00
#
# Epoch 00158: val_loss did not improve from 0.26623
# Epoch 159/5000
# 7232/7232 [==============================] - 2s 253us/step - loss: 0.3637 - acc: 0.0000e+00 - val_loss: 0.3726 - val_acc: 0.0000e+00
#
# Epoch 00159: val_loss did not improve from 0.26623
# Epoch 160/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3670 - acc: 0.0000e+00 - val_loss: 0.4545 - val_acc: 0.0000e+00
#
# Epoch 00160: val_loss did not improve from 0.26623
# Epoch 161/5000
# 7232/7232 [==============================] - 2s 267us/step - loss: 0.3588 - acc: 0.0000e+00 - val_loss: 0.3017 - val_acc: 0.0000e+00
#
# Epoch 00161: val_loss did not improve from 0.26623
# Epoch 162/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3634 - acc: 0.0000e+00 - val_loss: 0.3068 - val_acc: 0.0000e+00
#
# Epoch 00162: val_loss did not improve from 0.26623
# Epoch 163/5000
# 7232/7232 [==============================] - 2s 267us/step - loss: 0.3500 - acc: 0.0000e+00 - val_loss: 0.3479 - val_acc: 0.0000e+00
#
# Epoch 00163: val_loss did not improve from 0.26623
# Epoch 164/5000
# 7232/7232 [==============================] - 2s 253us/step - loss: 0.3587 - acc: 0.0000e+00 - val_loss: 0.2960 - val_acc: 0.0000e+00
#
# Epoch 00164: val_loss did not improve from 0.26623
# Epoch 165/5000
# 7232/7232 [==============================] - 2s 255us/step - loss: 0.3592 - acc: 0.0000e+00 - val_loss: 0.2741 - val_acc: 0.0000e+00
#
# Epoch 00165: val_loss did not improve from 0.26623
# Epoch 166/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.3667 - acc: 0.0000e+00 - val_loss: 0.2786 - val_acc: 0.0000e+00
#
# Epoch 00166: val_loss did not improve from 0.26623
# Epoch 167/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.3527 - acc: 0.0000e+00 - val_loss: 0.2841 - val_acc: 0.0000e+00
#
# Epoch 00167: val_loss did not improve from 0.26623
# Epoch 168/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.3539 - acc: 0.0000e+00 - val_loss: 0.4416 - val_acc: 0.0000e+00
#
# Epoch 00168: val_loss did not improve from 0.26623
# Epoch 169/5000
# 7232/7232 [==============================] - 2s 251us/step - loss: 0.3585 - acc: 0.0000e+00 - val_loss: 0.2997 - val_acc: 0.0000e+00
#
# Epoch 00169: val_loss did not improve from 0.26623
# Epoch 170/5000
# 7232/7232 [==============================] - 2s 253us/step - loss: 0.3534 - acc: 0.0000e+00 - val_loss: 0.2959 - val_acc: 0.0000e+00
#
# Epoch 00170: val_loss did not improve from 0.26623
# Epoch 171/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.3571 - acc: 0.0000e+00 - val_loss: 0.2978 - val_acc: 0.0000e+00
#
# Epoch 00171: val_loss did not improve from 0.26623
# Epoch 172/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.3430 - acc: 0.0000e+00 - val_loss: 0.2764 - val_acc: 0.0000e+00
#
# Epoch 00172: val_loss did not improve from 0.26623
# Epoch 173/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.3580 - acc: 0.0000e+00 - val_loss: 0.2647 - val_acc: 0.0000e+00
#
# Epoch 00173: val_loss improved from 0.26623 to 0.26467, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.264671.hdf5
# Epoch 174/5000
# 7232/7232 [==============================] - 2s 229us/step - loss: 0.3582 - acc: 0.0000e+00 - val_loss: 0.2784 - val_acc: 0.0000e+00
#
# Epoch 00174: val_loss did not improve from 0.26467
# Epoch 175/5000
# 7232/7232 [==============================] - 2s 242us/step - loss: 0.3632 - acc: 0.0000e+00 - val_loss: 0.2968 - val_acc: 0.0000e+00
#
# Epoch 00175: val_loss did not improve from 0.26467
# Epoch 176/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.3495 - acc: 0.0000e+00 - val_loss: 0.2861 - val_acc: 0.0000e+00
#
# Epoch 00176: val_loss did not improve from 0.26467
# Epoch 177/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.3566 - acc: 0.0000e+00 - val_loss: 0.3266 - val_acc: 0.0000e+00
#
# Epoch 00177: val_loss did not improve from 0.26467
# Epoch 178/5000
# 7232/7232 [==============================] - 2s 230us/step - loss: 0.3562 - acc: 0.0000e+00 - val_loss: 0.3459 - val_acc: 0.0000e+00
#
# Epoch 00178: val_loss did not improve from 0.26467
# Epoch 179/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.3496 - acc: 0.0000e+00 - val_loss: 0.2656 - val_acc: 0.0000e+00
#
# Epoch 00179: val_loss did not improve from 0.26467
# Epoch 180/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3541 - acc: 0.0000e+00 - val_loss: 0.2993 - val_acc: 0.0000e+00
#
# Epoch 00180: val_loss did not improve from 0.26467
# Epoch 181/5000
# 7232/7232 [==============================] - 2s 228us/step - loss: 0.3686 - acc: 0.0000e+00 - val_loss: 0.2774 - val_acc: 0.0000e+00
#
# Epoch 00181: val_loss did not improve from 0.26467
# Epoch 182/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3527 - acc: 0.0000e+00 - val_loss: 0.2740 - val_acc: 0.0000e+00
#
# Epoch 00182: val_loss did not improve from 0.26467
# Epoch 183/5000
# 7232/7232 [==============================] - 2s 260us/step - loss: 0.3570 - acc: 0.0000e+00 - val_loss: 0.2712 - val_acc: 0.0000e+00
#
# Epoch 00183: val_loss did not improve from 0.26467
# Epoch 184/5000
# 7232/7232 [==============================] - 2s 226us/step - loss: 0.3536 - acc: 0.0000e+00 - val_loss: 0.3120 - val_acc: 0.0000e+00
#
# Epoch 00184: val_loss did not improve from 0.26467
# Epoch 185/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3538 - acc: 0.0000e+00 - val_loss: 0.3035 - val_acc: 0.0000e+00
#
# Epoch 00185: val_loss did not improve from 0.26467
# Epoch 186/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3476 - acc: 0.0000e+00 - val_loss: 0.2713 - val_acc: 0.0000e+00
#
# Epoch 00186: val_loss did not improve from 0.26467
# Epoch 187/5000
# 7232/7232 [==============================] - 2s 224us/step - loss: 0.3698 - acc: 0.0000e+00 - val_loss: 0.2937 - val_acc: 0.0000e+00
#
# Epoch 00187: val_loss did not improve from 0.26467
# Epoch 188/5000
# 7232/7232 [==============================] - 2s 216us/step - loss: 0.3557 - acc: 0.0000e+00 - val_loss: 0.3355 - val_acc: 0.0000e+00
#
# Epoch 00188: val_loss did not improve from 0.26467
# Epoch 189/5000
# 7232/7232 [==============================] - 2s 223us/step - loss: 0.3526 - acc: 0.0000e+00 - val_loss: 0.2698 - val_acc: 0.0000e+00
#
# Epoch 00189: val_loss did not improve from 0.26467
# Epoch 190/5000
# 7232/7232 [==============================] - 2s 214us/step - loss: 0.3511 - acc: 0.0000e+00 - val_loss: 0.2748 - val_acc: 0.0000e+00
# Epoch 00190: val_loss did not improve from 0.26467
# Epoch 191/5000
# 7232/7232 [==============================] - 2s 237us/step - loss: 0.3456 - acc: 0.0000e+00 - val_loss: 0.2925 - val_acc: 0.0000e+00
#
# Epoch 00191: val_loss did not improve from 0.26467
# Epoch 192/5000
# 7232/7232 [==============================] - 2s 245us/step - loss: 0.3533 - acc: 0.0000e+00 - val_loss: 0.2920 - val_acc: 0.0000e+00
#
# Epoch 00192: val_loss did not improve from 0.26467
# Epoch 193/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3404 - acc: 0.0000e+00 - val_loss: 0.2991 - val_acc: 0.0000e+00
#
# Epoch 00193: val_loss did not improve from 0.26467
# Epoch 194/5000
# 7232/7232 [==============================] - 2s 238us/step - loss: 0.3468 - acc: 0.0000e+00 - val_loss: 0.2948 - val_acc: 0.0000e+00
#
# Epoch 00194: val_loss did not improve from 0.26467
# Epoch 195/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.3465 - acc: 0.0000e+00 - val_loss: 0.2911 - val_acc: 0.0000e+00
#
# Epoch 00195: val_loss did not improve from 0.26467
# Epoch 196/5000
# 7232/7232 [==============================] - 2s 236us/step - loss: 0.3508 - acc: 0.0000e+00 - val_loss: 0.2549 - val_acc: 0.0000e+00
#
# Epoch 00196: val_loss improved from 0.26467 to 0.25493, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.254930.hdf5
# Epoch 197/5000
# 7232/7232 [==============================] - 2s 224us/step - loss: 0.3496 - acc: 0.0000e+00 - val_loss: 0.3199 - val_acc: 0.0000e+00
#
# Epoch 00197: val_loss did not improve from 0.25493
# Epoch 198/5000
# 7232/7232 [==============================] - 2s 266us/step - loss: 0.3455 - acc: 0.0000e+00 - val_loss: 0.2916 - val_acc: 0.0000e+00
#
# Epoch 00198: val_loss did not improve from 0.25493
# Epoch 199/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3583 - acc: 0.0000e+00 - val_loss: 0.3068 - val_acc: 0.0000e+00
#
# Epoch 00199: val_loss did not improve from 0.25493
# Epoch 200/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3486 - acc: 0.0000e+00 - val_loss: 0.3042 - val_acc: 0.0000e+00
#
# Epoch 00200: val_loss did not improve from 0.25493
# Epoch 201/5000
# 7232/7232 [==============================] - 2s 247us/step - loss: 0.3466 - acc: 0.0000e+00 - val_loss: 0.3089 - val_acc: 0.0000e+00
#
# Epoch 00201: val_loss did not improve from 0.25493
# Epoch 202/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3527 - acc: 0.0000e+00 - val_loss: 0.2710 - val_acc: 0.0000e+00
#
# Epoch 00202: val_loss did not improve from 0.25493
# Epoch 203/5000
# 7232/7232 [==============================] - 2s 275us/step - loss: 0.3485 - acc: 0.0000e+00 - val_loss: 0.3277 - val_acc: 0.0000e+00
#
# Epoch 00203: val_loss did not improve from 0.25493
# Epoch 204/5000
# 7232/7232 [==============================] - 2s 272us/step - loss: 0.3530 - acc: 0.0000e+00 - val_loss: 0.2677 - val_acc: 0.0000e+00
#
# Epoch 00204: val_loss did not improve from 0.25493
# Epoch 205/5000
# 7232/7232 [==============================] - 2s 296us/step - loss: 0.3512 - acc: 0.0000e+00 - val_loss: 0.2661 - val_acc: 0.0000e+00
#
# Epoch 00205: val_loss did not improve from 0.25493
# Epoch 206/5000
# 7232/7232 [==============================] - 2s 262us/step - loss: 0.3481 - acc: 0.0000e+00 - val_loss: 0.3185 - val_acc: 0.0000e+00
#
# Epoch 00206: val_loss did not improve from 0.25493
# Epoch 207/5000
# 7232/7232 [==============================] - 2s 275us/step - loss: 0.3484 - acc: 0.0000e+00 - val_loss: 0.2598 - val_acc: 0.0000e+00
#
# Epoch 00207: val_loss did not improve from 0.25493
# Epoch 208/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.3553 - acc: 0.0000e+00 - val_loss: 0.2874 - val_acc: 0.0000e+00
#
# Epoch 00208: val_loss did not improve from 0.25493
# Epoch 209/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.3509 - acc: 0.0000e+00 - val_loss: 0.2492 - val_acc: 0.0000e+00
#
# Epoch 00209: val_loss improved from 0.25493 to 0.24920, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.249198.hdf5
# Epoch 210/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3624 - acc: 0.0000e+00 - val_loss: 0.2766 - val_acc: 0.0000e+00
#
# Epoch 00210: val_loss did not improve from 0.24920
# Epoch 211/5000
# 7232/7232 [==============================] - 2s 315us/step - loss: 0.3411 - acc: 0.0000e+00 - val_loss: 0.2751 - val_acc: 0.0000e+00
#
# Epoch 00211: val_loss did not improve from 0.24920
# Epoch 212/5000
# 7232/7232 [==============================] - 2s 292us/step - loss: 0.3358 - acc: 0.0000e+00 - val_loss: 0.2643 - val_acc: 0.0000e+00
#
# Epoch 00212: val_loss did not improve from 0.24920
# Epoch 213/5000
# 7232/7232 [==============================] - 2s 277us/step - loss: 0.3439 - acc: 0.0000e+00 - val_loss: 0.2589 - val_acc: 0.0000e+00
#
# Epoch 00213: val_loss did not improve from 0.24920
# Epoch 214/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3486 - acc: 0.0000e+00 - val_loss: 0.2636 - val_acc: 0.0000e+00
#
# Epoch 00214: val_loss did not improve from 0.24920
# Epoch 215/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3483 - acc: 0.0000e+00 - val_loss: 0.2750 - val_acc: 0.0000e+00
#
# Epoch 00215: val_loss did not improve from 0.24920
# Epoch 216/5000
# 7232/7232 [==============================] - 2s 270us/step - loss: 0.3512 - acc: 0.0000e+00 - val_loss: 0.2806 - val_acc: 0.0000e+00
#
# Epoch 00216: val_loss did not improve from 0.24920
# Epoch 217/5000
# 7232/7232 [==============================] - 2s 242us/step - loss: 0.3524 - acc: 0.0000e+00 - val_loss: 0.2481 - val_acc: 0.0000e+00
#
# Epoch 00217: val_loss improved from 0.24920 to 0.24809, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.248094.hdf5
# Epoch 218/5000
# 7232/7232 [==============================] - 2s 234us/step - loss: 0.3537 - acc: 0.0000e+00 - val_loss: 0.4915 - val_acc: 0.0000e+00
#
# Epoch 00218: val_loss did not improve from 0.24809
# Epoch 219/5000
# 7232/7232 [==============================] - 2s 237us/step - loss: 0.3472 - acc: 0.0000e+00 - val_loss: 0.2893 - val_acc: 0.0000e+00
#
# Epoch 00219: val_loss did not improve from 0.24809
# Epoch 220/5000
# 7232/7232 [==============================] - 2s 236us/step - loss: 0.3394 - acc: 0.0000e+00 - val_loss: 0.3127 - val_acc: 0.0000e+00
#
# Epoch 00220: val_loss did not improve from 0.24809
# Epoch 221/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.3468 - acc: 0.0000e+00 - val_loss: 0.2750 - val_acc: 0.0000e+00
#
# Epoch 00221: val_loss did not improve from 0.24809
# Epoch 222/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.3426 - acc: 0.0000e+00 - val_loss: 0.2583 - val_acc: 0.0000e+00
#
# Epoch 00222: val_loss did not improve from 0.24809
# Epoch 223/5000
# 7232/7232 [==============================] - 2s 265us/step - loss: 0.3454 - acc: 0.0000e+00 - val_loss: 0.2642 - val_acc: 0.0000e+00
#
# Epoch 00223: val_loss did not improve from 0.24809
# Epoch 224/5000
# 7232/7232 [==============================] - 2s 255us/step - loss: 0.3347 - acc: 0.0000e+00 - val_loss: 0.2554 - val_acc: 0.0000e+00
#
# ...
#
# Epoch 00281: val_loss did not improve from 0.23413
# Epoch 282/5000
# 7232/7232 [==============================] - 2s 247us/step - loss: 0.3401 - acc: 0.0000e+00 - val_loss: 0.2473 - val_acc: 0.0000e+00
#
# Epoch 00282: val_loss did not improve from 0.23413
# Epoch 283/5000
# 7232/7232 [==============================] - 2s 234us/step - loss: 0.3357 - acc: 0.0000e+00 - val_loss: 0.2706 - val_acc: 0.0000e+00
#
# Epoch 00283: val_loss did not improve from 0.23413
# Epoch 284/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3295 - acc: 0.0000e+00 - val_loss: 0.2798 - val_acc: 0.0000e+00
#
# Epoch 00284: val_loss did not improve from 0.23413
# Epoch 285/5000
# 7232/7232 [==============================] - 2s 253us/step - loss: 0.3318 - acc: 0.0000e+00 - val_loss: 0.3573 - val_acc: 0.0000e+00
#
# Epoch 00285: val_loss did not improve from 0.23413
# Epoch 286/5000
# 7232/7232 [==============================] - 2s 262us/step - loss: 0.3331 - acc: 0.0000e+00 - val_loss: 0.2638 - val_acc: 0.0000e+00
#
# Epoch 00286: val_loss did not improve from 0.23413
# Epoch 287/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3406 - acc: 0.0000e+00 - val_loss: 0.2351 - val_acc: 0.0000e+00
#
# Epoch 00287: val_loss did not improve from 0.23413
# Epoch 288/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3338 - acc: 0.0000e+00 - val_loss: 0.2522 - val_acc: 0.0000e+00
#
# Epoch 00288: val_loss did not improve from 0.23413
# Epoch 289/5000
# 7232/7232 [==============================] - 2s 231us/step - loss: 0.3387 - acc: 0.0000e+00 - val_loss: 0.2441 - val_acc: 0.0000e+00
#
# Epoch 00289: val_loss did not improve from 0.23413
# Epoch 290/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3368 - acc: 0.0000e+00 - val_loss: 0.2669 - val_acc: 0.0000e+00
#
# Epoch 00290: val_loss did not improve from 0.23413
# Epoch 291/5000
# 7232/7232 [==============================] - 2s 231us/step - loss: 0.3275 - acc: 0.0000e+00 - val_loss: 0.2434 - val_acc: 0.0000e+00
#
# Epoch 00291: val_loss did not improve from 0.23413
# Epoch 292/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.3367 - acc: 0.0000e+00 - val_loss: 0.2387 - val_acc: 0.0000e+00
#
# Epoch 00292: val_loss did not improve from 0.23413
# Epoch 293/5000
# 7232/7232 [==============================] - 2s 227us/step - loss: 0.3343 - acc: 0.0000e+00 - val_loss: 0.2410 - val_acc: 0.0000e+00
#
# Epoch 00293: val_loss did not improve from 0.23413
# Epoch 294/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.3340 - acc: 0.0000e+00 - val_loss: 0.2592 - val_acc: 0.0000e+00
#
# Epoch 00294: val_loss did not improve from 0.23413
# Epoch 295/5000
# 7232/7232 [==============================] - 2s 232us/step - loss: 0.3240 - acc: 0.0000e+00 - val_loss: 0.2727 - val_acc: 0.0000e+00
#
# Epoch 00295: val_loss did not improve from 0.23413
# Epoch 296/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3298 - acc: 0.0000e+00 - val_loss: 0.2899 - val_acc: 0.0000e+00
#
# Epoch 00296: val_loss did not improve from 0.23413
# Epoch 297/5000
# 7232/7232 [==============================] - 2s 224us/step - loss: 0.3341 - acc: 0.0000e+00 - val_loss: 0.2605 - val_acc: 0.0000e+00
#
# Epoch 00297: val_loss did not improve from 0.23413
# Epoch 298/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.3407 - acc: 0.0000e+00 - val_loss: 0.4182 - val_acc: 0.0000e+00
#
# Epoch 00298: val_loss did not improve from 0.23413
# Epoch 299/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3356 - acc: 0.0000e+00 - val_loss: 0.2626 - val_acc: 0.0000e+00
#
# Epoch 00299: val_loss did not improve from 0.23413
# Epoch 300/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.3390 - acc: 0.0000e+00 - val_loss: 0.2850 - val_acc: 0.0000e+00
#
# Epoch 00300: val_loss did not improve from 0.23413
# Epoch 301/5000
# 7232/7232 [==============================] - 2s 220us/step - loss: 0.3312 - acc: 0.0000e+00 - val_loss: 0.3102 - val_acc: 0.0000e+00
#
# Epoch 00301: val_loss did not improve from 0.23413
# Epoch 302/5000
# 7232/7232 [==============================] - 2s 260us/step - loss: 0.3365 - acc: 0.0000e+00 - val_loss: 0.2503 - val_acc: 0.0000e+00
#
# Epoch 00302: val_loss did not improve from 0.23413
# Epoch 303/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3313 - acc: 0.0000e+00 - val_loss: 0.2581 - val_acc: 0.0000e+00
#
# Epoch 00303: val_loss did not improve from 0.23413
# Epoch 304/5000
# 7232/7232 [==============================] - 2s 215us/step - loss: 0.3280 - acc: 0.0000e+00 - val_loss: 0.2566 - val_acc: 0.0000e+00
#
# Epoch 00304: val_loss did not improve from 0.23413
# Epoch 305/5000
# 7232/7232 [==============================] - 2s 226us/step - loss: 0.3292 - acc: 0.0000e+00 - val_loss: 0.2344 - val_acc: 0.0000e+00
#
# Epoch 00305: val_loss did not improve from 0.23413
# Epoch 306/5000
# 7232/7232 [==============================] - 2s 230us/step - loss: 0.3398 - acc: 0.0000e+00 - val_loss: 0.2452 - val_acc: 0.0000e+00
#
# Epoch 00306: val_loss did not improve from 0.23413
# Epoch 307/5000
# 7232/7232 [==============================] - 2s 219us/step - loss: 0.3385 - acc: 0.0000e+00 - val_loss: 0.2425 - val_acc: 0.0000e+00
#
# Epoch 00307: val_loss did not improve from 0.23413
# Epoch 308/5000
# 7232/7232 [==============================] - 2s 224us/step - loss: 0.3207 - acc: 0.0000e+00 - val_loss: 0.2375 - val_acc: 0.0000e+00
#
# Epoch 00308: val_loss did not improve from 0.23413
# Epoch 309/5000
# 7232/7232 [==============================] - 2s 221us/step - loss: 0.3356 - acc: 0.0000e+00 - val_loss: 0.2380 - val_acc: 0.0000e+00
#
# Epoch 00309: val_loss did not improve from 0.23413
# Epoch 310/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3308 - acc: 0.0000e+00 - val_loss: 0.2273 - val_acc: 0.0000e+00
#
# Epoch 00310: val_loss improved from 0.23413 to 0.22729, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.227289.hdf5
# Epoch 311/5000
# 7232/7232 [==============================] - 2s 238us/step - loss: 0.3273 - acc: 0.0000e+00 - val_loss: 0.2756 - val_acc: 0.0000e+00
#
# Epoch 00311: val_loss did not improve from 0.22729
# Epoch 312/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3258 - acc: 0.0000e+00 - val_loss: 0.2491 - val_acc: 0.0000e+00
#
# Epoch 00312: val_loss did not improve from 0.22729
# Epoch 313/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3363 - acc: 0.0000e+00 - val_loss: 0.2614 - val_acc: 0.0000e+00
#
# Epoch 00313: val_loss did not improve from 0.22729
# Epoch 314/5000
# 7232/7232 [==============================] - 2s 242us/step - loss: 0.3341 - acc: 0.0000e+00 - val_loss: 0.2648 - val_acc: 0.0000e+00
#
# Epoch 00314: val_loss did not improve from 0.22729
# Epoch 315/5000
# 7232/7232 [==============================] - 2s 242us/step - loss: 0.3316 - acc: 0.0000e+00 - val_loss: 0.2954 - val_acc: 0.0000e+00
#
# Epoch 00315: val_loss did not improve from 0.22729
# Epoch 316/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3297 - acc: 0.0000e+00 - val_loss: 0.2398 - val_acc: 0.0000e+00
#
# Epoch 00316: val_loss did not improve from 0.22729
# Epoch 317/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3236 - acc: 0.0000e+00 - val_loss: 0.2659 - val_acc: 0.0000e+00
#
# Epoch 00317: val_loss did not improve from 0.22729
# Epoch 318/5000
# 7232/7232 [==============================] - 2s 228us/step - loss: 0.3207 - acc: 0.0000e+00 - val_loss: 0.2688 - val_acc: 0.0000e+00
#
# Epoch 00318: val_loss did not improve from 0.22729
# Epoch 319/5000
# 7232/7232 [==============================] - 2s 255us/step - loss: 0.3222 - acc: 0.0000e+00 - val_loss: 0.2463 - val_acc: 0.0000e+00
#
# Epoch 00319: val_loss did not improve from 0.22729
# Epoch 320/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.3295 - acc: 0.0000e+00 - val_loss: 0.2679 - val_acc: 0.0000e+00
#
# Epoch 00320: val_loss did not improve from 0.22729
# Epoch 321/5000
# 7232/7232 [==============================] - 2s 291us/step - loss: 0.3321 - acc: 0.0000e+00 - val_loss: 0.3704 - val_acc: 0.0000e+00
#
# Epoch 00321: val_loss did not improve from 0.22729
# Epoch 322/5000
# 7232/7232 [==============================] - 2s 263us/step - loss: 0.3350 - acc: 0.0000e+00 - val_loss: 0.2426 - val_acc: 0.0000e+00
#
# Epoch 00322: val_loss did not improve from 0.22729
# Epoch 323/5000
# 7232/7232 [==============================] - 2s 274us/step - loss: 0.3263 - acc: 0.0000e+00 - val_loss: 0.2409 - val_acc: 0.0000e+00
#
# Epoch 00323: val_loss did not improve from 0.22729
# Epoch 324/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.3295 - acc: 0.0000e+00 - val_loss: 0.2394 - val_acc: 0.0000e+00
#
# Epoch 00324: val_loss did not improve from 0.22729
# Epoch 325/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3198 - acc: 0.0000e+00 - val_loss: 0.2393 - val_acc: 0.0000e+00
#
# Epoch 00325: val_loss did not improve from 0.22729
# Epoch 326/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.3338 - acc: 0.0000e+00 - val_loss: 0.4261 - val_acc: 0.0000e+00
#
# Epoch 00326: val_loss did not improve from 0.22729
# Epoch 327/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.3365 - acc: 0.0000e+00 - val_loss: 0.2631 - val_acc: 0.0000e+00
#
# Epoch 00327: val_loss did not improve from 0.22729
# Epoch 328/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.3253 - acc: 0.0000e+00 - val_loss: 0.2397 - val_acc: 0.0000e+00
#
# Epoch 00328: val_loss did not improve from 0.22729
# Epoch 329/5000
# 7232/7232 [==============================] - 2s 255us/step - loss: 0.3251 - acc: 0.0000e+00 - val_loss: 0.2559 - val_acc: 0.0000e+00
#
# Epoch 00329: val_loss did not improve from 0.22729
# Epoch 330/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3312 - acc: 0.0000e+00 - val_loss: 0.2363 - val_acc: 0.0000e+00
#
# Epoch 00330: val_loss did not improve from 0.22729
# Epoch 331/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.3282 - acc: 0.0000e+00 - val_loss: 0.2353 - val_acc: 0.0000e+00
#
# Epoch 00331: val_loss did not improve from 0.22729
# Epoch 332/5000
# 7232/7232 [==============================] - 2s 251us/step - loss: 0.3269 - acc: 0.0000e+00 - val_loss: 0.2495 - val_acc: 0.0000e+00
#
# Epoch 00332: val_loss did not improve from 0.22729
# Epoch 333/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.3264 - acc: 0.0000e+00 - val_loss: 0.2538 - val_acc: 0.0000e+00
#
# Epoch 00333: val_loss did not improve from 0.22729
# Epoch 334/5000
# 7232/7232 [==============================] - 2s 230us/step - loss: 0.3443 - acc: 0.0000e+00 - val_loss: 0.2789 - val_acc: 0.0000e+00
#
# Epoch 00334: val_loss did not improve from 0.22729
# Epoch 335/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.3227 - acc: 0.0000e+00 - val_loss: 0.2348 - val_acc: 0.0000e+00
#
# Epoch 00335: val_loss did not improve from 0.22729
# Epoch 336/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.3271 - acc: 0.0000e+00 - val_loss: 0.2991 - val_acc: 0.0000e+00
#
# Epoch 00336: val_loss did not improve from 0.22729
# Epoch 337/5000
# 7232/7232 [==============================] - 2s 245us/step - loss: 0.3274 - acc: 0.0000e+00 - val_loss: 0.2656 - val_acc: 0.0000e+00
#
# Epoch 00337: val_loss did not improve from 0.22729
# Epoch 338/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3270 - acc: 0.0000e+00 - val_loss: 0.2516 - val_acc: 0.0000e+00
#
# Epoch 00338: val_loss did not improve from 0.22729
# Epoch 339/5000
# 7232/7232 [==============================] - 2s 268us/step - loss: 0.3283 - acc: 0.0000e+00 - val_loss: 0.2766 - val_acc: 0.0000e+00
#
# Epoch 00339: val_loss did not improve from 0.22729
# Epoch 340/5000
# 7232/7232 [==============================] - 2s 266us/step - loss: 0.3245 - acc: 0.0000e+00 - val_loss: 0.2542 - val_acc: 0.0000e+00
#
# Epoch 00340: val_loss did not improve from 0.22729
# Epoch 341/5000
# 7232/7232 [==============================] - 2s 250us/step - loss: 0.3308 - acc: 0.0000e+00 - val_loss: 0.2434 - val_acc: 0.0000e+00
#
# Epoch 00341: val_loss did not improve from 0.22729
# Epoch 342/5000
# 7232/7232 [==============================] - 2s 260us/step - loss: 0.3274 - acc: 0.0000e+00 - val_loss: 0.2899 - val_acc: 0.0000e+00
#
# Epoch 00342: val_loss did not improve from 0.22729
# Epoch 343/5000
# 7232/7232 [==============================] - 2s 227us/step - loss: 0.3264 - acc: 0.0000e+00 - val_loss: 0.2402 - val_acc: 0.0000e+00
#
# Epoch 00343: val_loss did not improve from 0.22729
# Epoch 344/5000
# 7232/7232 [==============================] - 2s 223us/step - loss: 0.3367 - acc: 0.0000e+00 - val_loss: 0.2498 - val_acc: 0.0000e+00
#
# Epoch 00344: val_loss did not improve from 0.22729
# Epoch 345/5000
# 7232/7232 [==============================] - 2s 225us/step - loss: 0.3302 - acc: 0.0000e+00 - val_loss: 0.2462 - val_acc: 0.0000e+00
#
# Epoch 00345: val_loss did not improve from 0.22729
# Epoch 346/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3215 - acc: 0.0000e+00 - val_loss: 0.2277 - val_acc: 0.0000e+00
#
# Epoch 00346: val_loss did not improve from 0.22729
# Epoch 347/5000
# 7232/7232 [==============================] - 2s 230us/step - loss: 0.3240 - acc: 0.0000e+00 - val_loss: 0.2500 - val_acc: 0.0000e+00
#
# Epoch 00347: val_loss did not improve from 0.22729
# Epoch 348/5000
# 7232/7232 [==============================] - 2s 273us/step - loss: 0.3285 - acc: 0.0000e+00 - val_loss: 0.2484 - val_acc: 0.0000e+00
#
# Epoch 00348: val_loss did not improve from 0.22729
# Epoch 349/5000
# 7232/7232 [==============================] - 2s 242us/step - loss: 0.3282 - acc: 0.0000e+00 - val_loss: 0.2468 - val_acc: 0.0000e+00
#
# Epoch 00349: val_loss did not improve from 0.22729
# Epoch 350/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.3259 - acc: 0.0000e+00 - val_loss: 0.2379 - val_acc: 0.0000e+00
# Epoch 00350: val_loss did not improve from 0.22729
# Epoch 351/5000
# 7232/7232 [==============================] - 2s 273us/step - loss: 0.3283 - acc: 0.0000e+00 - val_loss: 0.2390 - val_acc: 0.0000e+00
#
# Epoch 00351: val_loss did not improve from 0.22729
# Epoch 352/5000
# 7232/7232 [==============================] - 2s 268us/step - loss: 0.3342 - acc: 0.0000e+00 - val_loss: 0.3060 - val_acc: 0.0000e+00
#
# Epoch 00352: val_loss did not improve from 0.22729
# Epoch 353/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3263 - acc: 0.0000e+00 - val_loss: 0.2522 - val_acc: 0.0000e+00
#
# Epoch 00353: val_loss did not improve from 0.22729
# Epoch 354/5000
# 7232/7232 [==============================] - 2s 251us/step - loss: 0.3313 - acc: 0.0000e+00 - val_loss: 0.2721 - val_acc: 0.0000e+00
#
# Epoch 00354: val_loss did not improve from 0.22729
# Epoch 355/5000
# 7232/7232 [==============================] - 2s 263us/step - loss: 0.3255 - acc: 0.0000e+00 - val_loss: 0.2399 - val_acc: 0.0000e+00
#
# Epoch 00355: val_loss did not improve from 0.22729
# Epoch 356/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.3217 - acc: 0.0000e+00 - val_loss: 0.2290 - val_acc: 0.0000e+00
#
# Epoch 00356: val_loss did not improve from 0.22729
# Epoch 357/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.3174 - acc: 0.0000e+00 - val_loss: 0.2825 - val_acc: 0.0000e+00
#
# Epoch 00357: val_loss did not improve from 0.22729
# Epoch 358/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.3233 - acc: 0.0000e+00 - val_loss: 0.2904 - val_acc: 0.0000e+00
#
# Epoch 00358: val_loss did not improve from 0.22729
# Epoch 359/5000
# 7232/7232 [==============================] - 2s 251us/step - loss: 0.3180 - acc: 0.0000e+00 - val_loss: 0.2454 - val_acc: 0.0000e+00
#
# Epoch 00359: val_loss did not improve from 0.22729
# Epoch 360/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.3209 - acc: 0.0000e+00 - val_loss: 0.2548 - val_acc: 0.0000e+00
#
# Epoch 00360: val_loss did not improve from 0.22729

# %%
def plot_train(history):
    fig, loss_ax = plt.subplots(figsize=(10,10))

    loss_ax.plot(history.history['loss'], 'y', label='train loss')
    loss_ax.plot(history.history['val_loss'], 'r', label='val loss')


    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')

    loss_ax.legend(loc='upper right')

    plt.show()
    
def test_summary(model, weight_path):
    plot_train(model[1]) #history = moedl[1]
    model[0].load_weights(weight_path) #model = model[0]
    norm_y = g + et*np.arcsinh((y_test-ep)/l)
    loss, acc = model[0].evaluate(x_test, norm_y, batch_size=32)
    #loss, acc = model[0].evaluate(x_test, y_test, batch_size=32)
    print('----- Evaluation loss and metrics -----')
    print('Test loss - RMSE : {:.5f}'.format(loss))
    
    
def save_model(model, path, gu_name):
    model_json = model[0].to_json()
    
    file_name = path+gu_name+'_model.json'
    print(file_name)
    with open(file_name, "w") as json_file : 
        json_file.write(model_json)
        
def load_model(path, gu_name):
    from keras.models import model_from_json
    
    file_name = path+gu_name+'_model.json'
    
    json_file = open(file_name, "r")
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    
    return loaded_model

# %%
def get_best_weights_path():
    return CURR_PATH + sorted(os.listdir(CURR_PATH))[0]

# %%
FULL_PATH = get_best_weights_path()
print(FULL_PATH)
# Out:
# ./서초구_model_20181117/MLP_rmse/val_loss-0.220076.hdf5

# %%
save_model(model, CURR_PATH, gu_name)
# Out:
# ./서초구_model_20181117/MLP_rmse/서초구_model.json

# %%
test_summary(model,FULL_PATH)
# Out:
# 2009/2009 [==============================] - 0s 33us/step
# ----- Evaluation loss and metrics -----
# Test loss - RMSE : 0.22212

# %%
def prediction_plot(n_sample):
    from sklearn.metrics import r2_score

    randidx = np.random.choice(len(x_test), n_sample, replace=False)
  
    
    y_pred = model[0].predict(x_test).flatten()
    y_pred = johnson_inverse(y_pred, g, et, ep, l)
    
    _y_pred = y_pred[randidx]
    y_sample = y_test[randidx]

    fig, (ax0, ax1) = plt.subplots(1,2, figsize=(20,10))

    index = np.arange(n_sample)
    bar_width = 0.35

    opacity = 0.4
    error_config = {'ecolor': '0.3'}

    rects1 = ax0.bar(index, y_sample, bar_width, alpha=opacity, color='b',label='GT')
    rects2 = ax0.bar(index + bar_width, _y_pred, bar_width, alpha=opacity, color='r',label='Pred')

    ax0.set_xlabel('Data')
    ax0.set_ylabel('Price')
    ax0.set_title('Difference between GT/Pred - {}'.format(gu_name))
    ax0.legend()

    
    loss = rmsle_for_eval(y_test, y_pred)

    lower_bound = int(y_test.min())-10000
    higher_bound = int(y_test.max())+10000
    
    
    mape = mean_absolute_percentage_error(y_test, y_pred)
    
    
    ax1.scatter(y_test, y_pred, alpha=opacity, color='g')
    ax1.plot([lower_bound, higher_bound], [lower_bound, higher_bound], '--k')
    ax1.set_ylabel('Pred')
    ax1.set_xlabel('GT')
    ax1.set_title('Regression - {}'.format(gu_name))
    ax1.text(lower_bound+25000, lower_bound+15000, r'$R^2$={:.2f}, RMSLE={:.5f}'.format(r2_score(y_test, y_pred),loss))
    ax1.set_xlim([lower_bound, higher_bound])
    ax1.set_ylim([lower_bound, higher_bound])
    
    fig.tight_layout()
    plt.show()
    
    diff = abs(y_pred-y_test)
    print('Max difference : {:.2f} 만원'.format(diff.max()))
    print('Mean difference : {:.2f} 만원'.format(diff.mean()))
    print('--------')
    print('Avg Price of {}: {:.2f} 만원'.format(gu_name,y_test.mean()))
    print('--------')
    print('R2 Coefficient : {:.3f}'.format(r2_score(y_test, y_pred)))
    print('RMLSE loss : {:.4f}'.format(loss))
    print('MAPE : {:.4f}' .format(mape))
    return y_pred, diff

# %%
y_pred, diff = prediction_plot(10)
# Out:
# Max difference : 131988.42 만원
# Mean difference : 7795.46 만원
# --------
# Avg Price of 서초구: 101535.96 만원
# --------
# R2 Coefficient : 0.924
# RMLSE loss : 0.1037
# MAPE : 7.6653

# %%
def run_loaded_model(model, x_train, y_train, batch_size, max_epochs):
    model.compile(optimizer=adam,
                  loss=rmse,
                  metrics=['accuracy'])
    model.summary()
    
    checkloss = create_checkpoint(MODEL_NAME)
    
    history = model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=max_epochs,
                  validation_split = 0.1,
                  shuffle=True,
                  callbacks=[checkloss, early_stopping])
    
    return model, history

# %%
loaded_model = load_model(CURR_PATH, gu_name)
FULL_PATH = get_best_weights_path()
loaded_model.load_weights(FULL_PATH)

# %%
model = run_loaded_model(loaded_model, x_train, yt, 16, 5000)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 128)               14720
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                528
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16)                64
# _________________________________________________________________
# dense_11 (Dense)             (None, 8)                 136
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8)                 32
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 26,721
# Trainable params: 26,225
# Non-trainable params: 496
# _________________________________________________________________
# Train on 7232 samples, validate on 804 samples
# Epoch 1/5000
# 7232/7232 [==============================] - 4s 503us/step - loss: 0.3477 - acc: 0.0000e+00 - val_loss: 0.2689 - val_acc: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.26890, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.268895.hdf5
# Epoch 2/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3157 - acc: 0.0000e+00 - val_loss: 0.2394 - val_acc: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.26890 to 0.23945, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.239445.hdf5
# Epoch 3/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.3254 - acc: 0.0000e+00 - val_loss: 0.2496 - val_acc: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 0.23945
# Epoch 4/5000
# 7232/7232 [==============================] - 2s 258us/step - loss: 0.3247 - acc: 0.0000e+00 - val_loss: 0.2702 - val_acc: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 0.23945
# Epoch 5/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.3327 - acc: 0.0000e+00 - val_loss: 0.2408 - val_acc: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.23945
# Epoch 6/5000
# 7232/7232 [==============================] - 2s 272us/step - loss: 0.3275 - acc: 0.0000e+00 - val_loss: 0.2481 - val_acc: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 0.23945
# Epoch 7/5000
# 7232/7232 [==============================] - 2s 270us/step - loss: 0.3191 - acc: 0.0000e+00 - val_loss: 0.2979 - val_acc: 0.0000e+00
#
# Epoch 00007: val_loss did not improve from 0.23945
# Epoch 8/5000
# 7232/7232 [==============================] - 2s 270us/step - loss: 0.3176 - acc: 0.0000e+00 - val_loss: 0.2805 - val_acc: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 0.23945
# Epoch 9/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3233 - acc: 0.0000e+00 - val_loss: 0.2328 - val_acc: 0.0000e+00
#
# Epoch 00009: val_loss improved from 0.23945 to 0.23278, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.232780.hdf5
# Epoch 10/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.3211 - acc: 0.0000e+00 - val_loss: 0.2371 - val_acc: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 0.23278
# Epoch 11/5000
# 7232/7232 [==============================] - 2s 247us/step - loss: 0.3231 - acc: 0.0000e+00 - val_loss: 0.2375 - val_acc: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 0.23278
# Epoch 12/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.3215 - acc: 0.0000e+00 - val_loss: 0.2314 - val_acc: 0.0000e+00
#
# Epoch 00012: val_loss improved from 0.23278 to 0.23141, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.231411.hdf5
# Epoch 13/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.3238 - acc: 0.0000e+00 - val_loss: 0.2528 - val_acc: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 0.23141
# Epoch 14/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.3197 - acc: 0.0000e+00 - val_loss: 0.2347 - val_acc: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 0.23141
# Epoch 15/5000
# 7232/7232 [==============================] - 2s 247us/step - loss: 0.3208 - acc: 0.0000e+00 - val_loss: 0.2672 - val_acc: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 0.23141
# Epoch 16/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3262 - acc: 0.0000e+00 - val_loss: 0.2561 - val_acc: 0.0000e+00
#
# Epoch 00016: val_loss did not improve from 0.23141
# Epoch 17/5000
# 7232/7232 [==============================] - 2s 255us/step - loss: 0.3123 - acc: 0.0000e+00 - val_loss: 0.2470 - val_acc: 0.0000e+00
#
# Epoch 00017: val_loss did not improve from 0.23141
# Epoch 18/5000
# 7232/7232 [==============================] - 2s 235us/step - loss: 0.3191 - acc: 0.0000e+00 - val_loss: 0.2349 - val_acc: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 0.23141
# Epoch 19/5000
# 7232/7232 [==============================] - 2s 236us/step - loss: 0.3155 - acc: 0.0000e+00 - val_loss: 0.2283 - val_acc: 0.0000e+00
#
# Epoch 00019: val_loss improved from 0.23141 to 0.22826, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.228258.hdf5
# Epoch 20/5000
# 7232/7232 [==============================] - 2s 250us/step - loss: 0.3179 - acc: 0.0000e+00 - val_loss: 0.2308 - val_acc: 0.0000e+00
#
# Epoch 00020: val_loss did not improve from 0.22826
# Epoch 21/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.3218 - acc: 0.0000e+00 - val_loss: 0.2435 - val_acc: 0.0000e+00
#
# Epoch 00021: val_loss did not improve from 0.22826
# Epoch 22/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.3135 - acc: 0.0000e+00 - val_loss: 0.2473 - val_acc: 0.0000e+00
#
# Epoch 00022: val_loss did not improve from 0.22826
# Epoch 23/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3210 - acc: 0.0000e+00 - val_loss: 0.2409 - val_acc: 0.0000e+00
#
# Epoch 00023: val_loss did not improve from 0.22826
# Epoch 24/5000
# 7232/7232 [==============================] - 2s 267us/step - loss: 0.3131 - acc: 0.0000e+00 - val_loss: 0.2664 - val_acc: 0.0000e+00
#
# Epoch 00024: val_loss did not improve from 0.22826
# Epoch 25/5000
# 7232/7232 [==============================] - 2s 264us/step - loss: 0.3142 - acc: 0.0000e+00 - val_loss: 0.2679 - val_acc: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 0.22826
# Epoch 26/5000
# 7232/7232 [==============================] - 2s 242us/step - loss: 0.3155 - acc: 0.0000e+00 - val_loss: 0.2234 - val_acc: 0.0000e+00
#
# Epoch 00026: val_loss improved from 0.22826 to 0.22336, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.223357.hdf5
# Epoch 27/5000
# 7232/7232 [==============================] - 2s 281us/step - loss: 0.3319 - acc: 0.0000e+00 - val_loss: 0.2368 - val_acc: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 0.22336
# Epoch 28/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3174 - acc: 0.0000e+00 - val_loss: 0.2190 - val_acc: 0.0000e+00
#
# Epoch 00028: val_loss improved from 0.22336 to 0.21896, saving model to ./서초구_model_20181117/MLP_rmse/val_loss-0.218960.hdf5
# Epoch 29/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3199 - acc: 0.0000e+00 - val_loss: 0.2382 - val_acc: 0.0000e+00
#
# Epoch 00029: val_loss did not improve from 0.21896
# Epoch 30/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3019 - acc: 0.0000e+00 - val_loss: 0.2850 - val_acc: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 0.21896
# Epoch 31/5000
# 7232/7232 [==============================] - 2s 240us/step - loss: 0.3114 - acc: 0.0000e+00 - val_loss: 0.2353 - val_acc: 0.0000e+00
#
# Epoch 00031: val_loss did not improve from 0.21896
# Epoch 32/5000
# 7232/7232 [==============================] - 2s 243us/step - loss: 0.3273 - acc: 0.0000e+00 - val_loss: 0.2649 - val_acc: 0.0000e+00
#
# Epoch 00032: val_loss did not improve from 0.21896
# Epoch 33/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.3168 - acc: 0.0000e+00 - val_loss: 0.2339 - val_acc: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 0.21896
# Epoch 34/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.3285 - acc: 0.0000e+00 - val_loss: 0.2334 - val_acc: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 0.21896
# Epoch 35/5000
# 7232/7232 [==============================] - 2s 239us/step - loss: 0.3169 - acc: 0.0000e+00 - val_loss: 0.2709 - val_acc: 0.0000e+00
#
# Epoch 00035: val_loss did not improve from 0.21896
# Epoch 36/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.3144 - acc: 0.0000e+00 - val_loss: 0.2301 - val_acc: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 0.21896
# Epoch 37/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.3101 - acc: 0.0000e+00 - val_loss: 0.2505 - val_acc: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 0.21896
# Epoch 38/5000
# 7232/7232 [==============================] - 2s 245us/step - loss: 0.3105 - acc: 0.0000e+00 - val_loss: 0.2509 - val_acc: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 0.21896
# Epoch 39/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3101 - acc: 0.0000e+00 - val_loss: 0.2549 - val_acc: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 0.21896
# Epoch 40/5000
# 7232/7232 [==============================] - 2s 244us/step - loss: 0.3215 - acc: 0.0000e+00 - val_loss: 0.2315 - val_acc: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 0.21896
# Epoch 41/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.3080 - acc: 0.0000e+00 - val_loss: 0.2391 - val_acc: 0.0000e+00
#
# Epoch 00041: val_loss did not improve from 0.21896
# Epoch 42/5000
# 7232/7232 [==============================] - 2s 248us/step - loss: 0.3293 - acc: 0.0000e+00 - val_loss: 0.2329 - val_acc: 0.0000e+00
#
# Epoch 00042: val_loss did not improve from 0.21896
# Epoch 43/5000
# 7232/7232 [==============================] - 2s 252us/step - loss: 0.3127 - acc: 0.0000e+00 - val_loss: 0.2304 - val_acc: 0.0000e+00
#
# Epoch 00043: val_loss did not improve from 0.21896
# Epoch 44/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3181 - acc: 0.0000e+00 - val_loss: 0.2430 - val_acc: 0.0000e+00
#
# Epoch 00044: val_loss did not improve from 0.21896
# Epoch 45/5000
# 7232/7232 [==============================] - 2s 245us/step - loss: 0.3203 - acc: 0.0000e+00 - val_loss: 0.2343 - val_acc: 0.0000e+00
#
# Epoch 00045: val_loss did not improve from 0.21896
# Epoch 46/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.3128 - acc: 0.0000e+00 - val_loss: 0.2414 - val_acc: 0.0000e+00
#
# Epoch 00046: val_loss did not improve from 0.21896
# Epoch 47/5000
# 7232/7232 [==============================] - 2s 249us/step - loss: 0.3129 - acc: 0.0000e+00 - val_loss: 0.2676 - val_acc: 0.0000e+00
#
# Epoch 00047: val_loss did not improve from 0.21896
# Epoch 48/5000
# 7232/7232 [==============================] - 2s 254us/step - loss: 0.3144 - acc: 0.0000e+00 - val_loss: 0.2324 - val_acc: 0.0000e+00
#
# Epoch 00048: val_loss did not improve from 0.21896
# Epoch 49/5000
# 7232/7232 [==============================] - 2s 245us/step - loss: 0.3170 - acc: 0.0000e+00 - val_loss: 0.2446 - val_acc: 0.0000e+00
#
# Epoch 00049: val_loss did not improve from 0.21896
# Epoch 50/5000
# 7232/7232 [==============================] - 2s 241us/step - loss: 0.3233 - acc: 0.0000e+00 - val_loss: 0.2384 - val_acc: 0.0000e+00
#
# Epoch 00050: val_loss did not improve from 0.21896
# Epoch 51/5000
# 7232/7232 [==============================] - 2s 311us/step - loss: 0.3230 - acc: 0.0000e+00 - val_loss: 0.2528 - val_acc: 0.0000e+00
#
# Epoch 00051: val_loss did not improve from 0.21896
# Epoch 52/5000
# 7232/7232 [==============================] - 2s 285us/step - loss: 0.3217 - acc: 0.0000e+00 - val_loss: 0.2661 - val_acc: 0.0000e+00
#
# Epoch 00052: val_loss did not improve from 0.21896
# Epoch 53/5000
# 7232/7232 [==============================] - 2s 256us/step - loss: 0.3256 - acc: 0.0000e+00 - val_loss: 0.2409 - val_acc: 0.0000e+00
#
# Epoch 00053: val_loss did not improve from 0.21896
# Epoch 54/5000
# 7232/7232 [==============================] - 2s 281us/step - loss: 0.3126 - acc: 0.0000e+00 - val_loss: 0.2303 - val_acc: 0.0000e+00
#
# Epoch 00054: val_loss did not improve from 0.21896
# Epoch 55/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.3163 - acc: 0.0000e+00 - val_loss: 0.2338 - val_acc: 0.0000e+00
#
# Epoch 00055: val_loss did not improve from 0.21896
# Epoch 56/5000
# 7232/7232 [==============================] - 2s 257us/step - loss: 0.3218 - acc: 0.0000e+00 - val_loss: 0.2516 - val_acc: 0.0000e+00
#
# Epoch 00056: val_loss did not improve from 0.21896
# Epoch 57/5000
# 7232/7232 [==============================] - 2s 236us/step - loss: 0.3078 - acc: 0.0000e+00 - val_loss: 0.2502 - val_acc: 0.0000e+00
#
# Epoch 00057: val_loss did not improve from 0.21896
# Epoch 58/5000
# 7232/7232 [==============================] - 2s 286us/step - loss: 0.3294 - acc: 0.0000e+00 - val_loss: 0.2767 - val_acc: 0.0000e+00
#
# Epoch 00058: val_loss did not improve from 0.21896
# Epoch 59/5000
# 7232/7232 [==============================] - 2s 271us/step - loss: 0.3152 - acc: 0.0000e+00 - val_loss: 0.2872 - val_acc: 0.0000e+00
#
# Epoch 00059: val_loss did not improve from 0.21896
# Epoch 60/5000
# 7232/7232 [==============================] - 2s 265us/step - loss: 0.3199 - acc: 0.0000e+00 - val_loss: 0.2392 - val_acc: 0.0000e+00
#
# Epoch 00060: val_loss did not improve from 0.21896
# Epoch 61/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.3128 - acc: 0.0000e+00 - val_loss: 0.2362 - val_acc: 0.0000e+00
#
# Epoch 00061: val_loss did not improve from 0.21896
# Epoch 62/5000
# 7232/7232 [==============================] - 2s 246us/step - loss: 0.3175 - acc: 0.0000e+00 - val_loss: 0.2416 - val_acc: 0.0000e+00
#
# Epoch 00062: val_loss did not improve from 0.21896
# Epoch 63/5000
# 7232/7232 [==============================] - 2s 265us/step - loss: 0.3214 - acc: 0.0000e+00 - val_loss: 0.2251 - val_acc: 0.0000e+00
#
# Epoch 00063: val_loss did not improve from 0.21896
# Epoch 64/5000
# 7232/7232 [==============================] - 2s 270us/step - loss: 0.3115 - acc: 0.0000e+00 - val_loss: 0.2875 - val_acc: 0.0000e+00
#
# Epoch 00064: val_loss did not improve from 0.21896
# Epoch 65/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.3141 - acc: 0.0000e+00 - val_loss: 0.2324 - val_acc: 0.0000e+00
#
# Epoch 00065: val_loss did not improve from 0.21896
# Epoch 66/5000
# 7232/7232 [==============================] - 2s 250us/step - loss: 0.3276 - acc: 0.0000e+00 - val_loss: 0.2398 - val_acc: 0.0000e+00
#
# Epoch 00066: val_loss did not improve from 0.21896
# Epoch 67/5000
# 7232/7232 [==============================] - 2s 264us/step - loss: 0.3172 - acc: 0.0000e+00 - val_loss: 0.2283 - val_acc: 0.0000e+00
#
# Epoch 00067: val_loss did not improve from 0.21896
# Epoch 68/5000
# 7232/7232 [==============================] - 2s 251us/step - loss: 0.3189 - acc: 0.0000e+00 - val_loss: 0.2328 - val_acc: 0.0000e+00
#
# Epoch 00068: val_loss did not improve from 0.21896
# Epoch 69/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.3164 - acc: 0.0000e+00 - val_loss: 0.2468 - val_acc: 0.0000e+00
#
# Epoch 00069: val_loss did not improve from 0.21896
# Epoch 70/5000
# 7232/7232 [==============================] - 2s 250us/step - loss: 0.3139 - acc: 0.0000e+00 - val_loss: 0.2307 - val_acc: 0.0000e+00
#
# Epoch 00070: val_loss did not improve from 0.21896
# Epoch 71/5000
# 7232/7232 [==============================] - 2s 266us/step - loss: 0.3237 - acc: 0.0000e+00 - val_loss: 0.2542 - val_acc: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 0.21896
# Epoch 72/5000
# 7232/7232 [==============================] - 2s 269us/step - loss: 0.3200 - acc: 0.0000e+00 - val_loss: 0.3406 - val_acc: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 0.21896
# Epoch 73/5000
# 7232/7232 [==============================] - 2s 261us/step - loss: 0.3166 - acc: 0.0000e+00 - val_loss: 0.2273 - val_acc: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 0.21896
# Epoch 74/5000
# 7232/7232 [==============================] - 2s 259us/step - loss: 0.3218 - acc: 0.0000e+00 - val_loss: 0.2254 - val_acc: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 0.21896
# Epoch 75/5000
# 7232/7232 [==============================] - 2s 270us/step - loss: 0.3151 - acc: 0.0000e+00 - val_loss: 0.2375 - val_acc: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 0.21896
# Epoch 76/5000
# 7232/7232 [==============================] - 2s 265us/step - loss: 0.3230 - acc: 0.0000e+00 - val_loss: 0.2251 - val_acc: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 0.21896
# Epoch 77/5000
# 7232/7232 [==============================] - 2s 277us/step - loss: 0.3283 - acc: 0.0000e+00 - val_loss: 0.2596 - val_acc: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 0.21896
# Epoch 78/5000
# 7232/7232 [==============================] - 2s 260us/step - loss: 0.3071 - acc: 0.0000e+00 - val_loss: 0.2303 - val_acc: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 0.21896

# %%
test_summary(model,FULL_PATH)
# Out:
# 2009/2009 [==============================] - 0s 53us/step
# ----- Evaluation loss and metrics -----
# Test loss - RMSE : 0.22035

# %%
y_pred, diff = prediction_plot(10)
# Out:
# Max difference : 127477.34 만원
# Mean difference : 7833.14 만원
# --------
# Avg Price of 서초구: 101535.96 만원
# --------
# R2 Coefficient : 0.919
# RMLSE loss : 0.1043
# MAPE : 7.5310
