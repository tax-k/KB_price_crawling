# %%
import pandas as pd
import pickle
import os

# %%
print(os.getcwd())
# Out:
# /Users/tax_k/Projects/AI-DL/KB

# %% [markdown]
# ### pickle -> dictionary -> pandas frame

# %%
with open('./Dataset/Price/deal_whole_data.txt', 'rb') as f:
    data = pickle.load(f)
    
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print((data[0]))
# Out:
# {'거래금액': '29,500', '건축년도': '1983', '년': '2006', '법정동': '당주동', '아파트': '세종', '월': '1', '일': '11~20', '전용면적': '93.4', '지번': '100', '지역코드': '11110', '층': '6'}

# %%
whole_data_frame = pd.DataFrame(data)
whole_data_frame.columns = ['deal_price', 'build_y', 'deal_year', 'law_code', 'apt_name',
                            'deal_month','deal_day', 'area', 'ji_bun', 'loc_code', 'current_floor']

# %%
whole_data_frame
# Out:
#         deal_price build_y deal_year law_code       apt_name deal_month  \
# 0           29,500    1983      2006      당주동             세종          1
# 1           15,741    1998      2006      익선동         운현신화타워          1
# 2           23,198    1998      2006      익선동         운현신화타워          1
# 3           23,198    1998      2006      익선동         운현신화타워          1
# 4           21,535    1998      2006      익선동         운현신화타워          1
# 5           21,500    1999      2006     명륜2가            아남3          1
# 6           20,000    1999      2006     명륜2가            아남3          1
# 7           16,800    1992      2006      창신동          창신쌍용1          1
# 8           16,500    1993      2006      창신동          창신쌍용2          1
# 9           28,000    1993      2006      창신동          창신쌍용2          1
# 10          19,200    1993      2006      창신동          창신쌍용2          1
# 11          15,950    1992      2006      창신동          창신쌍용1          1
# 12          10,500    1998      2006      숭인동          하림빌라트          1
# 13          17,500    1996      2006      평창동          일성빌라트          1
# 14          27,000    1996      2006      평창동          일성빌라트          1
# 15          33,500    1996      2006      평창동          일성빌라트          1
# 16          16,500    1998      2006      신영동          대아파크빌          1
# 17          16,000    1998      2006      신영동          대아파크빌          1
# 18          42,500    2000      2006      무악동             현대          1
# 19          41,500    2000      2006      무악동             현대          1
# 20          26,700    2000      2006      무악동             현대          1
# 21          24,000    2000      2006      무악동             현대          1
# 22          56,500    2000      2006      무악동             현대          1
# 23          52,000    2000      2006      무악동             현대          1
# 24           9,000    1968      2006    인현동2가           신성상가          1
# 25          15,000    1999      2006      예장동             삼익          1
# 26          22,000    2002      2006      신당동           남산타운          1
# 27          52,000    2002      2006      신당동           남산타운          1
# 28          60,015    2005      2006      신당동        남산정은스카이          1
# 29          62,500    2005      2006      신당동         신당푸르지오          1
# ...            ...     ...       ...      ...            ...        ...
# 1013420     43,000    2004      2018       길동         예전이룸1차         10
# 1013421     13,870    2013      2018       길동     청광플러스원큐브2차         10
# 1013422     44,000    2004      2018       길동          장인이즈빌         10
# 1013423     89,000    2003      2018       길동         강동LG자이         10
# 1013424     55,000    2004      2018       길동            예다움         10
# 1013425     12,000    2013      2018       길동       강동큐브(2차)         10
# 1013426     12,600    2014      2018       길동         강동렘브란트         10
# 1013424     1~10   100.36   347-27    11740            10
# 1013425     1~10    14.32   415-13    11740             9
# 1013426    11~20    15.86    457-1    11740            10
# 1013427    11~20    84.95   361-18    11740             4
# 1013428    11~20    82.42      472    11740            13
# 1013429    11~20     56.7    414-6    11740             3
# 1013430    11~20    15.86    457-1    11740            12
# 1013431     1~10    84.94       89    11740            11
# 1013432     1~10    83.97    435-8    11740             2
# 1013433     1~10   106.79      611    11740             5
# 1013434     1~10     84.9      630    11740             5
# 1013435    11~20    84.91   488-10    11740             2
# 1013436    11~20   103.01    414-2    11740            21
# 1013437     1~10    84.95    410-2    11740             3
# 1013438     1~10       63    463-1    11740             5
# 1013439     1~10    77.34   111-64    11740             3
# 1013440    11~20    67.84    439-2    11740             3
# 1013441    11~20    59.63   410-15    11740             2
# 1013442    11~20    59.86   448-14    11740             9
# 1013443     1~10    84.97      571    11740             9
# 1013444    11~20   114.85    293-8    11740             3
# 1013445    21~31    84.99   317-31    11740             2
# 1013446     1~10    84.83      695    11740             6
# 1013447     1~10   114.81      695    11740            10
# 1013448     1~10    84.53      695    11740             7
# 1013449    11~20    84.74      684    11740            13
#
# [1013450 rows x 11 columns]

# %% [markdown]
# ### pandas dataframe -> pickle save

# %%
with open('w_pandas_data_frame.txt', 'wb') as f:
    pickle.dump(whole_data_frame, f)

# %% [markdown]
# ### pickle -> pandas dataframe load

# %%
with open('w_pandas_data_frame.txt', 'rb') as f:
    t_data = pickle.load(f)

# %%
t_data
# Out:
#         deal_price build_y deal_year law_code       apt_name deal_month  \
# 0           29,500    1983      2006      당주동             세종          1
# 1           15,741    1998      2006      익선동         운현신화타워          1
# 2           23,198    1998      2006      익선동         운현신화타워          1
# 3           23,198    1998      2006      익선동         운현신화타워          1
# 4           21,535    1998      2006      익선동         운현신화타워          1
# 5           21,500    1999      2006     명륜2가            아남3          1
# 6           20,000    1999      2006     명륜2가            아남3          1
# 7           16,800    1992      2006      창신동          창신쌍용1          1
# 8           16,500    1993      2006      창신동          창신쌍용2          1
# 9           28,000    1993      2006      창신동          창신쌍용2          1
# 10          19,200    1993      2006      창신동          창신쌍용2          1
# 11          15,950    1992      2006      창신동          창신쌍용1          1
# 12          10,500    1998      2006      숭인동          하림빌라트          1
# 13          17,500    1996      2006      평창동          일성빌라트          1
# 14          27,000    1996      2006      평창동          일성빌라트          1
# 15          33,500    1996      2006      평창동          일성빌라트          1
# 16          16,500    1998      2006      신영동          대아파크빌          1
# 17          16,000    1998      2006      신영동          대아파크빌          1
# 18          42,500    2000      2006      무악동             현대          1
# 19          41,500    2000      2006      무악동             현대          1
# 20          26,700    2000      2006      무악동             현대          1
# 21          24,000    2000      2006      무악동             현대          1
# 22          56,500    2000      2006      무악동             현대          1
# 23          52,000    2000      2006      무악동             현대          1
# 16         11~20    59.22      254    11110            13
# 17         11~20    59.22      254    11110             9
# 18          1~10    84.92       82    11110            20
# 19         11~20    84.92       82    11110             9
# 20         11~20       60       82    11110            13
# 21         21~31       60       82    11110             3
# 22         21~31    114.9       82    11110             9
# 23         21~31    114.9       82    11110            10
# 24         21~31    42.31   192-30    11140             7
# 25         11~20    59.58        9    11140             4
# 26          1~10    59.94      844    11140             1
# 27          1~10    84.88      844    11140            15
# 28          1~10  143.049  366-126    11140             2
# 29          1~10    145.1      850    11140             2
# ...          ...      ...      ...      ...           ...
# 1013420     1~10    77.15    242-6    11740             1
# 1013421     1~10   14.495      457    11740             8
# 1013422     1~10    72.77      475    11740             6
# 1013423     1~10    84.88      474    11740             3
# 1013424     1~10   100.36   347-27    11740            10
# 1013425     1~10    14.32   415-13    11740             9
# 1013426    11~20    15.86    457-1    11740            10
# 1013427    11~20    84.95   361-18    11740             4
# 1013428    11~20    82.42      472    11740            13
# 1013429    11~20     56.7    414-6    11740             3
# 1013430    11~20    15.86    457-1    11740            12
# 1013431     1~10    84.94       89    11740            11
# 1013432     1~10    83.97    435-8    11740             2
# 1013433     1~10   106.79      611    11740             5
# 1013434     1~10     84.9      630    11740             5
# 1013435    11~20    84.91   488-10    11740             2
# 1013436    11~20   103.01    414-2    11740            21
# 1013437     1~10    84.95    410-2    11740             3
# 1013438     1~10       63    463-1    11740             5
# 1013439     1~10    77.34   111-64    11740             3
# 1013440    11~20    67.84    439-2    11740             3
# 1013441    11~20    59.63   410-15    11740             2
# 1013442    11~20    59.86   448-14    11740             9
# 1013443     1~10    84.97      571    11740             9
# 1013444    11~20   114.85    293-8    11740             3
# 1013445    21~31    84.99   317-31    11740             2
# 1013446     1~10    84.83      695    11740             6
# 1013447     1~10   114.81      695    11740            10
# 1013448     1~10    84.53      695    11740             7
# 1013449    11~20    84.74      684    11740            13
#
# [1013450 rows x 11 columns]

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
# %load executionTimeCheck.py
from time import time, strftime, localtime
from datetime import timedelta


class checkExecution:
    def __init__(self):
        self.startTime = ''

    def secondsToStr(self, elapsed=None):
        if elapsed is None:
            return strftime("%Y-%m-%d %H:%M:%S", localtime())
        else:
            return str(timedelta(seconds=elapsed))

    def log(self, s, elapsed=None):
        line = "=" * 40
        print()
        print(line)
        print(self.secondsToStr(), '-', s)
        if elapsed:
            print("Elapsed time:", elapsed)
        print(line)
        print()

    def startLog(self):
        self.startTime = time()
        self.log("Start Program")

    def endLog(self):
        end = time()
        elapsed = end - self.startTime
        self.log("End Program", self.secondsToStr(elapsed))

# %% [markdown]
# ### TestCode

# %%
L = [1, 2, 3]

# %%
L.insert?
# Out:
# Object `L.insert` not found.

# %%
L?
