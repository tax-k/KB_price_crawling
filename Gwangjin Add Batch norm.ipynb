# %%
 # %matplotlib inline
import pickle
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
from sklearn.model_selection import KFold
from IPython.display import HTML, display
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('./KB_mxxg/comb_pre_to_cat2.csv')

# %%
data = data.drop(['Unnamed: 0', 'Unnamed: 0.1'], 1)

# %%
def gucode(path):
    gucode = {}
    df = pd.read_csv(path, sep=':',names=['name', 'code'])
    for i,code in enumerate(df['code']):
        gucode[code] = df['name'][i]
    return gucode

gucode = gucode('./KB_mxxg/gucode.txt')

# %%
gucode
# Out:
# {11110: '종로구',
#  11140: '중구',
#  11170: '용산구',
#  11200: '성동구',
#  11215: '광진구',
#  11230: '동대문구',
#  11260: '중랑구',
#  11290: '성북구',
#  11305: '강북구',
#  11320: '도봉구',
#  11350: '노원구',
#  11380: '은평구',
#  11410: '서대문구',
#  11440: '마포구',
#  11470: '양천구',
#  11500: '강서구',
#  11530: '구로구',
#  11545: '금천구',
#  11560: '영등포구',
#  11590: '동작구',
#  11620: '관악구',
#  11650: '서초구',
#  11680: '강남구',
#  11710: '송파구',
#  11740: '강동구'}

# %%
def idx_custom(custom_data, year_range, year_idx, code):
    custom_data = custom_data.iloc[year_idx]
    custom_data = custom_data.reset_index(drop=True)
    print('Only {} data in {} year(s)'.format(gucode[code], year_range))
    print('Data size : {}'.format(len(custom_data)))
    
    return custom_data, gucode[code]

# %%
def custom_data(code):
    #input gu-code & year
    min_year = int(input('start year: '))
    max_year = int(input('end year: '))
    
    gu_idx = np.where(data[str(code)]==1)[0]
    
    custom_data = data.iloc[gu_idx] #원하는 구만 잘라냄
    custom_data = custom_data.reset_index(drop=True) #index 0부터 다시 초기화
    year_range = []
    
    if max_year >= min_year:
        
        for year in range(min_year, max_year + 1):
            year_range.append(year)
            
        tmp = [np.where(custom_data['d_yr'] == year)[0] for year in year_range]
        year_idx = np.concatenate(tmp)

        return idx_custom(custom_data, year_range, year_idx, code)
        
    elif max_year == min_year:
        year_range.append(min_year)
        year_idx = np.where(custom_data['d_yr'] == year_range[0])[0]
        
        return idx_custom(custom_data,year_range, year_idx, code)
    else:
        return 0

# %%
gwangjin, gu_name = custom_data(11215)
# Out:
# start year: 2010
# end year: 2018
# Only 광진구 data in [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018] year(s)
# Data size : 8198

# %%
def datasplit(data):
    data = data.sample(frac=1).reset_index(drop=True) #shuffle
    data = data.reset_index(drop=True) #index 초기화
    
    train_len = int(len(data)*0.8)
    
    train = data.loc[:train_len-1]
    train = train.sample(frac=1).reset_index(drop=True) #shuffle
    train = train.reset_index(drop=True) #index 초기화
    
    test = data.loc[train_len:]
    test = test.sample(frac=1).reset_index(drop=True) #shuffle
    test = test.reset_index(drop=True)
    
    print ('{} data is splitted into {} train / {} test data'.format(len(data),len(train), len(test)))
    return train, test

# %%
train, test = datasplit(gwangjin)
# Out:
# 8198 data is splitted into 6558 train / 1640 test data

# %%
def make_x_y(data):
    x = data.drop(['price', 'avg_price'],1)
    y = data['price'].values
    
    print('Done')
    return x,y

# %%
x_train, y_train = make_x_y(train)
x_test, y_test = make_x_y(test)
# Out:
# Done
# Done

# %%
def johnson(y):
    gamma, eta, epsilon, lbda = stats.johnsonsu.fit(y)
    yt = gamma + eta*np.arcsinh((y-epsilon)/lbda)
    return yt, gamma, eta, epsilon, lbda

def johnson_inverse(y, gamma, eta, epsilon, lbda):
    return lbda*np.sinh((y-gamma)/eta) + epsilon

yt, g, et, ep, l = johnson(y_train) #정규분포화
yt2 = johnson_inverse(yt, g, et, ep, l) #inverse 정규분포화
plt.figure(1)
sns.distplot(yt)
plt.figure(2)
sns.distplot(yt2)
# Out:
# /Users/tax_k/anaconda3/envs/DL/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import regularizers,optimizers,losses
from keras.layers.normalization import BatchNormalization

import datetime
import os
# Out:
# Using TensorFlow backend.

# %%
# path where all models are saved
now = datetime.datetime.now()
ymd = (str(now.year) + str(now.month) + str(now.day))

BASE_PATH = './'+gu_name+'_model_'+ymd+'/'
MODEL_NAME = 'MLP_rmse'
CURR_PATH = BASE_PATH + MODEL_NAME + "/"

if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

def create_checkpoint(model_name):
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, 'val_loss-{val_loss:.6f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               patience=50)

# %%
def custom_loss(y_true,y_pred):
    import keras.backend as K
    #loss = K.mean((y_true - y_pred)**2, axis=-1)
    loss = K.mean(K.abs(y_pred - y_true), axis=-1)
    '''
    def _logcosh(x):
        return x + K.softplus(-2. * x) - K.log(2.)
    loss= K.mean(_logcosh(y_pred - y_true), axis=-1)
    '''
    return loss

# %%
def rmse(y_true,y_pred):
    import keras.backend as K
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
def rmsle(y_true, y_pred):
    import keras.backend as K
    first_log = K.log(y_pred + 1)
    second_log = K.log(y_true + 1)
    loss= K.sqrt(K.mean(K.square(first_log - second_log)))
    return loss

# %%
def rmsle_for_eval(y_true, y_pred):
    return np.sqrt(np.mean(np.square(np.log(y_pred+1)-np.log(y_true+1))))

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
adam = optimizers.Adam(lr=0.0009, decay=0.0001)

# %%
def Model(x_train, y_train, batch_size, max_epochs):
    model = Sequential()
    model.add(Dense(128, activation='relu', input_dim=114))
    model.add(BatchNormalization())
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(16, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(8, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer=adam,
                  loss=rmse,
                  metrics=['accuracy'])

    model.summary()
    
    checkloss = create_checkpoint(MODEL_NAME)
    
    # Validation_split으로 validation 얼마나 해줄건지 정해중!
    history = model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=max_epochs,
                  validation_split = 0.1,
                  shuffle=True,
                  callbacks=[checkloss, early_stopping])
    
    return model, history

# %%
model = Model(x_train, yt, 16, 5000)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 128)               14720
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                528
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16)                64
# _________________________________________________________________
# dense_11 (Dense)             (None, 8)                 136
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8)                 32
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 26,721
# Trainable params: 26,225
# Non-trainable params: 496
# _________________________________________________________________
# Train on 5902 samples, validate on 656 samples
# Epoch 1/5000
# 5902/5902 [==============================] - 3s 505us/step - loss: 0.8693 - acc: 0.0000e+00 - val_loss: 1.0769 - val_acc: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 1.07687, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-1.076871.hdf5
# Epoch 2/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.7543 - acc: 0.0000e+00 - val_loss: 1.0296 - val_acc: 0.0000e+00
#
# Epoch 00002: val_loss improved from 1.07687 to 1.02959, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-1.029589.hdf5
# Epoch 3/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.6803 - acc: 0.0000e+00 - val_loss: 0.7246 - val_acc: 0.0000e+00
#
# Epoch 00003: val_loss improved from 1.02959 to 0.72455, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.724553.hdf5
# Epoch 4/5000
# 5902/5902 [==============================] - 1s 231us/step - loss: 0.6400 - acc: 0.0000e+00 - val_loss: 0.7063 - val_acc: 0.0000e+00
#
# Epoch 00004: val_loss improved from 0.72455 to 0.70632, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.706316.hdf5
# Epoch 5/5000
# 5902/5902 [==============================] - 1s 237us/step - loss: 0.6169 - acc: 0.0000e+00 - val_loss: 0.8555 - val_acc: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.70632
# Epoch 6/5000
# 5902/5902 [==============================] - 1s 235us/step - loss: 0.5915 - acc: 0.0000e+00 - val_loss: 0.6511 - val_acc: 0.0000e+00
#
# Epoch 00006: val_loss improved from 0.70632 to 0.65106, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.651061.hdf5
# Epoch 7/5000
# 5902/5902 [==============================] - 1s 218us/step - loss: 0.5819 - acc: 0.0000e+00 - val_loss: 0.6883 - val_acc: 0.0000e+00
#
# Epoch 00007: val_loss did not improve from 0.65106
# Epoch 8/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.5704 - acc: 0.0000e+00 - val_loss: 0.7972 - val_acc: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 0.65106
# Epoch 9/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.5607 - acc: 0.0000e+00 - val_loss: 0.7287 - val_acc: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 0.65106
# Epoch 10/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.5615 - acc: 0.0000e+00 - val_loss: 1.1190 - val_acc: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 0.65106
# Epoch 11/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.5608 - acc: 0.0000e+00 - val_loss: 0.8470 - val_acc: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 0.65106
# Epoch 12/5000
# 5902/5902 [==============================] - 1s 229us/step - loss: 0.5479 - acc: 0.0000e+00 - val_loss: 0.6974 - val_acc: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 0.65106
# Epoch 13/5000
# 5902/5902 [==============================] - 1s 230us/step - loss: 0.5287 - acc: 0.0000e+00 - val_loss: 1.5789 - val_acc: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 0.65106
# Epoch 14/5000
# 5902/5902 [==============================] - 1s 221us/step - loss: 0.5253 - acc: 0.0000e+00 - val_loss: 1.6633 - val_acc: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 0.65106
# Epoch 15/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.5024 - acc: 0.0000e+00 - val_loss: 0.8197 - val_acc: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 0.65106
# Epoch 16/5000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.5075 - acc: 0.0000e+00 - val_loss: 0.8429 - val_acc: 0.0000e+00
#
# Epoch 00016: val_loss did not improve from 0.65106
# Epoch 17/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.5005 - acc: 0.0000e+00 - val_loss: 1.0921 - val_acc: 0.0000e+00
#
# Epoch 00017: val_loss did not improve from 0.65106
# Epoch 18/5000
# 5902/5902 [==============================] - 1s 221us/step - loss: 0.4904 - acc: 0.0000e+00 - val_loss: 1.0764 - val_acc: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 0.65106
# Epoch 19/5000
# 5902/5902 [==============================] - 1s 214us/step - loss: 0.4788 - acc: 0.0000e+00 - val_loss: 0.9067 - val_acc: 0.0000e+00
#
# Epoch 00019: val_loss did not improve from 0.65106
# Epoch 20/5000
# 5902/5902 [==============================] - 1s 224us/step - loss: 0.4673 - acc: 0.0000e+00 - val_loss: 1.1416 - val_acc: 0.0000e+00
#
# Epoch 00020: val_loss did not improve from 0.65106
# Epoch 21/5000
# 5902/5902 [==============================] - 1s 222us/step - loss: 0.4675 - acc: 0.0000e+00 - val_loss: 1.0637 - val_acc: 0.0000e+00
#
# Epoch 00021: val_loss did not improve from 0.65106
# Epoch 22/5000
# 5902/5902 [==============================] - 1s 235us/step - loss: 0.4608 - acc: 0.0000e+00 - val_loss: 0.6158 - val_acc: 0.0000e+00
#
# Epoch 00022: val_loss improved from 0.65106 to 0.61575, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.615753.hdf5
# Epoch 23/5000
# 5902/5902 [==============================] - 1s 217us/step - loss: 0.4573 - acc: 0.0000e+00 - val_loss: 0.9936 - val_acc: 0.0000e+00
#
# Epoch 00023: val_loss did not improve from 0.61575
# Epoch 24/5000
# 5902/5902 [==============================] - 2s 293us/step - loss: 0.4603 - acc: 0.0000e+00 - val_loss: 1.4132 - val_acc: 0.0000e+00
#
# Epoch 00024: val_loss did not improve from 0.61575
# Epoch 25/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.4575 - acc: 0.0000e+00 - val_loss: 0.9697 - val_acc: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 0.61575
# Epoch 26/5000
# 5902/5902 [==============================] - 1s 213us/step - loss: 0.4453 - acc: 0.0000e+00 - val_loss: 0.8227 - val_acc: 0.0000e+00
#
# Epoch 00026: val_loss did not improve from 0.61575
# Epoch 27/5000
# 5902/5902 [==============================] - 1s 210us/step - loss: 0.4486 - acc: 0.0000e+00 - val_loss: 0.8936 - val_acc: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 0.61575
# Epoch 28/5000
# 5902/5902 [==============================] - 1s 208us/step - loss: 0.4459 - acc: 0.0000e+00 - val_loss: 0.4489 - val_acc: 0.0000e+00
#
# Epoch 00028: val_loss improved from 0.61575 to 0.44890, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.448898.hdf5
# Epoch 29/5000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.4482 - acc: 0.0000e+00 - val_loss: 1.1346 - val_acc: 0.0000e+00
#
# Epoch 00029: val_loss did not improve from 0.44890
# Epoch 30/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.4379 - acc: 0.0000e+00 - val_loss: 1.1478 - val_acc: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 0.44890
# Epoch 31/5000
# 5902/5902 [==============================] - 1s 235us/step - loss: 0.4430 - acc: 0.0000e+00 - val_loss: 0.6685 - val_acc: 0.0000e+00
#
# Epoch 00031: val_loss did not improve from 0.44890
# Epoch 32/5000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.4307 - acc: 0.0000e+00 - val_loss: 0.4989 - val_acc: 0.0000e+00
#
# Epoch 00032: val_loss did not improve from 0.44890
# Epoch 33/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.4362 - acc: 0.0000e+00 - val_loss: 0.6742 - val_acc: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 0.44890
# Epoch 34/5000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.4409 - acc: 0.0000e+00 - val_loss: 0.6945 - val_acc: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 0.44890
# Epoch 35/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.4326 - acc: 0.0000e+00 - val_loss: 0.8502 - val_acc: 0.0000e+00
#
# Epoch 00035: val_loss did not improve from 0.44890
# Epoch 36/5000
# 5902/5902 [==============================] - 1s 238us/step - loss: 0.4355 - acc: 0.0000e+00 - val_loss: 0.7080 - val_acc: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 0.44890
# Epoch 37/5000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.4221 - acc: 0.0000e+00 - val_loss: 0.6022 - val_acc: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 0.44890
# Epoch 38/5000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.4289 - acc: 0.0000e+00 - val_loss: 0.3869 - val_acc: 0.0000e+00
#
# Epoch 00038: val_loss improved from 0.44890 to 0.38691, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.386912.hdf5
# Epoch 39/5000
# 5902/5902 [==============================] - 1s 238us/step - loss: 0.4325 - acc: 0.0000e+00 - val_loss: 0.8454 - val_acc: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 0.38691
# Epoch 40/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.4255 - acc: 0.0000e+00 - val_loss: 0.8022 - val_acc: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 0.38691
# Epoch 41/5000
# 5902/5902 [==============================] - 1s 222us/step - loss: 0.4222 - acc: 0.0000e+00 - val_loss: 0.4030 - val_acc: 0.0000e+00
#
# Epoch 00041: val_loss did not improve from 0.38691
# Epoch 42/5000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.4183 - acc: 0.0000e+00 - val_loss: 0.4092 - val_acc: 0.0000e+00
#
# Epoch 00042: val_loss did not improve from 0.38691
# Epoch 43/5000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.4118 - acc: 0.0000e+00 - val_loss: 0.5476 - val_acc: 0.0000e+00
#
# Epoch 00043: val_loss did not improve from 0.38691
# Epoch 44/5000
# 5902/5902 [==============================] - 1s 245us/step - loss: 0.4117 - acc: 0.0000e+00 - val_loss: 0.4365 - val_acc: 0.0000e+00
#
# Epoch 00044: val_loss did not improve from 0.38691
# Epoch 45/5000
# 5902/5902 [==============================] - 1s 230us/step - loss: 0.4170 - acc: 0.0000e+00 - val_loss: 0.5109 - val_acc: 0.0000e+00
#
# Epoch 00045: val_loss did not improve from 0.38691
# Epoch 46/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.4069 - acc: 0.0000e+00 - val_loss: 0.5415 - val_acc: 0.0000e+00
#
# Epoch 00046: val_loss did not improve from 0.38691
# Epoch 47/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.4151 - acc: 0.0000e+00 - val_loss: 0.7483 - val_acc: 0.0000e+00
#
# Epoch 00047: val_loss did not improve from 0.38691
# Epoch 48/5000
# 5902/5902 [==============================] - 1s 237us/step - loss: 0.4083 - acc: 0.0000e+00 - val_loss: 0.4921 - val_acc: 0.0000e+00
#
# Epoch 00048: val_loss did not improve from 0.38691
# Epoch 49/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.4163 - acc: 0.0000e+00 - val_loss: 0.6488 - val_acc: 0.0000e+00
#
# Epoch 00049: val_loss did not improve from 0.38691
# Epoch 50/5000
# 5902/5902 [==============================] - 1s 243us/step - loss: 0.4038 - acc: 0.0000e+00 - val_loss: 0.6258 - val_acc: 0.0000e+00
#
# Epoch 00050: val_loss did not improve from 0.38691
# Epoch 51/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3938 - acc: 0.0000e+00 - val_loss: 0.6445 - val_acc: 0.0000e+00
#
# Epoch 00051: val_loss did not improve from 0.38691
# Epoch 52/5000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.4054 - acc: 0.0000e+00 - val_loss: 0.9812 - val_acc: 0.0000e+00
#
# Epoch 00052: val_loss did not improve from 0.38691
# Epoch 53/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.4050 - acc: 0.0000e+00 - val_loss: 0.6119 - val_acc: 0.0000e+00
#
# Epoch 00053: val_loss did not improve from 0.38691
# Epoch 54/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3944 - acc: 0.0000e+00 - val_loss: 0.3558 - val_acc: 0.0000e+00
#
# Epoch 00054: val_loss improved from 0.38691 to 0.35581, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.355807.hdf5
# Epoch 55/5000
# 5902/5902 [==============================] - 1s 220us/step - loss: 0.3890 - acc: 0.0000e+00 - val_loss: 0.6726 - val_acc: 0.0000e+00
#
# Epoch 00055: val_loss did not improve from 0.35581
# Epoch 56/5000
# 5902/5902 [==============================] - 1s 219us/step - loss: 0.3948 - acc: 0.0000e+00 - val_loss: 0.7901 - val_acc: 0.0000e+00
#
# Epoch 00056: val_loss did not improve from 0.35581
# Epoch 57/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3949 - acc: 0.0000e+00 - val_loss: 0.4051 - val_acc: 0.0000e+00
#
# Epoch 00057: val_loss did not improve from 0.35581
# Epoch 58/5000
# 5902/5902 [==============================] - 1s 222us/step - loss: 0.3938 - acc: 0.0000e+00 - val_loss: 1.0682 - val_acc: 0.0000e+00
#
# Epoch 00058: val_loss did not improve from 0.35581
# Epoch 59/5000
# 5902/5902 [==============================] - 1s 222us/step - loss: 0.4008 - acc: 0.0000e+00 - val_loss: 0.4487 - val_acc: 0.0000e+00
#
# Epoch 00059: val_loss did not improve from 0.35581
# Epoch 60/5000
# 5902/5902 [==============================] - 1s 214us/step - loss: 0.3916 - acc: 0.0000e+00 - val_loss: 0.4832 - val_acc: 0.0000e+00
#
# Epoch 00060: val_loss did not improve from 0.35581
# Epoch 61/5000
# 5902/5902 [==============================] - 1s 230us/step - loss: 0.3877 - acc: 0.0000e+00 - val_loss: 0.4214 - val_acc: 0.0000e+00
#
# Epoch 00061: val_loss did not improve from 0.35581
# Epoch 62/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3978 - acc: 0.0000e+00 - val_loss: 0.3067 - val_acc: 0.0000e+00
#
# Epoch 00062: val_loss improved from 0.35581 to 0.30672, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.306724.hdf5
# Epoch 63/5000
# 5902/5902 [==============================] - 1s 225us/step - loss: 0.3885 - acc: 0.0000e+00 - val_loss: 0.5563 - val_acc: 0.0000e+00
#
# Epoch 00063: val_loss did not improve from 0.30672
# Epoch 64/5000
# 5902/5902 [==============================] - 1s 228us/step - loss: 0.3968 - acc: 0.0000e+00 - val_loss: 0.3560 - val_acc: 0.0000e+00
#
# Epoch 00064: val_loss did not improve from 0.30672
# Epoch 65/5000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3952 - acc: 0.0000e+00 - val_loss: 0.4452 - val_acc: 0.0000e+00
#
# Epoch 00065: val_loss did not improve from 0.30672
# Epoch 66/5000
# 5902/5902 [==============================] - 2s 268us/step - loss: 0.3836 - acc: 0.0000e+00 - val_loss: 0.4843 - val_acc: 0.0000e+00
#
# Epoch 00066: val_loss did not improve from 0.30672
# Epoch 67/5000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3812 - acc: 0.0000e+00 - val_loss: 0.6367 - val_acc: 0.0000e+00
#
# Epoch 00067: val_loss did not improve from 0.30672
# Epoch 68/5000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3944 - acc: 0.0000e+00 - val_loss: 0.4678 - val_acc: 0.0000e+00
#
# Epoch 00068: val_loss did not improve from 0.30672
# Epoch 69/5000
# 5902/5902 [==============================] - 1s 231us/step - loss: 0.3783 - acc: 0.0000e+00 - val_loss: 0.5630 - val_acc: 0.0000e+00
#
# Epoch 00069: val_loss did not improve from 0.30672
# Epoch 70/5000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.3916 - acc: 0.0000e+00 - val_loss: 0.5265 - val_acc: 0.0000e+00
#
# Epoch 00070: val_loss did not improve from 0.30672
# Epoch 71/5000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.3866 - acc: 0.0000e+00 - val_loss: 0.5696 - val_acc: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 0.30672
# Epoch 72/5000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.3727 - acc: 0.0000e+00 - val_loss: 0.5855 - val_acc: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 0.30672
# Epoch 73/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3901 - acc: 0.0000e+00 - val_loss: 0.3181 - val_acc: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 0.30672
# Epoch 74/5000
# 5902/5902 [==============================] - 1s 245us/step - loss: 0.3715 - acc: 0.0000e+00 - val_loss: 0.4982 - val_acc: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 0.30672
# Epoch 75/5000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3785 - acc: 0.0000e+00 - val_loss: 0.4941 - val_acc: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 0.30672
# Epoch 76/5000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.3764 - acc: 0.0000e+00 - val_loss: 0.5350 - val_acc: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 0.30672
# Epoch 77/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3865 - acc: 0.0000e+00 - val_loss: 0.6681 - val_acc: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 0.30672
# Epoch 78/5000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.3838 - acc: 0.0000e+00 - val_loss: 0.6882 - val_acc: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 0.30672
# Epoch 79/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.3875 - acc: 0.0000e+00 - val_loss: 0.3279 - val_acc: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 0.30672
# Epoch 80/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3748 - acc: 0.0000e+00 - val_loss: 0.4724 - val_acc: 0.0000e+00
#
# Epoch 00080: val_loss did not improve from 0.30672
# Epoch 81/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3670 - acc: 0.0000e+00 - val_loss: 0.4555 - val_acc: 0.0000e+00
#
# Epoch 00081: val_loss did not improve from 0.30672
# Epoch 82/5000
# 5902/5902 [==============================] - 1s 250us/step - loss: 0.3794 - acc: 0.0000e+00 - val_loss: 0.3237 - val_acc: 0.0000e+00
#
# Epoch 00082: val_loss did not improve from 0.30672
# Epoch 83/5000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3732 - acc: 0.0000e+00 - val_loss: 0.7713 - val_acc: 0.0000e+00
#
# Epoch 00083: val_loss did not improve from 0.30672
# Epoch 84/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3827 - acc: 0.0000e+00 - val_loss: 0.4145 - val_acc: 0.0000e+00
#
# Epoch 00084: val_loss did not improve from 0.30672
# Epoch 85/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3759 - acc: 0.0000e+00 - val_loss: 0.5224 - val_acc: 0.0000e+00
#
# Epoch 00085: val_loss did not improve from 0.30672
# Epoch 86/5000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.3696 - acc: 0.0000e+00 - val_loss: 0.4270 - val_acc: 0.0000e+00
#
# Epoch 00086: val_loss did not improve from 0.30672
# Epoch 87/5000
# 5902/5902 [==============================] - 1s 238us/step - loss: 0.3822 - acc: 0.0000e+00 - val_loss: 0.3052 - val_acc: 0.0000e+00
#
# Epoch 00087: val_loss improved from 0.30672 to 0.30520, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.305197.hdf5
# Epoch 88/5000
# 5902/5902 [==============================] - 1s 237us/step - loss: 0.3835 - acc: 0.0000e+00 - val_loss: 0.3373 - val_acc: 0.0000e+00
#
# Epoch 00088: val_loss did not improve from 0.30520
# Epoch 89/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3757 - acc: 0.0000e+00 - val_loss: 0.7790 - val_acc: 0.0000e+00
#
# Epoch 00089: val_loss did not improve from 0.30520
# Epoch 90/5000
# 5902/5902 [==============================] - 2s 255us/step - loss: 0.3746 - acc: 0.0000e+00 - val_loss: 0.4340 - val_acc: 0.0000e+00
#
# Epoch 00090: val_loss did not improve from 0.30520
# Epoch 91/5000
# 5902/5902 [==============================] - 2s 264us/step - loss: 0.3829 - acc: 0.0000e+00 - val_loss: 0.5272 - val_acc: 0.0000e+00
#
# Epoch 00091: val_loss did not improve from 0.30520
# Epoch 92/5000
# 5902/5902 [==============================] - 2s 268us/step - loss: 0.3766 - acc: 0.0000e+00 - val_loss: 0.4151 - val_acc: 0.0000e+00
#
# Epoch 00092: val_loss did not improve from 0.30520
# Epoch 93/5000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.3985 - acc: 0.0000e+00 - val_loss: 0.7969 - val_acc: 0.0000e+00
#
# Epoch 00093: val_loss did not improve from 0.30520
# Epoch 94/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3648 - acc: 0.0000e+00 - val_loss: 0.4479 - val_acc: 0.0000e+00
#
# Epoch 00094: val_loss did not improve from 0.30520
# Epoch 95/5000
# 5902/5902 [==============================] - 1s 238us/step - loss: 0.3714 - acc: 0.0000e+00 - val_loss: 0.3340 - val_acc: 0.0000e+00
#
# Epoch 00095: val_loss did not improve from 0.30520
# Epoch 96/5000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.3745 - acc: 0.0000e+00 - val_loss: 0.2987 - val_acc: 0.0000e+00
#
# Epoch 00096: val_loss improved from 0.30520 to 0.29865, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.298650.hdf5
# Epoch 97/5000
# 5902/5902 [==============================] - 2s 265us/step - loss: 0.3626 - acc: 0.0000e+00 - val_loss: 0.7531 - val_acc: 0.0000e+00
#
# Epoch 00097: val_loss did not improve from 0.29865
# Epoch 98/5000
# 5902/5902 [==============================] - 1s 231us/step - loss: 0.3697 - acc: 0.0000e+00 - val_loss: 0.3391 - val_acc: 0.0000e+00
#
# Epoch 00098: val_loss did not improve from 0.29865
# Epoch 99/5000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.3672 - acc: 0.0000e+00 - val_loss: 0.5066 - val_acc: 0.0000e+00
#
# Epoch 00099: val_loss did not improve from 0.29865
# Epoch 100/5000
# 5902/5902 [==============================] - 1s 233us/step - loss: 0.3689 - acc: 0.0000e+00 - val_loss: 0.4472 - val_acc: 0.0000e+00
#
# Epoch 00100: val_loss did not improve from 0.29865
# Epoch 101/5000
# 5902/5902 [==============================] - 1s 228us/step - loss: 0.3731 - acc: 0.0000e+00 - val_loss: 0.3078 - val_acc: 0.0000e+00
#
# Epoch 00101: val_loss did not improve from 0.29865
# Epoch 102/5000
# 5902/5902 [==============================] - 1s 250us/step - loss: 0.3586 - acc: 0.0000e+00 - val_loss: 0.3444 - val_acc: 0.0000e+00
#
# Epoch 00102: val_loss did not improve from 0.29865
# Epoch 103/5000
# 5902/5902 [==============================] - 2s 311us/step - loss: 0.3625 - acc: 0.0000e+00 - val_loss: 0.3700 - val_acc: 0.0000e+00
#
# Epoch 00103: val_loss did not improve from 0.29865
# Epoch 104/5000
# 5902/5902 [==============================] - 2s 295us/step - loss: 0.3718 - acc: 0.0000e+00 - val_loss: 0.4971 - val_acc: 0.0000e+00
#
# Epoch 00104: val_loss did not improve from 0.29865
# Epoch 105/5000
# 5902/5902 [==============================] - 1s 251us/step - loss: 0.3732 - acc: 0.0000e+00 - val_loss: 0.2794 - val_acc: 0.0000e+00
#
# Epoch 00105: val_loss improved from 0.29865 to 0.27938, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.279377.hdf5
# Epoch 106/5000
# 5902/5902 [==============================] - 1s 245us/step - loss: 0.3577 - acc: 0.0000e+00 - val_loss: 0.6058 - val_acc: 0.0000e+00
#
# Epoch 00106: val_loss did not improve from 0.27938
# Epoch 107/5000
# 5902/5902 [==============================] - 2s 320us/step - loss: 0.3635 - acc: 0.0000e+00 - val_loss: 0.3141 - val_acc: 0.0000e+00
#
# Epoch 00107: val_loss did not improve from 0.27938
# Epoch 108/5000
# 5902/5902 [==============================] - 2s 259us/step - loss: 0.3645 - acc: 0.0000e+00 - val_loss: 0.7340 - val_acc: 0.0000e+00
#
# Epoch 00108: val_loss did not improve from 0.27938
# Epoch 109/5000
# 5902/5902 [==============================] - 2s 263us/step - loss: 0.3789 - acc: 0.0000e+00 - val_loss: 0.3660 - val_acc: 0.0000e+00
#
# Epoch 00109: val_loss did not improve from 0.27938
# Epoch 110/5000
# 5902/5902 [==============================] - 2s 273us/step - loss: 0.3624 - acc: 0.0000e+00 - val_loss: 0.4525 - val_acc: 0.0000e+00
#
# Epoch 00110: val_loss did not improve from 0.27938
# Epoch 111/5000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.3703 - acc: 0.0000e+00 - val_loss: 0.5973 - val_acc: 0.0000e+00
#
# Epoch 00111: val_loss did not improve from 0.27938
# Epoch 112/5000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3638 - acc: 0.0000e+00 - val_loss: 0.3039 - val_acc: 0.0000e+00
#
# Epoch 00112: val_loss did not improve from 0.27938
# Epoch 113/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3542 - acc: 0.0000e+00 - val_loss: 0.3383 - val_acc: 0.0000e+00
#
# Epoch 00113: val_loss did not improve from 0.27938
# Epoch 114/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3672 - acc: 0.0000e+00 - val_loss: 0.3160 - val_acc: 0.0000e+00
#
# Epoch 00114: val_loss did not improve from 0.27938
# Epoch 115/5000
# 5902/5902 [==============================] - 1s 245us/step - loss: 0.3604 - acc: 0.0000e+00 - val_loss: 0.3772 - val_acc: 0.0000e+00
#
# Epoch 00115: val_loss did not improve from 0.27938
# Epoch 116/5000
# 5902/5902 [==============================] - 1s 243us/step - loss: 0.3717 - acc: 0.0000e+00 - val_loss: 0.4085 - val_acc: 0.0000e+00
#
# Epoch 00116: val_loss did not improve from 0.27938
# Epoch 117/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3617 - acc: 0.0000e+00 - val_loss: 0.3231 - val_acc: 0.0000e+00
#
# Epoch 00117: val_loss did not improve from 0.27938
# Epoch 118/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3581 - acc: 0.0000e+00 - val_loss: 0.3062 - val_acc: 0.0000e+00
#
# Epoch 00118: val_loss did not improve from 0.27938
# Epoch 119/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3729 - acc: 0.0000e+00 - val_loss: 0.3870 - val_acc: 0.0000e+00
#
# Epoch 00119: val_loss did not improve from 0.27938
# Epoch 120/5000
# 5902/5902 [==============================] - 1s 238us/step - loss: 0.3655 - acc: 0.0000e+00 - val_loss: 0.2787 - val_acc: 0.0000e+00
#
# Epoch 00120: val_loss improved from 0.27938 to 0.27870, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.278698.hdf5
# Epoch 121/5000
# 5902/5902 [==============================] - 1s 226us/step - loss: 0.3648 - acc: 0.0000e+00 - val_loss: 0.3305 - val_acc: 0.0000e+00
#
# Epoch 00121: val_loss did not improve from 0.27870
# Epoch 122/5000
# 5902/5902 [==============================] - 1s 229us/step - loss: 0.3579 - acc: 0.0000e+00 - val_loss: 0.3228 - val_acc: 0.0000e+00
#
# Epoch 00122: val_loss did not improve from 0.27870
# Epoch 123/5000
# 5902/5902 [==============================] - 1s 250us/step - loss: 0.3575 - acc: 0.0000e+00 - val_loss: 0.4028 - val_acc: 0.0000e+00
#
# Epoch 00123: val_loss did not improve from 0.27870
# Epoch 124/5000
# 5902/5902 [==============================] - 1s 227us/step - loss: 0.3565 - acc: 0.0000e+00 - val_loss: 0.3100 - val_acc: 0.0000e+00
#
# Epoch 00124: val_loss did not improve from 0.27870
# Epoch 125/5000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.3713 - acc: 0.0000e+00 - val_loss: 0.8688 - val_acc: 0.0000e+00
#
# Epoch 00125: val_loss did not improve from 0.27870
# Epoch 126/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3614 - acc: 0.0000e+00 - val_loss: 0.3389 - val_acc: 0.0000e+00
#
# Epoch 00126: val_loss did not improve from 0.27870
# Epoch 127/5000
# 5902/5902 [==============================] - 1s 249us/step - loss: 0.3643 - acc: 0.0000e+00 - val_loss: 0.2757 - val_acc: 0.0000e+00
#
# Epoch 00127: val_loss improved from 0.27870 to 0.27571, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.275713.hdf5
# Epoch 128/5000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3542 - acc: 0.0000e+00 - val_loss: 0.7137 - val_acc: 0.0000e+00
#
# Epoch 00128: val_loss did not improve from 0.27571
# Epoch 129/5000
# 5902/5902 [==============================] - 1s 229us/step - loss: 0.3607 - acc: 0.0000e+00 - val_loss: 0.3748 - val_acc: 0.0000e+00
#
# Epoch 00129: val_loss did not improve from 0.27571
# Epoch 130/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3611 - acc: 0.0000e+00 - val_loss: 0.6141 - val_acc: 0.0000e+00
#
# Epoch 00130: val_loss did not improve from 0.27571
# Epoch 131/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3625 - acc: 0.0000e+00 - val_loss: 0.3484 - val_acc: 0.0000e+00
#
# Epoch 00131: val_loss did not improve from 0.27571
# Epoch 132/5000
# 5902/5902 [==============================] - 1s 221us/step - loss: 0.3549 - acc: 0.0000e+00 - val_loss: 0.3095 - val_acc: 0.0000e+00
#
# Epoch 00132: val_loss did not improve from 0.27571
# Epoch 133/5000
# 5902/5902 [==============================] - 1s 227us/step - loss: 0.3562 - acc: 0.0000e+00 - val_loss: 0.7044 - val_acc: 0.0000e+00
#
# Epoch 00133: val_loss did not improve from 0.27571
# Epoch 134/5000
# 5902/5902 [==============================] - 1s 211us/step - loss: 0.3630 - acc: 0.0000e+00 - val_loss: 0.4066 - val_acc: 0.0000e+00
#
# Epoch 00134: val_loss did not improve from 0.27571
# Epoch 135/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.3563 - acc: 0.0000e+00 - val_loss: 0.3126 - val_acc: 0.0000e+00
#
# Epoch 00135: val_loss did not improve from 0.27571
# Epoch 136/5000
# 5902/5902 [==============================] - 1s 231us/step - loss: 0.3622 - acc: 0.0000e+00 - val_loss: 0.3051 - val_acc: 0.0000e+00
#
# Epoch 00136: val_loss did not improve from 0.27571
# Epoch 137/5000
# 5902/5902 [==============================] - 1s 217us/step - loss: 0.3642 - acc: 0.0000e+00 - val_loss: 0.3203 - val_acc: 0.0000e+00
#
# Epoch 00137: val_loss did not improve from 0.27571
# Epoch 138/5000
# 5902/5902 [==============================] - 1s 213us/step - loss: 0.3626 - acc: 0.0000e+00 - val_loss: 0.3254 - val_acc: 0.0000e+00
#
# Epoch 00138: val_loss did not improve from 0.27571
# Epoch 139/5000
# 5902/5902 [==============================] - 1s 235us/step - loss: 0.3661 - acc: 0.0000e+00 - val_loss: 0.8752 - val_acc: 0.0000e+00
#
# Epoch 00139: val_loss did not improve from 0.27571
# Epoch 140/5000
# 5902/5902 [==============================] - 1s 218us/step - loss: 0.3597 - acc: 0.0000e+00 - val_loss: 0.3598 - val_acc: 0.0000e+00
#
# Epoch 00140: val_loss did not improve from 0.27571
# Epoch 141/5000
# 5902/5902 [==============================] - 1s 231us/step - loss: 0.3536 - acc: 0.0000e+00 - val_loss: 0.3828 - val_acc: 0.0000e+00
#
# Epoch 00141: val_loss did not improve from 0.27571
# Epoch 142/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3612 - acc: 0.0000e+00 - val_loss: 0.3864 - val_acc: 0.0000e+00
#
# Epoch 00142: val_loss did not improve from 0.27571
# Epoch 143/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3690 - acc: 0.0000e+00 - val_loss: 0.3483 - val_acc: 0.0000e+00
#
# Epoch 00143: val_loss did not improve from 0.27571
# Epoch 144/5000
# 5902/5902 [==============================] - 1s 206us/step - loss: 0.3513 - acc: 0.0000e+00 - val_loss: 0.5064 - val_acc: 0.0000e+00
#
# Epoch 00144: val_loss did not improve from 0.27571
# Epoch 145/5000
# 5902/5902 [==============================] - 1s 225us/step - loss: 0.3554 - acc: 0.0000e+00 - val_loss: 1.0208 - val_acc: 0.0000e+00
#
# Epoch 00145: val_loss did not improve from 0.27571
# Epoch 146/5000
# 5902/5902 [==============================] - 1s 226us/step - loss: 0.3686 - acc: 0.0000e+00 - val_loss: 0.2810 - val_acc: 0.0000e+00
#
# Epoch 00146: val_loss did not improve from 0.27571
# Epoch 147/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3623 - acc: 0.0000e+00 - val_loss: 0.3119 - val_acc: 0.0000e+00
#
# Epoch 00147: val_loss did not improve from 0.27571
# Epoch 148/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.3622 - acc: 0.0000e+00 - val_loss: 0.3011 - val_acc: 0.0000e+00
#
# Epoch 00148: val_loss did not improve from 0.27571
# Epoch 149/5000
# 5902/5902 [==============================] - 1s 208us/step - loss: 0.3631 - acc: 0.0000e+00 - val_loss: 0.4632 - val_acc: 0.0000e+00
#
# Epoch 00149: val_loss did not improve from 0.27571
# Epoch 150/5000
# 5902/5902 [==============================] - 1s 228us/step - loss: 0.3557 - acc: 0.0000e+00 - val_loss: 0.3505 - val_acc: 0.0000e+00
#
# Epoch 00150: val_loss did not improve from 0.27571
# Epoch 151/5000
# 5902/5902 [==============================] - 1s 245us/step - loss: 0.3583 - acc: 0.0000e+00 - val_loss: 0.3263 - val_acc: 0.0000e+00
#
# Epoch 00151: val_loss did not improve from 0.27571
# Epoch 152/5000
# 5902/5902 [==============================] - 1s 238us/step - loss: 0.3495 - acc: 0.0000e+00 - val_loss: 0.3846 - val_acc: 0.0000e+00
#
# Epoch 00152: val_loss did not improve from 0.27571
# Epoch 153/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3478 - acc: 0.0000e+00 - val_loss: 0.7228 - val_acc: 0.0000e+00
#
# Epoch 00153: val_loss did not improve from 0.27571
# Epoch 154/5000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3543 - acc: 0.0000e+00 - val_loss: 0.3127 - val_acc: 0.0000e+00
#
# Epoch 00154: val_loss did not improve from 0.27571
# Epoch 155/5000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.3581 - acc: 0.0000e+00 - val_loss: 0.2681 - val_acc: 0.0000e+00
#
# Epoch 00155: val_loss improved from 0.27571 to 0.26807, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.268071.hdf5
# Epoch 156/5000
# 5902/5902 [==============================] - 1s 235us/step - loss: 0.3501 - acc: 0.0000e+00 - val_loss: 0.5250 - val_acc: 0.0000e+00
#
# Epoch 00156: val_loss did not improve from 0.26807
# Epoch 157/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3599 - acc: 0.0000e+00 - val_loss: 0.6195 - val_acc: 0.0000e+00
#
# Epoch 00157: val_loss did not improve from 0.26807
# Epoch 158/5000
# 5902/5902 [==============================] - 1s 249us/step - loss: 0.3508 - acc: 0.0000e+00 - val_loss: 0.5206 - val_acc: 0.0000e+00
#
# Epoch 00158: val_loss did not improve from 0.26807
# Epoch 159/5000
# 5902/5902 [==============================] - 1s 243us/step - loss: 0.3522 - acc: 0.0000e+00 - val_loss: 0.2823 - val_acc: 0.0000e+00
#
# Epoch 00159: val_loss did not improve from 0.26807
# Epoch 160/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3556 - acc: 0.0000e+00 - val_loss: 0.3512 - val_acc: 0.0000e+00
#
# Epoch 00160: val_loss did not improve from 0.26807
# Epoch 161/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3524 - acc: 0.0000e+00 - val_loss: 0.3329 - val_acc: 0.0000e+00
#
# Epoch 00161: val_loss did not improve from 0.26807
# Epoch 162/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3467 - acc: 0.0000e+00 - val_loss: 0.4922 - val_acc: 0.0000e+00
#
# Epoch 00162: val_loss did not improve from 0.26807
# Epoch 163/5000
# 5902/5902 [==============================] - 1s 237us/step - loss: 0.3579 - acc: 0.0000e+00 - val_loss: 0.5551 - val_acc: 0.0000e+00
#
# Epoch 00163: val_loss did not improve from 0.26807
# Epoch 164/5000
# 5902/5902 [==============================] - 1s 249us/step - loss: 0.3553 - acc: 0.0000e+00 - val_loss: 0.3667 - val_acc: 0.0000e+00
#
# Epoch 00164: val_loss did not improve from 0.26807
# Epoch 165/5000
# 5902/5902 [==============================] - 1s 238us/step - loss: 0.3613 - acc: 0.0000e+00 - val_loss: 0.2678 - val_acc: 0.0000e+00
#
# Epoch 00165: val_loss improved from 0.26807 to 0.26782, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.267823.hdf5
# Epoch 166/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3518 - acc: 0.0000e+00 - val_loss: 0.3026 - val_acc: 0.0000e+00
#
# Epoch 00166: val_loss did not improve from 0.26782
# Epoch 167/5000
# 5902/5902 [==============================] - 1s 251us/step - loss: 0.3548 - acc: 0.0000e+00 - val_loss: 0.2850 - val_acc: 0.0000e+00
#
# Epoch 00167: val_loss did not improve from 0.26782
# Epoch 168/5000
# 5902/5902 [==============================] - 2s 300us/step - loss: 0.3497 - acc: 0.0000e+00 - val_loss: 0.3426 - val_acc: 0.0000e+00
#
# Epoch 00168: val_loss did not improve from 0.26782
# Epoch 169/5000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.3439 - acc: 0.0000e+00 - val_loss: 0.3265 - val_acc: 0.0000e+00
#
# Epoch 00169: val_loss did not improve from 0.26782
# Epoch 170/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3533 - acc: 0.0000e+00 - val_loss: 0.6079 - val_acc: 0.0000e+00
#
# Epoch 00170: val_loss did not improve from 0.26782
# Epoch 171/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3680 - acc: 0.0000e+00 - val_loss: 0.4882 - val_acc: 0.0000e+00
#
# Epoch 00171: val_loss did not improve from 0.26782
# Epoch 172/5000
# 5902/5902 [==============================] - 1s 227us/step - loss: 0.3570 - acc: 0.0000e+00 - val_loss: 0.6021 - val_acc: 0.0000e+00
#
# Epoch 00172: val_loss did not improve from 0.26782
# Epoch 173/5000
# 5902/5902 [==============================] - 1s 221us/step - loss: 0.3471 - acc: 0.0000e+00 - val_loss: 0.3549 - val_acc: 0.0000e+00
#
# Epoch 00173: val_loss did not improve from 0.26782
# Epoch 174/5000
# 5902/5902 [==============================] - 1s 222us/step - loss: 0.3487 - acc: 0.0000e+00 - val_loss: 0.2583 - val_acc: 0.0000e+00
#
# Epoch 00174: val_loss improved from 0.26782 to 0.25829, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.258289.hdf5
# Epoch 175/5000
# 5902/5902 [==============================] - 1s 219us/step - loss: 0.3481 - acc: 0.0000e+00 - val_loss: 0.6538 - val_acc: 0.0000e+00
#
# Epoch 00175: val_loss did not improve from 0.25829
# Epoch 176/5000
# 5902/5902 [==============================] - 1s 221us/step - loss: 0.3565 - acc: 0.0000e+00 - val_loss: 0.5245 - val_acc: 0.0000e+00
#
# Epoch 00176: val_loss did not improve from 0.25829
# Epoch 177/5000
# 5902/5902 [==============================] - 1s 213us/step - loss: 0.3512 - acc: 0.0000e+00 - val_loss: 0.3086 - val_acc: 0.0000e+00
#
# Epoch 00177: val_loss did not improve from 0.25829
# Epoch 178/5000
# 5902/5902 [==============================] - 1s 221us/step - loss: 0.3548 - acc: 0.0000e+00 - val_loss: 0.3057 - val_acc: 0.0000e+00
#
# Epoch 00178: val_loss did not improve from 0.25829
# Epoch 179/5000
# 5902/5902 [==============================] - 1s 227us/step - loss: 0.3512 - acc: 0.0000e+00 - val_loss: 0.5501 - val_acc: 0.0000e+00
#
# Epoch 00179: val_loss did not improve from 0.25829
# Epoch 180/5000
# 5902/5902 [==============================] - 1s 231us/step - loss: 0.3552 - acc: 0.0000e+00 - val_loss: 0.2958 - val_acc: 0.0000e+00
#
# Epoch 00180: val_loss did not improve from 0.25829
# Epoch 181/5000
# 5902/5902 [==============================] - 1s 220us/step - loss: 0.3461 - acc: 0.0000e+00 - val_loss: 0.3056 - val_acc: 0.0000e+00
#
# Epoch 00181: val_loss did not improve from 0.25829
# Epoch 182/5000
# 5902/5902 [==============================] - 1s 222us/step - loss: 0.3382 - acc: 0.0000e+00 - val_loss: 0.2732 - val_acc: 0.0000e+00
#
# Epoch 00182: val_loss did not improve from 0.25829
# Epoch 183/5000
# 5902/5902 [==============================] - 1s 214us/step - loss: 0.3437 - acc: 0.0000e+00 - val_loss: 0.6052 - val_acc: 0.0000e+00
#
# Epoch 00183: val_loss did not improve from 0.25829
# Epoch 184/5000
# 5902/5902 [==============================] - 1s 220us/step - loss: 0.3466 - acc: 0.0000e+00 - val_loss: 0.3453 - val_acc: 0.0000e+00
#
# Epoch 00184: val_loss did not improve from 0.25829
# Epoch 185/5000
# 5902/5902 [==============================] - 1s 213us/step - loss: 0.3528 - acc: 0.0000e+00 - val_loss: 0.3557 - val_acc: 0.0000e+00
#
# Epoch 00185: val_loss did not improve from 0.25829
# Epoch 186/5000
# 5902/5902 [==============================] - 1s 200us/step - loss: 0.3505 - acc: 0.0000e+00 - val_loss: 0.2827 - val_acc: 0.0000e+00
#
# Epoch 00186: val_loss did not improve from 0.25829
# Epoch 187/5000
# 5902/5902 [==============================] - 1s 210us/step - loss: 0.3434 - acc: 0.0000e+00 - val_loss: 0.3101 - val_acc: 0.0000e+00
#
# Epoch 00187: val_loss did not improve from 0.25829
# Epoch 188/5000
# 5902/5902 [==============================] - 1s 204us/step - loss: 0.3450 - acc: 0.0000e+00 - val_loss: 0.2689 - val_acc: 0.0000e+00
#
# Epoch 00188: val_loss did not improve from 0.25829
# Epoch 189/5000
# 5902/5902 [==============================] - 1s 217us/step - loss: 0.3543 - acc: 0.0000e+00 - val_loss: 0.6037 - val_acc: 0.0000e+00
#
# Epoch 00189: val_loss did not improve from 0.25829
# Epoch 190/5000
# 5902/5902 [==============================] - 1s 227us/step - loss: 0.3478 - acc: 0.0000e+00 - val_loss: 0.2916 - val_acc: 0.0000e+00
#
# Epoch 00190: val_loss did not improve from 0.25829
# Epoch 191/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.3430 - acc: 0.0000e+00 - val_loss: 0.3652 - val_acc: 0.0000e+00
#
# Epoch 00191: val_loss did not improve from 0.25829
# Epoch 192/5000
# 5902/5902 [==============================] - 1s 237us/step - loss: 0.3530 - acc: 0.0000e+00 - val_loss: 0.3371 - val_acc: 0.0000e+00
#
# Epoch 00192: val_loss did not improve from 0.25829
# Epoch 193/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.3581 - acc: 0.0000e+00 - val_loss: 0.3295 - val_acc: 0.0000e+00
#
# Epoch 00193: val_loss did not improve from 0.25829
# Epoch 194/5000
# 5902/5902 [==============================] - 1s 235us/step - loss: 0.3485 - acc: 0.0000e+00 - val_loss: 0.3029 - val_acc: 0.0000e+00
#
# Epoch 00194: val_loss did not improve from 0.25829
# Epoch 195/5000
# 5902/5902 [==============================] - 1s 238us/step - loss: 0.3577 - acc: 0.0000e+00 - val_loss: 0.2756 - val_acc: 0.0000e+00
#
# Epoch 00195: val_loss did not improve from 0.25829
# Epoch 196/5000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.3451 - acc: 0.0000e+00 - val_loss: 0.4029 - val_acc: 0.0000e+00
#
# Epoch 00196: val_loss did not improve from 0.25829
# Epoch 197/5000
# 5902/5902 [==============================] - 2s 312us/step - loss: 0.3533 - acc: 0.0000e+00 - val_loss: 0.3862 - val_acc: 0.0000e+00
#
# Epoch 00197: val_loss did not improve from 0.25829
# Epoch 198/5000
# 5902/5902 [==============================] - 2s 266us/step - loss: 0.3478 - acc: 0.0000e+00 - val_loss: 0.2985 - val_acc: 0.0000e+00
#
# Epoch 00198: val_loss did not improve from 0.25829
# Epoch 199/5000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3499 - acc: 0.0000e+00 - val_loss: 0.3484 - val_acc: 0.0000e+00
#
# Epoch 00199: val_loss did not improve from 0.25829
# Epoch 200/5000
# 5902/5902 [==============================] - 2s 267us/step - loss: 0.3463 - acc: 0.0000e+00 - val_loss: 0.3190 - val_acc: 0.0000e+00
#
# Epoch 00200: val_loss did not improve from 0.25829
# Epoch 201/5000
# 5902/5902 [==============================] - 1s 235us/step - loss: 0.3526 - acc: 0.0000e+00 - val_loss: 0.3533 - val_acc: 0.0000e+00
#
# Epoch 00201: val_loss did not improve from 0.25829
# Epoch 202/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3464 - acc: 0.0000e+00 - val_loss: 0.4585 - val_acc: 0.0000e+00
#
# Epoch 00202: val_loss did not improve from 0.25829
# Epoch 203/5000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.3420 - acc: 0.0000e+00 - val_loss: 0.5741 - val_acc: 0.0000e+00
#
# Epoch 00203: val_loss did not improve from 0.25829
# Epoch 204/5000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3454 - acc: 0.0000e+00 - val_loss: 0.3227 - val_acc: 0.0000e+00
#
# Epoch 00204: val_loss did not improve from 0.25829
# Epoch 205/5000
# 5902/5902 [==============================] - 2s 263us/step - loss: 0.3465 - acc: 0.0000e+00 - val_loss: 0.4038 - val_acc: 0.0000e+00
#
# Epoch 00205: val_loss did not improve from 0.25829
# Epoch 206/5000
# 5902/5902 [==============================] - 2s 273us/step - loss: 0.3551 - acc: 0.0000e+00 - val_loss: 0.2800 - val_acc: 0.0000e+00
#
# Epoch 00206: val_loss did not improve from 0.25829
# Epoch 207/5000
# 5902/5902 [==============================] - 2s 276us/step - loss: 0.3542 - acc: 0.0000e+00 - val_loss: 0.3916 - val_acc: 0.0000e+00
#
# Epoch 00207: val_loss did not improve from 0.25829
# Epoch 208/5000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3549 - acc: 0.0000e+00 - val_loss: 0.3836 - val_acc: 0.0000e+00
#
# Epoch 00208: val_loss did not improve from 0.25829
# Epoch 209/5000
# 5902/5902 [==============================] - 2s 261us/step - loss: 0.3537 - acc: 0.0000e+00 - val_loss: 0.2790 - val_acc: 0.0000e+00
#
# Epoch 00209: val_loss did not improve from 0.25829
# Epoch 210/5000
# 5902/5902 [==============================] - 2s 270us/step - loss: 0.3455 - acc: 0.0000e+00 - val_loss: 0.2999 - val_acc: 0.0000e+00
#
# Epoch 00210: val_loss did not improve from 0.25829
# Epoch 211/5000
# 5902/5902 [==============================] - 2s 277us/step - loss: 0.3539 - acc: 0.0000e+00 - val_loss: 0.2945 - val_acc: 0.0000e+00
#
# Epoch 00211: val_loss did not improve from 0.25829
# Epoch 212/5000
# 5902/5902 [==============================] - 1s 249us/step - loss: 0.3483 - acc: 0.0000e+00 - val_loss: 0.3060 - val_acc: 0.0000e+00
#
# Epoch 00212: val_loss did not improve from 0.25829
# Epoch 213/5000
# 5902/5902 [==============================] - 2s 262us/step - loss: 0.3381 - acc: 0.0000e+00 - val_loss: 0.3015 - val_acc: 0.0000e+00
#
# Epoch 00213: val_loss did not improve from 0.25829
# Epoch 214/5000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3383 - acc: 0.0000e+00 - val_loss: 0.3060 - val_acc: 0.0000e+00
#
# Epoch 00214: val_loss did not improve from 0.25829
# Epoch 215/5000
# 5902/5902 [==============================] - 2s 267us/step - loss: 0.3428 - acc: 0.0000e+00 - val_loss: 0.5241 - val_acc: 0.0000e+00
#
# Epoch 00215: val_loss did not improve from 0.25829
# Epoch 216/5000
# 5902/5902 [==============================] - 2s 255us/step - loss: 0.3617 - acc: 0.0000e+00 - val_loss: 0.4442 - val_acc: 0.0000e+00
#
# Epoch 00216: val_loss did not improve from 0.25829
# Epoch 217/5000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3411 - acc: 0.0000e+00 - val_loss: 0.4131 - val_acc: 0.0000e+00
#
# Epoch 00217: val_loss did not improve from 0.25829
# Epoch 218/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.3428 - acc: 0.0000e+00 - val_loss: 0.3013 - val_acc: 0.0000e+00
#
# Epoch 00218: val_loss did not improve from 0.25829
# Epoch 219/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3501 - acc: 0.0000e+00 - val_loss: 0.5740 - val_acc: 0.0000e+00
#
# Epoch 00219: val_loss did not improve from 0.25829
# Epoch 220/5000
# 5902/5902 [==============================] - 2s 257us/step - loss: 0.3476 - acc: 0.0000e+00 - val_loss: 0.9650 - val_acc: 0.0000e+00
#
# Epoch 00220: val_loss did not improve from 0.25829
# Epoch 221/5000
# 5902/5902 [==============================] - 2s 257us/step - loss: 0.3461 - acc: 0.0000e+00 - val_loss: 0.3090 - val_acc: 0.0000e+00
#
# Epoch 00221: val_loss did not improve from 0.25829
# Epoch 222/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.3524 - acc: 0.0000e+00 - val_loss: 0.2519 - val_acc: 0.0000e+00
#
# Epoch 00222: val_loss improved from 0.25829 to 0.25193, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.251927.hdf5
# Epoch 223/5000
# 5902/5902 [==============================] - 1s 236us/step - loss: 0.3341 - acc: 0.0000e+00 - val_loss: 0.7912 - val_acc: 0.0000e+00
#
# Epoch 00223: val_loss did not improve from 0.25193
# Epoch 224/5000
# 5902/5902 [==============================] - 1s 230us/step - loss: 0.3438 - acc: 0.0000e+00 - val_loss: 0.3408 - val_acc: 0.0000e+00
#
# Epoch 00224: val_loss did not improve from 0.25193
# Epoch 225/5000
# 5902/5902 [==============================] - 1s 227us/step - loss: 0.3484 - acc: 0.0000e+00 - val_loss: 0.3844 - val_acc: 0.0000e+00
#
# Epoch 00225: val_loss did not improve from 0.25193
# Epoch 226/5000
# 5902/5902 [==============================] - 1s 224us/step - loss: 0.3455 - acc: 0.0000e+00 - val_loss: 0.4306 - val_acc: 0.0000e+00
#
# Epoch 00226: val_loss did not improve from 0.25193
# Epoch 227/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3449 - acc: 0.0000e+00 - val_loss: 0.2651 - val_acc: 0.0000e+00
#
# Epoch 00227: val_loss did not improve from 0.25193
# Epoch 228/5000
# 5902/5902 [==============================] - 1s 226us/step - loss: 0.3570 - acc: 0.0000e+00 - val_loss: 0.3125 - val_acc: 0.0000e+00
#
# Epoch 00228: val_loss did not improve from 0.25193
# Epoch 229/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3430 - acc: 0.0000e+00 - val_loss: 0.2927 - val_acc: 0.0000e+00
#
# Epoch 00229: val_loss did not improve from 0.25193
# Epoch 230/5000
# 5902/5902 [==============================] - 1s 235us/step - loss: 0.3472 - acc: 0.0000e+00 - val_loss: 0.4710 - val_acc: 0.0000e+00
# Epoch 00230: val_loss did not improve from 0.25193
# Epoch 231/5000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.3427 - acc: 0.0000e+00 - val_loss: 0.5013 - val_acc: 0.0000e+00
#
# Epoch 00231: val_loss did not improve from 0.25193
# Epoch 232/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3572 - acc: 0.0000e+00 - val_loss: 0.3110 - val_acc: 0.0000e+00
#
# Epoch 00232: val_loss did not improve from 0.25193
# Epoch 233/5000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.3438 - acc: 0.0000e+00 - val_loss: 0.2851 - val_acc: 0.0000e+00
#
# Epoch 00233: val_loss did not improve from 0.25193
# Epoch 234/5000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3470 - acc: 0.0000e+00 - val_loss: 0.2961 - val_acc: 0.0000e+00
#
# Epoch 00234: val_loss did not improve from 0.25193
# Epoch 235/5000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.3510 - acc: 0.0000e+00 - val_loss: 0.2913 - val_acc: 0.0000e+00
#
# Epoch 00235: val_loss did not improve from 0.25193
# Epoch 236/5000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.3457 - acc: 0.0000e+00 - val_loss: 0.4445 - val_acc: 0.0000e+00
#
# Epoch 00236: val_loss did not improve from 0.25193
# Epoch 237/5000
# 5902/5902 [==============================] - 1s 250us/step - loss: 0.3454 - acc: 0.0000e+00 - val_loss: 0.2962 - val_acc: 0.0000e+00
#
# Epoch 00237: val_loss did not improve from 0.25193
# Epoch 238/5000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3515 - acc: 0.0000e+00 - val_loss: 0.3536 - val_acc: 0.0000e+00
#
# Epoch 00238: val_loss did not improve from 0.25193
# Epoch 239/5000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.3440 - acc: 0.0000e+00 - val_loss: 0.2986 - val_acc: 0.0000e+00
#
# Epoch 00239: val_loss did not improve from 0.25193
# Epoch 240/5000
# 5902/5902 [==============================] - 2s 265us/step - loss: 0.3439 - acc: 0.0000e+00 - val_loss: 0.3201 - val_acc: 0.0000e+00
#
# Epoch 00240: val_loss did not improve from 0.25193
# Epoch 241/5000
# 5902/5902 [==============================] - 2s 255us/step - loss: 0.3476 - acc: 0.0000e+00 - val_loss: 0.2884 - val_acc: 0.0000e+00
#
# Epoch 00241: val_loss did not improve from 0.25193
# Epoch 242/5000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3468 - acc: 0.0000e+00 - val_loss: 0.3585 - val_acc: 0.0000e+00
#
# Epoch 00242: val_loss did not improve from 0.25193
# Epoch 243/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3487 - acc: 0.0000e+00 - val_loss: 0.3075 - val_acc: 0.0000e+00
#
# Epoch 00243: val_loss did not improve from 0.25193
# Epoch 244/5000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3441 - acc: 0.0000e+00 - val_loss: 0.2942 - val_acc: 0.0000e+00
#
# Epoch 00244: val_loss did not improve from 0.25193
# Epoch 245/5000
# 5902/5902 [==============================] - 1s 250us/step - loss: 0.3397 - acc: 0.0000e+00 - val_loss: 0.2850 - val_acc: 0.0000e+00
#
# Epoch 00245: val_loss did not improve from 0.25193
# Epoch 246/5000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.3449 - acc: 0.0000e+00 - val_loss: 0.2893 - val_acc: 0.0000e+00
#
# Epoch 00246: val_loss did not improve from 0.25193
# Epoch 247/5000
# 5902/5902 [==============================] - 1s 249us/step - loss: 0.3318 - acc: 0.0000e+00 - val_loss: 0.3218 - val_acc: 0.0000e+00
#
# Epoch 00247: val_loss did not improve from 0.25193
# Epoch 248/5000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3526 - acc: 0.0000e+00 - val_loss: 0.9241 - val_acc: 0.0000e+00
#
# Epoch 00248: val_loss did not improve from 0.25193
# Epoch 249/5000
# 5902/5902 [==============================] - 2s 254us/step - loss: 0.3571 - acc: 0.0000e+00 - val_loss: 0.3805 - val_acc: 0.0000e+00
#
# Epoch 00249: val_loss did not improve from 0.25193
# Epoch 250/5000
# 5902/5902 [==============================] - 2s 255us/step - loss: 0.3466 - acc: 0.0000e+00 - val_loss: 0.2900 - val_acc: 0.0000e+00
#
# Epoch 00250: val_loss did not improve from 0.25193
# Epoch 251/5000
# 5902/5902 [==============================] - 2s 259us/step - loss: 0.3402 - acc: 0.0000e+00 - val_loss: 0.3571 - val_acc: 0.0000e+00
#
# Epoch 00251: val_loss did not improve from 0.25193
# Epoch 252/5000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3431 - acc: 0.0000e+00 - val_loss: 0.2950 - val_acc: 0.0000e+00
#
# Epoch 00252: val_loss did not improve from 0.25193
# Epoch 253/5000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.3432 - acc: 0.0000e+00 - val_loss: 0.2889 - val_acc: 0.0000e+00
#
# Epoch 00253: val_loss did not improve from 0.25193
# Epoch 254/5000
# 5902/5902 [==============================] - 1s 249us/step - loss: 0.3342 - acc: 0.0000e+00 - val_loss: 0.2739 - val_acc: 0.0000e+00
#
# Epoch 00254: val_loss did not improve from 0.25193
# Epoch 255/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3403 - acc: 0.0000e+00 - val_loss: 0.2570 - val_acc: 0.0000e+00
#
# Epoch 00255: val_loss did not improve from 0.25193
# Epoch 256/5000
# 5902/5902 [==============================] - 2s 266us/step - loss: 0.3455 - acc: 0.0000e+00 - val_loss: 0.5158 - val_acc: 0.0000e+00
#
# Epoch 00256: val_loss did not improve from 0.25193
# Epoch 257/5000
# 5902/5902 [==============================] - 1s 245us/step - loss: 0.3406 - acc: 0.0000e+00 - val_loss: 0.4112 - val_acc: 0.0000e+00
#
# Epoch 00257: val_loss did not improve from 0.25193
# Epoch 258/5000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3438 - acc: 0.0000e+00 - val_loss: 0.4045 - val_acc: 0.0000e+00
#
# Epoch 00258: val_loss did not improve from 0.25193
# Epoch 259/5000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3458 - acc: 0.0000e+00 - val_loss: 0.5412 - val_acc: 0.0000e+00
#
# Epoch 00259: val_loss did not improve from 0.25193
# Epoch 260/5000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.3392 - acc: 0.0000e+00 - val_loss: 0.3871 - val_acc: 0.0000e+00
#
# Epoch 00260: val_loss did not improve from 0.25193
# Epoch 261/5000
# 5902/5902 [==============================] - 2s 257us/step - loss: 0.3314 - acc: 0.0000e+00 - val_loss: 0.7383 - val_acc: 0.0000e+00
#
# Epoch 00261: val_loss did not improve from 0.25193
# Epoch 262/5000
# 5902/5902 [==============================] - 1s 243us/step - loss: 0.3397 - acc: 0.0000e+00 - val_loss: 0.3286 - val_acc: 0.0000e+00
#
# Epoch 00262: val_loss did not improve from 0.25193
# Epoch 263/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3440 - acc: 0.0000e+00 - val_loss: 0.3080 - val_acc: 0.0000e+00
#
# Epoch 00263: val_loss did not improve from 0.25193
# Epoch 264/5000
# 5902/5902 [==============================] - 1s 233us/step - loss: 0.3367 - acc: 0.0000e+00 - val_loss: 0.4321 - val_acc: 0.0000e+00
#
# Epoch 00264: val_loss did not improve from 0.25193
# Epoch 265/5000
# 5902/5902 [==============================] - 1s 239us/step - loss: 0.3506 - acc: 0.0000e+00 - val_loss: 0.3487 - val_acc: 0.0000e+00
#
# Epoch 00265: val_loss did not improve from 0.25193
# Epoch 266/5000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3306 - acc: 0.0000e+00 - val_loss: 0.2749 - val_acc: 0.0000e+00
#
# Epoch 00266: val_loss did not improve from 0.25193
# Epoch 267/5000
# 5902/5902 [==============================] - 1s 234us/step - loss: 0.3419 - acc: 0.0000e+00 - val_loss: 0.3111 - val_acc: 0.0000e+00
#
# Epoch 00267: val_loss did not improve from 0.25193
# Epoch 268/5000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3370 - acc: 0.0000e+00 - val_loss: 0.3395 - val_acc: 0.0000e+00
#
# Epoch 00268: val_loss did not improve from 0.25193
# Epoch 269/5000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.3402 - acc: 0.0000e+00 - val_loss: 0.3832 - val_acc: 0.0000e+00
#
# Epoch 00269: val_loss did not improve from 0.25193
# Epoch 270/5000
# 5902/5902 [==============================] - 1s 230us/step - loss: 0.3521 - acc: 0.0000e+00 - val_loss: 0.2663 - val_acc: 0.0000e+00
#
# Epoch 00270: val_loss did not improve from 0.25193
# Epoch 271/5000
# 5902/5902 [==============================] - 1s 243us/step - loss: 0.3593 - acc: 0.0000e+00 - val_loss: 0.3624 - val_acc: 0.0000e+00
# Epoch 00271: val_loss did not improve from 0.25193
# Epoch 272/5000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.3407 - acc: 0.0000e+00 - val_loss: 0.2837 - val_acc: 0.0000e+00
#
# Epoch 00272: val_loss did not improve from 0.25193

# %%
def plot_train(history):
    fig, loss_ax = plt.subplots(figsize=(10,10))

    loss_ax.plot(history.history['loss'], 'y', label='train loss')
    loss_ax.plot(history.history['val_loss'], 'r', label='val loss')


    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')

    loss_ax.legend(loc='upper right')

    plt.show()
    
def test_summary(model, weight_path):
    plot_train(model[1]) #history = moedl[1]
    model[0].load_weights(weight_path) #model = model[0]
    norm_y = g + et*np.arcsinh((y_test-ep)/l)
    loss, acc = model[0].evaluate(x_test, norm_y, batch_size=32)
    #loss, acc = model[0].evaluate(x_test, y_test, batch_size=32)
    print('----- Evaluation loss and metrics -----')
    print('Test loss - RMSE : {:.5f}'.format(loss))
    
    
def save_model(model, path, gu_name):
    model_json = model[0].to_json()
    
    file_name = path+gu_name+'_model.json'
    print(file_name)
    with open(file_name, "w") as json_file : 
        json_file.write(model_json)
        
def load_model(path, gu_name):
    from keras.models import model_from_json
    
    file_name = path+gu_name+'_model.json'
    
    json_file = open(file_name, "r")
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    
    return loaded_model

# %%
def get_best_weights_path():
    result = CURR_PATH + sorted(os.listdir(CURR_PATH))[0]
    print("best model path: ", result)
    
    return result

# %%
FULL_PATH = get_best_weights_path()
# Out:
# best model path:  ./광진구_model_20181117/MLP_rmse/val_loss-0.251927.hdf5

# %%
save_model(model, CURR_PATH, gu_name)
# Out:
# ./광진구_model_20181117/MLP_rmse/광진구_model.json

# %%
test_summary(model,FULL_PATH)
# Out:
# 1640/1640 [==============================] - 0s 26us/step
# ----- Evaluation loss and metrics -----
# Test loss - RMSE : 0.24736

# %%
def prediction_plot(n_sample):
    from sklearn.metrics import r2_score

    randidx = np.random.choice(len(x_test), n_sample, replace=False)
  
    
    y_pred = model[0].predict(x_test).flatten()
    y_pred = johnson_inverse(y_pred, g, et, ep, l)
    
    _y_pred = y_pred[randidx]
    y_sample = y_test[randidx]

    fig, (ax0, ax1) = plt.subplots(1,2, figsize=(20,10))

    index = np.arange(n_sample)
    bar_width = 0.35

    opacity = 0.4
    error_config = {'ecolor': '0.3'}

    rects1 = ax0.bar(index, y_sample, bar_width, alpha=opacity, color='b',label='GT')
    rects2 = ax0.bar(index + bar_width, _y_pred, bar_width, alpha=opacity, color='r',label='Pred')

    ax0.set_xlabel('Data')
    ax0.set_ylabel('Price')
    ax0.set_title('Difference between GT/Pred - {}'.format(gu_name))
    ax0.legend()

    
    loss = rmsle_for_eval(y_test, y_pred)

    lower_bound = int(y_test.min())-10000
    higher_bound = int(y_test.max())+10000
    
    
    mape = mean_absolute_percentage_error(y_test, y_pred)
    
    
    ax1.scatter(y_test, y_pred, alpha=opacity, color='g')
    ax1.plot([lower_bound, higher_bound], [lower_bound, higher_bound], '--k')
    ax1.set_ylabel('Pred')
    ax1.set_xlabel('GT')
    ax1.set_title('Regression - {}'.format(gu_name))
    ax1.text(lower_bound+25000, lower_bound+15000, r'$R^2$={:.2f}, RMSLE={:.5f}'.format(r2_score(y_test, y_pred),loss))
    ax1.set_xlim([lower_bound, higher_bound])
    ax1.set_ylim([lower_bound, higher_bound])
    
    fig.tight_layout()
    plt.show()
    
    diff = abs(y_pred-y_test)
    print('Max difference : {:.2f} 만원'.format(diff.max()))
    print('Mean difference : {:.2f} 만원'.format(diff.mean()))
    print('--------')
    print('Avg Price of {}: {:.2f} 만원'.format(gu_name,y_test.mean()))
    print('--------')
    print('R2 Coefficient : {:.3f}'.format(r2_score(y_test, y_pred)))
    print('RMLSE loss : {:.4f}'.format(loss))
    print('MAPE : {:.4f}' .format(mape))
    return y_pred, diff

# %%
y_pred, diff = prediction_plot(10)
# Out:
# Max difference : 41993.05 만원
# Mean difference : 4379.46 만원
# --------
# Avg Price of 광진구: 62860.51 만원
# --------
# R2 Coefficient : 0.916
# RMLSE loss : 0.0829
# MAPE : 6.1757

# %%
def run_loaded_model(model, x_train, y_train, batch_size, max_epochs):
    model.compile(optimizer=adam,
                  loss=rmse,
                  metrics=['accuracy'])
    model.summary()
    
    checkloss = create_checkpoint(MODEL_NAME)
    
    history = model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=max_epochs,
                  validation_split = 0.1,
                  shuffle=True,
                  callbacks=[checkloss, early_stopping])
    
    return model, history

# %%
loaded_model = load_model(CURR_PATH, gu_name)
FULL_PATH = get_best_weights_path()
loaded_model.load_weights(FULL_PATH)
# Out:
# best model path:  ./광진구_model_20181117/MLP_rmse/val_loss-0.236131.hdf5

# %%
model = run_loaded_model(loaded_model, x_train, yt, 16, 1000)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 128)               14720
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                528
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16)                64
# _________________________________________________________________
# dense_11 (Dense)             (None, 8)                 136
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8)                 32
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 26,721
# Trainable params: 26,225
# Non-trainable params: 496
# _________________________________________________________________
# Train on 5902 samples, validate on 656 samples
# Epoch 1/1000
# 5902/5902 [==============================] - 3s 562us/step - loss: 0.3665 - acc: 0.0000e+00 - val_loss: 0.2774 - val_acc: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.27739, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.277386.hdf5
# Epoch 2/1000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.3461 - acc: 0.0000e+00 - val_loss: 0.3784 - val_acc: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 0.27739
# Epoch 3/1000
# 5902/5902 [==============================] - 2s 261us/step - loss: 0.3438 - acc: 0.0000e+00 - val_loss: 0.3158 - val_acc: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 0.27739
# Epoch 4/1000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.3400 - acc: 0.0000e+00 - val_loss: 0.3117 - val_acc: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 0.27739
# Epoch 5/1000
# 5902/5902 [==============================] - 1s 247us/step - loss: 0.3419 - acc: 0.0000e+00 - val_loss: 0.3017 - val_acc: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.27739
# Epoch 6/1000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.3448 - acc: 0.0000e+00 - val_loss: 0.3056 - val_acc: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 0.27739
# Epoch 7/1000
# 5902/5902 [==============================] - 1s 240us/step - loss: 0.3512 - acc: 0.0000e+00 - val_loss: 0.2573 - val_acc: 0.0000e+00
#
# Epoch 00007: val_loss improved from 0.27739 to 0.25728, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.257282.hdf5
# Epoch 8/1000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3435 - acc: 0.0000e+00 - val_loss: 0.3196 - val_acc: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 0.25728
# Epoch 9/1000
# 5902/5902 [==============================] - 2s 259us/step - loss: 0.3608 - acc: 0.0000e+00 - val_loss: 0.2590 - val_acc: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 0.25728
# Epoch 10/1000
# 5902/5902 [==============================] - 1s 248us/step - loss: 0.3360 - acc: 0.0000e+00 - val_loss: 0.2669 - val_acc: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 0.25728
# Epoch 11/1000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3415 - acc: 0.0000e+00 - val_loss: 0.4196 - val_acc: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 0.25728
# Epoch 12/1000
# 5902/5902 [==============================] - 2s 264us/step - loss: 0.3374 - acc: 0.0000e+00 - val_loss: 0.4737 - val_acc: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 0.25728
# Epoch 13/1000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3439 - acc: 0.0000e+00 - val_loss: 0.5655 - val_acc: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 0.25728
# Epoch 14/1000
# 5902/5902 [==============================] - 2s 300us/step - loss: 0.3406 - acc: 0.0000e+00 - val_loss: 0.3142 - val_acc: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 0.25728
# Epoch 15/1000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.3509 - acc: 0.0000e+00 - val_loss: 0.2692 - val_acc: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 0.25728
# Epoch 16/1000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3480 - acc: 0.0000e+00 - val_loss: 0.2575 - val_acc: 0.0000e+00
#
# Epoch 00016: val_loss did not improve from 0.25728
# Epoch 17/1000
# 5902/5902 [==============================] - 1s 219us/step - loss: 0.3478 - acc: 0.0000e+00 - val_loss: 0.4082 - val_acc: 0.0000e+00
#
# Epoch 00017: val_loss did not improve from 0.25728
# Epoch 18/1000
# 5902/5902 [==============================] - 1s 213us/step - loss: 0.3401 - acc: 0.0000e+00 - val_loss: 0.3572 - val_acc: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 0.25728
# Epoch 19/1000
# 5902/5902 [==============================] - 1s 224us/step - loss: 0.3422 - acc: 0.0000e+00 - val_loss: 0.2658 - val_acc: 0.0000e+00
#
# Epoch 00019: val_loss did not improve from 0.25728
# Epoch 20/1000
# 5902/5902 [==============================] - 1s 215us/step - loss: 0.3466 - acc: 0.0000e+00 - val_loss: 0.5706 - val_acc: 0.0000e+00
#
# Epoch 00020: val_loss did not improve from 0.25728
# Epoch 21/1000
# 5902/5902 [==============================] - 1s 220us/step - loss: 0.3382 - acc: 0.0000e+00 - val_loss: 0.3338 - val_acc: 0.0000e+00
#
# Epoch 00021: val_loss did not improve from 0.25728
# Epoch 22/1000
# 5902/5902 [==============================] - 1s 230us/step - loss: 0.3516 - acc: 0.0000e+00 - val_loss: 0.4896 - val_acc: 0.0000e+00
#
# Epoch 00022: val_loss did not improve from 0.25728
# Epoch 23/1000
# 5902/5902 [==============================] - 1s 226us/step - loss: 0.3505 - acc: 0.0000e+00 - val_loss: 0.2693 - val_acc: 0.0000e+00
#
# Epoch 00023: val_loss did not improve from 0.25728
# Epoch 24/1000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.3485 - acc: 0.0000e+00 - val_loss: 0.3498 - val_acc: 0.0000e+00
#
# Epoch 00024: val_loss did not improve from 0.25728
# Epoch 25/1000
# 5902/5902 [==============================] - 1s 227us/step - loss: 0.3475 - acc: 0.0000e+00 - val_loss: 0.3055 - val_acc: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 0.25728
# Epoch 26/1000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3431 - acc: 0.0000e+00 - val_loss: 0.4670 - val_acc: 0.0000e+00
#
# Epoch 00026: val_loss did not improve from 0.25728
# Epoch 27/1000
# 5902/5902 [==============================] - 1s 211us/step - loss: 0.3343 - acc: 0.0000e+00 - val_loss: 0.3598 - val_acc: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 0.25728
# Epoch 28/1000
# 5902/5902 [==============================] - 1s 207us/step - loss: 0.3497 - acc: 0.0000e+00 - val_loss: 0.2938 - val_acc: 0.0000e+00
#
# Epoch 00028: val_loss did not improve from 0.25728
# Epoch 29/1000
# 5902/5902 [==============================] - 1s 208us/step - loss: 0.3447 - acc: 0.0000e+00 - val_loss: 0.2988 - val_acc: 0.0000e+00
#
# Epoch 00029: val_loss did not improve from 0.25728
# Epoch 30/1000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3379 - acc: 0.0000e+00 - val_loss: 0.3297 - val_acc: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 0.25728
# Epoch 31/1000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3529 - acc: 0.0000e+00 - val_loss: 0.2640 - val_acc: 0.0000e+00
#
# Epoch 00031: val_loss did not improve from 0.25728
# Epoch 32/1000
# 5902/5902 [==============================] - 2s 275us/step - loss: 0.3434 - acc: 0.0000e+00 - val_loss: 0.3456 - val_acc: 0.0000e+00
#
# Epoch 00032: val_loss did not improve from 0.25728
# Epoch 33/1000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3473 - acc: 0.0000e+00 - val_loss: 0.3084 - val_acc: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 0.25728
# Epoch 34/1000
# 5902/5902 [==============================] - 1s 249us/step - loss: 0.3546 - acc: 0.0000e+00 - val_loss: 0.4469 - val_acc: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 0.25728
# Epoch 35/1000
# 5902/5902 [==============================] - 2s 259us/step - loss: 0.3382 - acc: 0.0000e+00 - val_loss: 0.2590 - val_acc: 0.0000e+00
#
# Epoch 00035: val_loss did not improve from 0.25728
# Epoch 36/1000
# 5902/5902 [==============================] - 1s 250us/step - loss: 0.3303 - acc: 0.0000e+00 - val_loss: 0.2586 - val_acc: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 0.25728
# Epoch 37/1000
# 5902/5902 [==============================] - 2s 269us/step - loss: 0.3324 - acc: 0.0000e+00 - val_loss: 0.2632 - val_acc: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 0.25728
# Epoch 38/1000
# 5902/5902 [==============================] - 2s 263us/step - loss: 0.3340 - acc: 0.0000e+00 - val_loss: 0.3536 - val_acc: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 0.25728
# Epoch 39/1000
# 5902/5902 [==============================] - 2s 263us/step - loss: 0.3392 - acc: 0.0000e+00 - val_loss: 0.3140 - val_acc: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 0.25728
# Epoch 40/1000
# 5902/5902 [==============================] - 2s 264us/step - loss: 0.3422 - acc: 0.0000e+00 - val_loss: 0.2648 - val_acc: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 0.25728
# Epoch 41/1000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3522 - acc: 0.0000e+00 - val_loss: 0.2810 - val_acc: 0.0000e+00
#
# Epoch 00041: val_loss did not improve from 0.25728
# Epoch 42/1000
# 5902/5902 [==============================] - 2s 273us/step - loss: 0.3413 - acc: 0.0000e+00 - val_loss: 0.2599 - val_acc: 0.0000e+00
#
# Epoch 00042: val_loss did not improve from 0.25728
# Epoch 43/1000
# 5902/5902 [==============================] - 2s 266us/step - loss: 0.3420 - acc: 0.0000e+00 - val_loss: 0.6937 - val_acc: 0.0000e+00
#
# Epoch 00043: val_loss did not improve from 0.25728
# Epoch 44/1000
# 5902/5902 [==============================] - 2s 266us/step - loss: 0.3581 - acc: 0.0000e+00 - val_loss: 0.2572 - val_acc: 0.0000e+00
#
# Epoch 00044: val_loss improved from 0.25728 to 0.25717, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.257169.hdf5
# Epoch 45/1000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3439 - acc: 0.0000e+00 - val_loss: 0.3158 - val_acc: 0.0000e+00
#
# Epoch 00045: val_loss did not improve from 0.25717
# Epoch 46/1000
# 5902/5902 [==============================] - 2s 264us/step - loss: 0.3421 - acc: 0.0000e+00 - val_loss: 0.5341 - val_acc: 0.0000e+00
#
# Epoch 00046: val_loss did not improve from 0.25717
# Epoch 47/1000
# 5902/5902 [==============================] - 2s 261us/step - loss: 0.3397 - acc: 0.0000e+00 - val_loss: 0.3999 - val_acc: 0.0000e+00
#
# Epoch 00047: val_loss did not improve from 0.25717
# Epoch 48/1000
# 5902/5902 [==============================] - 2s 254us/step - loss: 0.3398 - acc: 0.0000e+00 - val_loss: 0.3878 - val_acc: 0.0000e+00
#
# Epoch 00048: val_loss did not improve from 0.25717
# Epoch 49/1000
# 5902/5902 [==============================] - 1s 246us/step - loss: 0.3396 - acc: 0.0000e+00 - val_loss: 0.2662 - val_acc: 0.0000e+00
#
# Epoch 00049: val_loss did not improve from 0.25717
# Epoch 50/1000
# 5902/5902 [==============================] - 1s 245us/step - loss: 0.3415 - acc: 0.0000e+00 - val_loss: 0.2907 - val_acc: 0.0000e+00
#
# Epoch 00050: val_loss did not improve from 0.25717
# Epoch 51/1000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3465 - acc: 0.0000e+00 - val_loss: 0.3027 - val_acc: 0.0000e+00
#
# Epoch 00051: val_loss did not improve from 0.25717
# Epoch 52/1000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3444 - acc: 0.0000e+00 - val_loss: 0.2518 - val_acc: 0.0000e+00
#
# Epoch 00052: val_loss improved from 0.25717 to 0.25177, saving model to ./광진구_model_20181117/MLP_rmse/val_loss-0.251769.hdf5
# Epoch 53/1000
# 5902/5902 [==============================] - 1s 237us/step - loss: 0.3397 - acc: 0.0000e+00 - val_loss: 0.2558 - val_acc: 0.0000e+00
#
# Epoch 00053: val_loss did not improve from 0.25177
# Epoch 54/1000
# 5902/5902 [==============================] - 1s 233us/step - loss: 0.3462 - acc: 0.0000e+00 - val_loss: 0.3255 - val_acc: 0.0000e+00
#
# Epoch 00054: val_loss did not improve from 0.25177
# Epoch 55/1000
# 5902/5902 [==============================] - 1s 243us/step - loss: 0.3517 - acc: 0.0000e+00 - val_loss: 0.2752 - val_acc: 0.0000e+00
#
# Epoch 00055: val_loss did not improve from 0.25177
# Epoch 56/1000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3381 - acc: 0.0000e+00 - val_loss: 0.4838 - val_acc: 0.0000e+00
#
# Epoch 00056: val_loss did not improve from 0.25177
# Epoch 57/1000
# 5902/5902 [==============================] - 1s 233us/step - loss: 0.3382 - acc: 0.0000e+00 - val_loss: 0.2621 - val_acc: 0.0000e+00
#
# Epoch 00057: val_loss did not improve from 0.25177
# Epoch 58/1000
# 5902/5902 [==============================] - 1s 223us/step - loss: 0.3406 - acc: 0.0000e+00 - val_loss: 0.5425 - val_acc: 0.0000e+00
#
# Epoch 00058: val_loss did not improve from 0.25177
# Epoch 59/1000
# 5902/5902 [==============================] - 1s 232us/step - loss: 0.3442 - acc: 0.0000e+00 - val_loss: 0.2526 - val_acc: 0.0000e+00
#
# Epoch 00059: val_loss did not improve from 0.25177
# Epoch 60/1000
# 5902/5902 [==============================] - 1s 251us/step - loss: 0.3418 - acc: 0.0000e+00 - val_loss: 0.2778 - val_acc: 0.0000e+00
#
# Epoch 00060: val_loss did not improve from 0.25177
# Epoch 61/1000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.3420 - acc: 0.0000e+00 - val_loss: 0.2640 - val_acc: 0.0000e+00
#
# Epoch 00061: val_loss did not improve from 0.25177
# Epoch 62/1000
# 5902/5902 [==============================] - 1s 233us/step - loss: 0.3350 - acc: 0.0000e+00 - val_loss: 0.2799 - val_acc: 0.0000e+00
#
# Epoch 00062: val_loss did not improve from 0.25177
# Epoch 63/1000
# 5902/5902 [==============================] - 2s 255us/step - loss: 0.3396 - acc: 0.0000e+00 - val_loss: 0.3117 - val_acc: 0.0000e+00
#
# Epoch 00063: val_loss did not improve from 0.25177
# Epoch 64/1000
# 5902/5902 [==============================] - 2s 265us/step - loss: 0.3347 - acc: 0.0000e+00 - val_loss: 0.6518 - val_acc: 0.0000e+00
#
# Epoch 00064: val_loss did not improve from 0.25177
# Epoch 65/1000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.3539 - acc: 0.0000e+00 - val_loss: 0.2603 - val_acc: 0.0000e+00
#
# Epoch 00065: val_loss did not improve from 0.25177
# Epoch 66/1000
# 5902/5902 [==============================] - 1s 237us/step - loss: 0.3375 - acc: 0.0000e+00 - val_loss: 0.4145 - val_acc: 0.0000e+00
#
# Epoch 00066: val_loss did not improve from 0.25177
# Epoch 67/1000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3387 - acc: 0.0000e+00 - val_loss: 0.3591 - val_acc: 0.0000e+00
#
# Epoch 00067: val_loss did not improve from 0.25177
# Epoch 68/1000
# 5902/5902 [==============================] - 2s 274us/step - loss: 0.3324 - acc: 0.0000e+00 - val_loss: 0.3633 - val_acc: 0.0000e+00
#
# Epoch 00068: val_loss did not improve from 0.25177
# Epoch 69/1000
# 5902/5902 [==============================] - 2s 284us/step - loss: 0.3476 - acc: 0.0000e+00 - val_loss: 0.2677 - val_acc: 0.0000e+00
#
# Epoch 00069: val_loss did not improve from 0.25177
# Epoch 70/1000
# 5902/5902 [==============================] - 2s 266us/step - loss: 0.3437 - acc: 0.0000e+00 - val_loss: 0.2653 - val_acc: 0.0000e+00
#
# Epoch 00070: val_loss did not improve from 0.25177
# Epoch 71/1000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3421 - acc: 0.0000e+00 - val_loss: 0.2600 - val_acc: 0.0000e+00
#
# Epoch 00071: val_loss did not improve from 0.25177
# Epoch 72/1000
# 5902/5902 [==============================] - 2s 269us/step - loss: 0.3458 - acc: 0.0000e+00 - val_loss: 0.2691 - val_acc: 0.0000e+00
#
# Epoch 00072: val_loss did not improve from 0.25177
# Epoch 73/1000
# 5902/5902 [==============================] - 2s 261us/step - loss: 0.3407 - acc: 0.0000e+00 - val_loss: 0.2608 - val_acc: 0.0000e+00
#
# Epoch 00073: val_loss did not improve from 0.25177
# Epoch 74/1000
# 5902/5902 [==============================] - 2s 279us/step - loss: 0.3435 - acc: 0.0000e+00 - val_loss: 0.5141 - val_acc: 0.0000e+00
#
# Epoch 00074: val_loss did not improve from 0.25177
# Epoch 75/1000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3508 - acc: 0.0000e+00 - val_loss: 0.2929 - val_acc: 0.0000e+00
#
# Epoch 00075: val_loss did not improve from 0.25177
# Epoch 76/1000
# 5902/5902 [==============================] - 2s 261us/step - loss: 0.3368 - acc: 0.0000e+00 - val_loss: 0.2623 - val_acc: 0.0000e+00
#
# Epoch 00076: val_loss did not improve from 0.25177
# Epoch 77/1000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3433 - acc: 0.0000e+00 - val_loss: 0.2625 - val_acc: 0.0000e+00
#
# Epoch 00077: val_loss did not improve from 0.25177
# Epoch 78/1000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.3414 - acc: 0.0000e+00 - val_loss: 0.2607 - val_acc: 0.0000e+00
#
# Epoch 00078: val_loss did not improve from 0.25177
# Epoch 79/1000
# 5902/5902 [==============================] - 2s 259us/step - loss: 0.3344 - acc: 0.0000e+00 - val_loss: 0.2783 - val_acc: 0.0000e+00
#
# Epoch 00079: val_loss did not improve from 0.25177
# Epoch 80/1000
# 5902/5902 [==============================] - 2s 261us/step - loss: 0.3337 - acc: 0.0000e+00 - val_loss: 0.3738 - val_acc: 0.0000e+00
#
# Epoch 00080: val_loss did not improve from 0.25177
# Epoch 81/1000
# 5902/5902 [==============================] - 2s 263us/step - loss: 0.3356 - acc: 0.0000e+00 - val_loss: 0.5706 - val_acc: 0.0000e+00
#
# Epoch 00081: val_loss did not improve from 0.25177
# Epoch 82/1000
# 5902/5902 [==============================] - 2s 266us/step - loss: 0.3345 - acc: 0.0000e+00 - val_loss: 0.2993 - val_acc: 0.0000e+00
#
# Epoch 00082: val_loss did not improve from 0.25177
# Epoch 83/1000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.3404 - acc: 0.0000e+00 - val_loss: 0.2682 - val_acc: 0.0000e+00
#
# Epoch 00083: val_loss did not improve from 0.25177
# Epoch 84/1000
# 5902/5902 [==============================] - 2s 256us/step - loss: 0.3404 - acc: 0.0000e+00 - val_loss: 0.3794 - val_acc: 0.0000e+00
#
# Epoch 00084: val_loss did not improve from 0.25177
# Epoch 85/1000
# 5902/5902 [==============================] - 2s 265us/step - loss: 0.3459 - acc: 0.0000e+00 - val_loss: 0.2894 - val_acc: 0.0000e+00
#
# Epoch 00085: val_loss did not improve from 0.25177
# Epoch 86/1000
# 5902/5902 [==============================] - 2s 258us/step - loss: 0.3377 - acc: 0.0000e+00 - val_loss: 0.3786 - val_acc: 0.0000e+00
#
# Epoch 00086: val_loss did not improve from 0.25177
# Epoch 87/1000
# 5902/5902 [==============================] - 2s 257us/step - loss: 0.3333 - acc: 0.0000e+00 - val_loss: 0.3122 - val_acc: 0.0000e+00
#
# Epoch 00087: val_loss did not improve from 0.25177
# Epoch 88/1000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3538 - acc: 0.0000e+00 - val_loss: 0.3463 - val_acc: 0.0000e+00
#
# Epoch 00088: val_loss did not improve from 0.25177
# Epoch 89/1000
# 5902/5902 [==============================] - 2s 267us/step - loss: 0.3527 - acc: 0.0000e+00 - val_loss: 0.2531 - val_acc: 0.0000e+00
#
# Epoch 00089: val_loss did not improve from 0.25177
# Epoch 90/1000
# 5902/5902 [==============================] - 1s 245us/step - loss: 0.3357 - acc: 0.0000e+00 - val_loss: 0.2707 - val_acc: 0.0000e+00
#
# Epoch 00090: val_loss did not improve from 0.25177
# Epoch 91/1000
# 5902/5902 [==============================] - 1s 252us/step - loss: 0.3498 - acc: 0.0000e+00 - val_loss: 0.2772 - val_acc: 0.0000e+00
#
# Epoch 00091: val_loss did not improve from 0.25177
# Epoch 92/1000
# 5902/5902 [==============================] - 2s 260us/step - loss: 0.3401 - acc: 0.0000e+00 - val_loss: 0.2938 - val_acc: 0.0000e+00
#
# Epoch 00092: val_loss did not improve from 0.25177
# Epoch 93/1000
# 5902/5902 [==============================] - 1s 250us/step - loss: 0.3397 - acc: 0.0000e+00 - val_loss: 0.2619 - val_acc: 0.0000e+00
#
# Epoch 00093: val_loss did not improve from 0.25177
# Epoch 94/1000
# 5902/5902 [==============================] - 2s 259us/step - loss: 0.3468 - acc: 0.0000e+00 - val_loss: 0.2745 - val_acc: 0.0000e+00
#
# Epoch 00094: val_loss did not improve from 0.25177
# Epoch 95/1000
# 5902/5902 [==============================] - 2s 263us/step - loss: 0.3315 - acc: 0.0000e+00 - val_loss: 0.2574 - val_acc: 0.0000e+00
#
# Epoch 00095: val_loss did not improve from 0.25177
# Epoch 96/1000
# 5902/5902 [==============================] - 1s 244us/step - loss: 0.3442 - acc: 0.0000e+00 - val_loss: 0.3571 - val_acc: 0.0000e+00
#
# Epoch 00096: val_loss did not improve from 0.25177
# Epoch 97/1000
# 5902/5902 [==============================] - 2s 254us/step - loss: 0.3422 - acc: 0.0000e+00 - val_loss: 0.3221 - val_acc: 0.0000e+00
#
# Epoch 00097: val_loss did not improve from 0.25177
# Epoch 98/1000
# 5902/5902 [==============================] - 1s 242us/step - loss: 0.3449 - acc: 0.0000e+00 - val_loss: 0.3197 - val_acc: 0.0000e+00
#
# Epoch 00098: val_loss did not improve from 0.25177
# Epoch 99/1000
# 5902/5902 [==============================] - 2s 259us/step - loss: 0.3402 - acc: 0.0000e+00 - val_loss: 0.2936 - val_acc: 0.0000e+00
#
# Epoch 00099: val_loss did not improve from 0.25177
# Epoch 100/1000
# 5902/5902 [==============================] - 1s 249us/step - loss: 0.3348 - acc: 0.0000e+00 - val_loss: 0.2587 - val_acc: 0.0000e+00
#
# Epoch 00100: val_loss did not improve from 0.25177
# Epoch 101/1000
# 5902/5902 [==============================] - 1s 253us/step - loss: 0.3427 - acc: 0.0000e+00 - val_loss: 0.3458 - val_acc: 0.0000e+00
#
# Epoch 00101: val_loss did not improve from 0.25177
# Epoch 102/1000
# 5902/5902 [==============================] - 1s 241us/step - loss: 0.3320 - acc: 0.0000e+00 - val_loss: 0.2742 - val_acc: 0.0000e+00
#
# Epoch 00102: val_loss did not improve from 0.25177

# %%
test_summary(model,FULL_PATH)
# Out:
# 1640/1640 [==============================] - 0s 54us/step
# ----- Evaluation loss and metrics -----
# Test loss - RMSE : 0.21574

# %%
y_pred, diff = prediction_plot(10)
# Out:
# Max difference : 30957.06 만원
# Mean difference : 3288.93 만원
# --------
# Avg Price of 광진구: 62860.51 만원
# --------
# R2 Coefficient : 0.958
# RMLSE loss : 0.0669
# MAPE : 5.0633
