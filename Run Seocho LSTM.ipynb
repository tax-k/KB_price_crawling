# %%
import math

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="darkgrid")
import matplotlib.pyplot as plt
import os

# %%
data = pd.read_csv('./extract_seoul.csv')

# %%
data = data.drop(['Unnamed: 0'],1)

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 30 columns):
# Date               188 non-null datetime64[ns]
# Total              188 non-null float64
# Seoul              188 non-null float64
# Northern seoul     188 non-null float64
# Gangbuk-gu         188 non-null float64
# Gwangjin-gu        188 non-null float64
# Nowon-gu           188 non-null float64
# Dobong-gu          188 non-null float64
# Dongdaemun-gu      188 non-null float64
# Mapo-gu            188 non-null float64
# Seodaemun-gu       188 non-null float64
# Seongdong-gu       188 non-null float64
# Seongbuk-gu        188 non-null float64
# Yongsan-gu         188 non-null float64
# Eunpyeong-gu       188 non-null float64
# Jongno-gu          188 non-null float64
# Jung-gu            188 non-null float64
# Jungnang-gu        188 non-null float64
# Southern Seoul     188 non-null float64
# Gangnam-gu         188 non-null float64
# Gangdong-gu        188 non-null float64
# Gangseo-gu         188 non-null float64
# Gwanak-gu          188 non-null float64
# Guro-gu            188 non-null float64
# Geumcheon-gu       188 non-null float64
# Dongjak-gu         188 non-null float64
# Seocho-gu          188 non-null float64
# Songpa-gu          188 non-null float64
# Yangcheon-gu       188 non-null float64
# Yeongdeungpo-gu    188 non-null float64
# dtypes: datetime64[ns](1), float64(29)
# memory usage: 44.1 KB

# %%
GU_ENG_NAME = ''

# %% [markdown]
# ### Dict 관련 함수 선언

# %%
def create_dict(a, b):
    d = dict()
    #갯수 다르면
    if len(a)-len(b) != 0:
        for i in range(len(a)-len(b)):
            b.append(None)
    #갯수 같으면
    for j in range(len(a)):
        d[a[j]] = b[j]
    return d

# %%
def find_val_using_key(dic, key):
    if key in dic:
        return dic[key]
    else:
        print('404 not found')
        return dic['서울']

# %%
def find_key_using_val(dic, val):
    return [k for k, v in dic.items() if v == val][0]

# %% [markdown]
# ### 원하는 구만 선택하기

# %%
def select_gu_data(df, gu_name):
    gu_name += '-gu'
    global GU_ENG_NAME
    
    GU_ENG_NAME = gu_name
    
    return df[['Date', gu_name]]

# %%
BASE_PATH = './TimeSeries/'
MODEL_NAME = 'LSTM'

# %%
gangnam = select_gu_data(data, 'Seocho')
print(GU_ENG_NAME)
# Out:
# Seocho-gu

# %%
plt.figure(figsize = (15, 5))
ax = sns.lineplot(x="Date", y=GU_ENG_NAME, data=gangnam)

# %% [markdown]
# ### Keras import

# %%
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle

# %%
gangnam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 2 columns):
# Date         188 non-null datetime64[ns]
# Seocho-gu    188 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.0 KB

# %%
mask = pd.to_datetime('2010-01-01')
tmp = gangnam.loc[:][gangnam['Date'] >= mask]

# %%
gangnam_tmp = tmp.drop('Date', 1)

# %%
gangnam_tmp
# Out:
#      Seocho-gu
# 84    0.323217
# 85    1.178676
# 86    0.154842
# 87   -0.091265
# 88   -0.366036
# 89   -0.527977
# 90   -0.181004
# 91   -0.107197
# 92   -0.118016
# 93   -0.073612
# 94    0.019474
# 95    0.333810
# 96    0.473431
# 97    0.930963
# 98    0.168474
# 99    0.070206
# 100  -0.041734
# 101  -0.078915
# 102  -0.021966
# 103   0.006056
# 104   0.117910
# 105  -0.039522
# 106  -0.282155
# 107  -0.154114
# 108  -0.250591
# 109  -0.087833
# 110  -0.284927
# 111  -0.516308
# 112  -0.633916
# 113  -0.606338
# ..         ...
# 158   0.001655
# 159   0.092694
# 160   0.608634
# 161   0.714151
# 162   0.766583
# 163   0.878363
# 164   0.659669
# 165   1.041506
# 166   0.522451
# 167  -0.112410
# 168  -0.270748
# 169  -0.019880
# 170   0.239952
# 171   0.243877
# 172   0.325321
# 173   0.915841
# 174   0.861213
# 175   1.169829
# 176  -0.024100
# 177   0.359388
# 178   0.477157
# 179   0.816347
# 180   1.039073
# 181   0.929877
# 182   1.445946
# 183   0.579427
# 184   0.190921
# 185  -0.014436
# 186   0.000101
# 187   1.040402
#
# [104 rows x 1 columns]

# %% [markdown]
# ### Normalize

# %%
scaler = MinMaxScaler(feature_range = (0, 1))
dataset = scaler.fit_transform(gangnam_tmp)

# %%
dataset[:5]
# Out:
# array([[0.54935058],
#        [0.89272117],
#        [0.48176684],
#        [0.3829826 ],
#        [0.27269293]])

# %%
TRAIN_SIZE = 0.80

train_size = int(len(dataset) * TRAIN_SIZE)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size], dataset[train_size:len(dataset)]
print("Number of entries (training set, test set): " + str((len(train), len(test))))
# Out:
# Number of entries (training set, test set): (83, 21)

# %%
def create_dataset(dataset, window_size = 1):
    data_X, data_Y = [], []
    for i in range(len(dataset) - window_size - 1):
        a = dataset[i:(i + window_size), 0]
        data_X.append(a)
        data_Y.append(dataset[i + window_size, 0])
    return(np.array(data_X), np.array(data_Y))

# %%
window_size = 4

# %%
train_X, train_Y = create_dataset(train, window_size)
test_X, test_Y = create_dataset(test, window_size)

whole_X, whole_Y = create_dataset(dataset, window_size)
print("Original training data shape:")
print(whole_X.shape)
print(whole_Y.shape)
# Out:
# Original training data shape:
# (99, 4)
# (99,)

# %%
train_Y[:10]
# Out:
# array([0.27269293, 0.20769186, 0.34696253, 0.37658777, 0.37224517,
#        0.39006837, 0.42743189, 0.55360252, 0.60964457, 0.79329202])

# %%
# Reshape the input data into appropriate form for Keras.
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))
whole_X = np.reshape(whole_X, (whole_X.shape[0], 1, whole_X.shape[1]))

print("New training data shape:")
print(train_X.shape)
# Out:
# New training data shape:
# (78, 1, 4)

# %%
MODEL_PATH = ''


if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

def create_checkpoint(model_name):
    global MODEL_PATH
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    print("Model_path : ", MODEL_PATH)
    
    MODEL_PATH = MODEL_PATH + "/" + GU_ENG_NAME
    
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, 'val_loss-{val_loss:.6f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

early_stopping = EarlyStopping(monitor='val_loss', patience=50)

# %%
def Model(train_X, train_Y, window_size = 1):
    model = Sequential()
    model.add(LSTM(12,return_sequences=True, input_shape = (1, window_size)))
    model.add(LSTM(12,return_sequences=True))
    model.add(LSTM(12))
    model.add(Dense(1))
    
    adam = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=1e-6, amsgrad=False)
    checkloss = create_checkpoint(MODEL_NAME)
    
    model.compile(loss = "mean_squared_error", 
                  optimizer = adam)

    model.summary()
    
    checkloss = create_checkpoint(MODEL_NAME)
    
    history = model.fit(train_X, train_Y, epochs = 500 ,batch_size=2, validation_split = 0.1,
                        shuffle=True,
                        callbacks=[checkloss, early_stopping])
    
    return model, history

# %%
model = Model(train_X, train_Y, window_size)
# Out:
# Model_path :  ./TimeSeries/LSTM
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 1, 12)             816
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 1, 12)             1200
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 12)                1200
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 3,229
# Trainable params: 3,229
# Non-trainable params: 0
# _________________________________________________________________
# Model_path :  ./TimeSeries/LSTM
# Train on 70 samples, validate on 8 samples
# Epoch 1/500
# 70/70 [==============================] - 3s 36ms/step - loss: 0.1983 - val_loss: 0.3987
#
# Epoch 00001: val_loss improved from inf to 0.39873, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.398729.hdf5
# Epoch 2/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.1623 - val_loss: 0.3366
#
# Epoch 00002: val_loss improved from 0.39873 to 0.33660, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.336603.hdf5
# Epoch 3/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.1231 - val_loss: 0.2589
#
# Epoch 00003: val_loss improved from 0.33660 to 0.25885, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.258855.hdf5
# Epoch 4/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0776 - val_loss: 0.1733
#
# Epoch 00004: val_loss improved from 0.25885 to 0.17326, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.173259.hdf5
# Epoch 5/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0395 - val_loss: 0.0897
#
# Epoch 00005: val_loss improved from 0.17326 to 0.08972, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.089723.hdf5
# Epoch 6/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0225 - val_loss: 0.0490
#
# Epoch 00006: val_loss improved from 0.08972 to 0.04901, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.049011.hdf5
# Epoch 7/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0418
#
# Epoch 00007: val_loss improved from 0.04901 to 0.04184, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.041840.hdf5
# Epoch 8/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0197 - val_loss: 0.0431
#
# Epoch 00008: val_loss did not improve from 0.04184
# Epoch 9/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0191 - val_loss: 0.0368
#
# Epoch 00009: val_loss improved from 0.04184 to 0.03678, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.036783.hdf5
# Epoch 10/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0188 - val_loss: 0.0380
#
# Epoch 00010: val_loss did not improve from 0.03678
# Epoch 11/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0382
#
# Epoch 00011: val_loss did not improve from 0.03678
# Epoch 12/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0179 - val_loss: 0.0354
#
# Epoch 00012: val_loss improved from 0.03678 to 0.03544, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.035438.hdf5
# Epoch 13/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0344
#
# Epoch 00013: val_loss improved from 0.03544 to 0.03441, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.034411.hdf5
# Epoch 14/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0367
#
# Epoch 00014: val_loss did not improve from 0.03441
# Epoch 15/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0171 - val_loss: 0.0312
#
# Epoch 00015: val_loss improved from 0.03441 to 0.03120, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.031200.hdf5
# Epoch 16/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0326
#
# Epoch 00016: val_loss did not improve from 0.03120
# Epoch 17/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0164 - val_loss: 0.0324
#
# Epoch 00017: val_loss did not improve from 0.03120
# Epoch 18/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0297
#
# Epoch 00018: val_loss improved from 0.03120 to 0.02975, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.029747.hdf5
# Epoch 19/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0159 - val_loss: 0.0356
#
# Epoch 00019: val_loss did not improve from 0.02975
# Epoch 20/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0265
#
# Epoch 00020: val_loss improved from 0.02975 to 0.02654, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.026541.hdf5
# Epoch 21/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0152 - val_loss: 0.0324
#
# Epoch 00021: val_loss did not improve from 0.02654
# Epoch 22/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0149 - val_loss: 0.0254
#
# Epoch 00022: val_loss improved from 0.02654 to 0.02539, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.025393.hdf5
# Epoch 23/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0271
#
# Epoch 00023: val_loss did not improve from 0.02539
# Epoch 24/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.0241
#
# Epoch 00024: val_loss improved from 0.02539 to 0.02411, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.024108.hdf5
# Epoch 25/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0143 - val_loss: 0.0243
#
# Epoch 00025: val_loss did not improve from 0.02411
# Epoch 26/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0143 - val_loss: 0.0246
#
# Epoch 00026: val_loss did not improve from 0.02411
# Epoch 27/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0225
#
# Epoch 00027: val_loss improved from 0.02411 to 0.02255, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.022547.hdf5
# Epoch 28/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0138 - val_loss: 0.0236
#
# Epoch 00028: val_loss did not improve from 0.02255
# Epoch 29/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0225
#
# Epoch 00029: val_loss improved from 0.02255 to 0.02254, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.022545.hdf5
# Epoch 30/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0134 - val_loss: 0.0250
#
# Epoch 00030: val_loss did not improve from 0.02254
# Epoch 31/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0220
#
# Epoch 00031: val_loss improved from 0.02254 to 0.02199, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.021985.hdf5
# Epoch 32/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0134 - val_loss: 0.0233
#
# Epoch 00032: val_loss did not improve from 0.02199
# Epoch 33/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.0209
#
# Epoch 00033: val_loss improved from 0.02199 to 0.02091, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.020907.hdf5
# Epoch 34/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0128 - val_loss: 0.0192
#
# Epoch 00034: val_loss improved from 0.02091 to 0.01925, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.019249.hdf5
# Epoch 35/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0128 - val_loss: 0.0196
#
# Epoch 00035: val_loss did not improve from 0.01925
# Epoch 36/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0206
#
# Epoch 00036: val_loss did not improve from 0.01925
# Epoch 37/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0129 - val_loss: 0.0253
#
# Epoch 00037: val_loss did not improve from 0.01925
# Epoch 38/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0187
#
# Epoch 00038: val_loss improved from 0.01925 to 0.01869, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.018693.hdf5
# Epoch 39/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0162
#
# Epoch 00039: val_loss improved from 0.01869 to 0.01624, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.016241.hdf5
# Epoch 40/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.0193
#
# Epoch 00040: val_loss did not improve from 0.01624
# Epoch 41/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0204
#
# Epoch 00041: val_loss did not improve from 0.01624
# Epoch 42/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0122 - val_loss: 0.0193
#
# Epoch 00042: val_loss did not improve from 0.01624
# Epoch 43/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0121 - val_loss: 0.0156
#
# Epoch 00043: val_loss improved from 0.01624 to 0.01561, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.015608.hdf5
# Epoch 44/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0121 - val_loss: 0.0167
#
# Epoch 00044: val_loss did not improve from 0.01561
# Epoch 45/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0119 - val_loss: 0.0183
#
# Epoch 00045: val_loss did not improve from 0.01561
# Epoch 46/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0119 - val_loss: 0.0182
#
# Epoch 00046: val_loss did not improve from 0.01561
# Epoch 47/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0118 - val_loss: 0.0161
#
# Epoch 00047: val_loss did not improve from 0.01561
# Epoch 48/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0119 - val_loss: 0.0154
#
# Epoch 00048: val_loss improved from 0.01561 to 0.01540, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.015398.hdf5
# Epoch 49/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0123 - val_loss: 0.0195
#
# Epoch 00049: val_loss did not improve from 0.01540
# Epoch 50/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0116 - val_loss: 0.0149
#
# Epoch 00050: val_loss improved from 0.01540 to 0.01494, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.014940.hdf5
# Epoch 51/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0178
#
# Epoch 00051: val_loss did not improve from 0.01494
# Epoch 52/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0116 - val_loss: 0.0154
#
# Epoch 00052: val_loss did not improve from 0.01494
# Epoch 53/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0154
#
# Epoch 00053: val_loss did not improve from 0.01494
# Epoch 54/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0112 - val_loss: 0.0157
#
# Epoch 00054: val_loss did not improve from 0.01494
# Epoch 55/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0113 - val_loss: 0.0179
#
# Epoch 00055: val_loss did not improve from 0.01494
# Epoch 56/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0166
#
# Epoch 00056: val_loss did not improve from 0.01494
# Epoch 57/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0113 - val_loss: 0.0194
#
# Epoch 00057: val_loss did not improve from 0.01494
# Epoch 58/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0171
#
# Epoch 00058: val_loss did not improve from 0.01494
# Epoch 59/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0112 - val_loss: 0.0146
#
# Epoch 00059: val_loss improved from 0.01494 to 0.01464, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.014640.hdf5
# Epoch 60/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0113 - val_loss: 0.0151
#
# Epoch 00060: val_loss did not improve from 0.01464
# Epoch 61/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0139
#
# Epoch 00061: val_loss improved from 0.01464 to 0.01390, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.013899.hdf5
# Epoch 62/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0167
#
# Epoch 00062: val_loss did not improve from 0.01390
# Epoch 63/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0151
#
# Epoch 00063: val_loss did not improve from 0.01390
# Epoch 64/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0191
#
# Epoch 00064: val_loss did not improve from 0.01390
# Epoch 65/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0147
#
# Epoch 00065: val_loss did not improve from 0.01390
# Epoch 66/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0109 - val_loss: 0.0160
#
# Epoch 00066: val_loss did not improve from 0.01390
# Epoch 67/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0139
#
# Epoch 00067: val_loss improved from 0.01390 to 0.01389, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.013894.hdf5
# Epoch 68/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0155
#
# Epoch 00068: val_loss did not improve from 0.01389
# Epoch 69/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0139
#
# Epoch 00069: val_loss did not improve from 0.01389
# Epoch 70/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0162
#
# Epoch 00070: val_loss did not improve from 0.01389
# Epoch 71/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0139
#
# Epoch 00071: val_loss did not improve from 0.01389
# Epoch 72/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0139
#
# Epoch 00072: val_loss did not improve from 0.01389
# Epoch 73/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0144
#
# Epoch 00073: val_loss did not improve from 0.01389
# Epoch 74/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0109 - val_loss: 0.0132
#
# Epoch 00074: val_loss improved from 0.01389 to 0.01325, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.013247.hdf5
# Epoch 75/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0166
#
# Epoch 00075: val_loss did not improve from 0.01325
# Epoch 76/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0145
#
# Epoch 00076: val_loss did not improve from 0.01325
# Epoch 77/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0122
#
# Epoch 00077: val_loss improved from 0.01325 to 0.01216, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.012159.hdf5
# Epoch 78/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0127
#
# Epoch 00078: val_loss did not improve from 0.01216
# Epoch 79/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0139
#
# Epoch 00079: val_loss did not improve from 0.01216
# Epoch 80/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0156
#
# Epoch 00080: val_loss did not improve from 0.01216
# Epoch 81/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0141
#
# Epoch 00081: val_loss did not improve from 0.01216
# Epoch 82/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0158
#
# Epoch 00082: val_loss did not improve from 0.01216
# Epoch 83/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0164
#
# Epoch 00083: val_loss did not improve from 0.01216
# Epoch 84/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.0155
#
# Epoch 00084: val_loss did not improve from 0.01216
# Epoch 85/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0103 - val_loss: 0.0157
#
# Epoch 00085: val_loss did not improve from 0.01216
# Epoch 86/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0137
#
# Epoch 00086: val_loss did not improve from 0.01216
# Epoch 87/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0121
#
# Epoch 00087: val_loss improved from 0.01216 to 0.01205, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.012053.hdf5
# Epoch 88/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0128
#
# Epoch 00088: val_loss did not improve from 0.01205
# Epoch 89/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0170
#
# Epoch 00089: val_loss did not improve from 0.01205
# Epoch 90/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0146
#
# Epoch 00090: val_loss did not improve from 0.01205
# Epoch 91/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0160
#
# Epoch 00091: val_loss did not improve from 0.01205
# Epoch 92/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0142
#
# Epoch 00092: val_loss did not improve from 0.01205
# Epoch 93/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0142
#
# Epoch 00093: val_loss did not improve from 0.01205
# Epoch 94/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0123
#
# Epoch 00094: val_loss did not improve from 0.01205
# Epoch 95/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0149
#
# Epoch 00095: val_loss did not improve from 0.01205
# Epoch 96/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0112
#
# Epoch 00096: val_loss improved from 0.01205 to 0.01120, saving model to ./TimeSeries/LSTM/Seocho-gu/val_loss-0.011200.hdf5
# Epoch 97/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0102 - val_loss: 0.0138
#
# Epoch 00097: val_loss did not improve from 0.01120
# Epoch 98/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0134
#
# Epoch 00098: val_loss did not improve from 0.01120
# Epoch 99/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0130
#
# Epoch 00099: val_loss did not improve from 0.01120
# Epoch 100/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0142
#
# Epoch 00100: val_loss did not improve from 0.01120
# Epoch 101/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0166
#
# Epoch 00101: val_loss did not improve from 0.01120
# Epoch 102/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0128
#
# Epoch 00102: val_loss did not improve from 0.01120
# Epoch 103/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0101 - val_loss: 0.0130
#
# Epoch 00103: val_loss did not improve from 0.01120
# Epoch 104/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0141
#
# Epoch 00104: val_loss did not improve from 0.01120
# Epoch 105/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0127
#
# Epoch 00105: val_loss did not improve from 0.01120
# Epoch 106/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0147
#
# Epoch 00106: val_loss did not improve from 0.01120
# Epoch 107/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0148
#
# Epoch 00107: val_loss did not improve from 0.01120
# Epoch 108/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0130
#
# Epoch 00108: val_loss did not improve from 0.01120
# Epoch 109/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0134
#
# Epoch 00109: val_loss did not improve from 0.01120
# Epoch 110/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0143
#
# Epoch 00110: val_loss did not improve from 0.01120
# Epoch 111/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0099 - val_loss: 0.0122
#
# Epoch 00111: val_loss did not improve from 0.01120
# Epoch 112/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0120
#
# Epoch 00112: val_loss did not improve from 0.01120
# Epoch 113/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0131
#
# Epoch 00113: val_loss did not improve from 0.01120
# Epoch 114/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0126
#
# Epoch 00114: val_loss did not improve from 0.01120
# Epoch 115/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0132
#
# Epoch 00115: val_loss did not improve from 0.01120
# Epoch 116/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0100 - val_loss: 0.0158
#
# Epoch 00116: val_loss did not improve from 0.01120
# Epoch 117/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0133
#
# Epoch 00117: val_loss did not improve from 0.01120
# Epoch 118/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0101 - val_loss: 0.0164
#
# Epoch 00118: val_loss did not improve from 0.01120
# Epoch 119/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0100 - val_loss: 0.0118
#
# Epoch 00119: val_loss did not improve from 0.01120
# Epoch 120/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0124
#
# Epoch 00120: val_loss did not improve from 0.01120
# Epoch 121/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0146
#
# Epoch 00121: val_loss did not improve from 0.01120
# Epoch 122/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0160
#
# Epoch 00122: val_loss did not improve from 0.01120
# Epoch 123/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0096 - val_loss: 0.0128
#
# Epoch 00123: val_loss did not improve from 0.01120
# Epoch 124/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0117
#
# Epoch 00124: val_loss did not improve from 0.01120
# Epoch 125/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0137
#
# Epoch 00125: val_loss did not improve from 0.01120
# Epoch 126/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0101 - val_loss: 0.0117
#
# Epoch 00126: val_loss did not improve from 0.01120
# Epoch 127/500
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0133
#
# Epoch 00127: val_loss did not improve from 0.01120
# Epoch 128/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0132
#
# Epoch 00128: val_loss did not improve from 0.01120
# Epoch 129/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0117
#
# Epoch 00129: val_loss did not improve from 0.01120
# Epoch 130/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0144
#
# Epoch 00130: val_loss did not improve from 0.01120
# Epoch 131/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0136
#
# Epoch 00131: val_loss did not improve from 0.01120
# Epoch 132/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0130
#
# Epoch 00132: val_loss did not improve from 0.01120
# Epoch 133/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0121
#
# Epoch 00133: val_loss did not improve from 0.01120
# Epoch 134/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0133
#
# Epoch 00134: val_loss did not improve from 0.01120
# Epoch 135/500
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0096 - val_loss: 0.0122
#
# Epoch 00135: val_loss did not improve from 0.01120
# Epoch 136/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0145
#
# Epoch 00136: val_loss did not improve from 0.01120
# Epoch 137/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0124
#
# Epoch 00137: val_loss did not improve from 0.01120
# Epoch 138/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0158
#
# Epoch 00138: val_loss did not improve from 0.01120
# Epoch 139/500
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0134
#
# Epoch 00139: val_loss did not improve from 0.01120
# Epoch 140/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0140
#
# Epoch 00140: val_loss did not improve from 0.01120
# Epoch 141/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0116
#
# Epoch 00141: val_loss did not improve from 0.01120
# Epoch 142/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0124
#
# Epoch 00142: val_loss did not improve from 0.01120
# Epoch 143/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0124
#
# Epoch 00143: val_loss did not improve from 0.01120
# Epoch 144/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0141
#
# Epoch 00144: val_loss did not improve from 0.01120
# Epoch 145/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0122
#
# Epoch 00145: val_loss did not improve from 0.01120
# Epoch 146/500
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0143
#
# Epoch 00146: val_loss did not improve from 0.01120

# %%
def predict_and_score(model, X, Y):
    pred = scaler.inverse_transform(model.predict(X))
    # 0 ~ 1 inverse origin
    orig_data = scaler.inverse_transform([Y])
    
    print(len(orig_data[0]))
    print(len(pred[:, 0]))
    
    #RMSE.
    score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
    return(score, pred, orig_data)

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
rmse_train, train_predict, train_orig = predict_and_score(model[0], train_X, train_Y)
rmse_test, test_predict, test_orig = predict_and_score(model[0], test_X, test_Y)

whole_test, whole_predict, whole_orig = predict_and_score(model[0], whole_X, whole_Y)

print("Training data score: %.2f RMSE" % rmse_train)
print("Test data score: %.2f RMSE" % rmse_test)
print("Whole data score: %.2f RMSE " % whole_test)
# Out:
# 78
# 78
# 16
# 16
# 99
# 99
# Training data score: 0.24 RMSE
# Test data score: 0.66 RMSE
# Whole data score: 0.35 RMSE

# %%
mean_absolute_percentage_error(whole_orig[0], whole_predict[:, 0])
# Out:
# 498.3027241058339

# %%
def start_predict_n_plot(dataset, train_predict, test_predict):
    train_predict_plot = np.empty_like(dataset)
    train_predict_plot[:, :] = np.nan
    
    ##땡기자
    print("window_size: ", window_size)
    train_predict_plot[(window_size - 1) : len(train_predict) + (window_size - 1)] = train_predict

    
    test_predict_plot = np.empty_like(dataset)
    test_predict_plot[:, :] = np.nan
#     test_predict_plot[len(train_predict) + (window_size * 2) + 1:len(dataset) - 1] = test_predict
    test_predict_plot[(window_size - 1): len(whole_predict) + (window_size - 1), :] = whole_predict
    
    print(test_predict_plot.shape)
    print(whole_predict.shape)

    plt.figure(figsize = (15, 5))
    plt.plot(scaler.inverse_transform(dataset), label = "True value")
    plt.plot(train_predict_plot, label = "Training set pred")
    plt.plot(test_predict_plot, label = "Test set pred")
    plt.xlabel("Month")
    plt.ylabel("Price")
    plt.title("Gangnam Train/test Predict")
    plt.legend()
    plt.show()

# %%
start_predict_n_plot(dataset, train_predict, test_predict)
# Out:
# window_size:  4
# (104, 1)
# (99, 1)

# %%
def get_best_weights_path():
    result = MODEL_PATH +"/"+sorted(os.listdir(MODEL_PATH))[0]
    print("best model path: ", result)
    
    return result

# %%
best_model = get_best_weights_path()
# Out:
# best model path:  ./TimeSeries/LSTM/Songpa-gu/val_loss-0.005143.hdf5

# %%
model[0].load_weights(best_model)

# %%
def run_loaded_model(model, train_X, train_Y, window_size = 1):
    adam = Adam(lr=0.00146, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=1e-6, amsgrad=False)
    model.compile(loss = "mean_squared_error", 
                  optimizer = adam)
    model.summary()
    
    checkloss = create_checkpoint(MODEL_NAME)
    history = model.fit(train_X, train_Y, epochs = 1000 ,batch_size=2, validation_split = 0.1,
                        shuffle=True,
                        callbacks=[checkloss, early_stopping])
    
    return model, history

# %%
model2 = run_loaded_model(model[0], train_X, train_Y, window_size)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 12)             816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 12)             1200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 12)                1200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 3,229
# Trainable params: 3,229
# Non-trainable params: 0
# _________________________________________________________________
# Model_path :  ./TimeSeries/LSTM
# Train on 70 samples, validate on 8 samples
# Epoch 1/1000
# 70/70 [==============================] - 2s 33ms/step - loss: 0.0046 - val_loss: 0.0050
#
# Epoch 00001: val_loss improved from inf to 0.00499, saving model to ./TimeSeries/LSTM/Songpa-gu/val_loss-0.004992.hdf5
# Epoch 2/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0039
#
# Epoch 00002: val_loss improved from 0.00499 to 0.00393, saving model to ./TimeSeries/LSTM/Songpa-gu/val_loss-0.003934.hdf5
# Epoch 3/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0041
#
# Epoch 00003: val_loss did not improve from 0.00393
# Epoch 4/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0070
#
# Epoch 00004: val_loss did not improve from 0.00393
# Epoch 5/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0045
#
# Epoch 00005: val_loss did not improve from 0.00393
# Epoch 6/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0088
#
# Epoch 00006: val_loss did not improve from 0.00393
# Epoch 7/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0046
#
# Epoch 00007: val_loss did not improve from 0.00393
# Epoch 8/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0059
#
# Epoch 00008: val_loss did not improve from 0.00393
# Epoch 9/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0109
#
# Epoch 00009: val_loss did not improve from 0.00393
# Epoch 10/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0061
#
# Epoch 00010: val_loss did not improve from 0.00393
# Epoch 11/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0103
#
# Epoch 00011: val_loss did not improve from 0.00393
# Epoch 12/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0076
#
# Epoch 00012: val_loss did not improve from 0.00393
# Epoch 13/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0039
#
# Epoch 00013: val_loss improved from 0.00393 to 0.00386, saving model to ./TimeSeries/LSTM/Songpa-gu/val_loss-0.003858.hdf5
# Epoch 14/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0061
#
# Epoch 00014: val_loss did not improve from 0.00386
# Epoch 15/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0047
#
# Epoch 00015: val_loss did not improve from 0.00386
# Epoch 16/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0049
#
# Epoch 00016: val_loss did not improve from 0.00386
# Epoch 17/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0062
#
# Epoch 00017: val_loss did not improve from 0.00386
# Epoch 18/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0046
#
# Epoch 00018: val_loss did not improve from 0.00386
# Epoch 19/1000
# 70/70 [==============================] - ETA: 0s - loss: 0.004 - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0053
#
# Epoch 00019: val_loss did not improve from 0.00386
# Epoch 20/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0037
#
# Epoch 00020: val_loss improved from 0.00386 to 0.00374, saving model to ./TimeSeries/LSTM/Songpa-gu/val_loss-0.003740.hdf5
# Epoch 21/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0055
#
# Epoch 00021: val_loss did not improve from 0.00374
# Epoch 22/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0056
#
# Epoch 00022: val_loss did not improve from 0.00374
# Epoch 23/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0062
#
# Epoch 00023: val_loss did not improve from 0.00374
# Epoch 24/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0044
#
# Epoch 00024: val_loss did not improve from 0.00374
# Epoch 25/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0138
#
# Epoch 00025: val_loss did not improve from 0.00374
# Epoch 26/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0052
#
# Epoch 00026: val_loss did not improve from 0.00374
# Epoch 27/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0071
#
# Epoch 00027: val_loss did not improve from 0.00374
# Epoch 28/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0056
#
# Epoch 00028: val_loss did not improve from 0.00374
# Epoch 29/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0103
#
# Epoch 00029: val_loss did not improve from 0.00374
# Epoch 30/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0045
#
# Epoch 00030: val_loss did not improve from 0.00374
# Epoch 31/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0039
#
# Epoch 00031: val_loss did not improve from 0.00374
# Epoch 32/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0054
#
# Epoch 00032: val_loss did not improve from 0.00374
# Epoch 33/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0052
#
# Epoch 00033: val_loss did not improve from 0.00374
# Epoch 34/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0037
#
# Epoch 00034: val_loss improved from 0.00374 to 0.00367, saving model to ./TimeSeries/LSTM/Songpa-gu/val_loss-0.003673.hdf5
# Epoch 35/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0053
#
# Epoch 00035: val_loss did not improve from 0.00367
# Epoch 36/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0071
#
# Epoch 00036: val_loss did not improve from 0.00367
# Epoch 37/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0129
#
# Epoch 00037: val_loss did not improve from 0.00367
# Epoch 38/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0109
#
# Epoch 00038: val_loss did not improve from 0.00367
# Epoch 39/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0130
#
# Epoch 00039: val_loss did not improve from 0.00367
# Epoch 40/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0037
#
# Epoch 00040: val_loss improved from 0.00367 to 0.00365, saving model to ./TimeSeries/LSTM/Songpa-gu/val_loss-0.003655.hdf5
# Epoch 41/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0065
#
# Epoch 00041: val_loss did not improve from 0.00365
# Epoch 42/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0071
#
# Epoch 00042: val_loss did not improve from 0.00365
# Epoch 43/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00043: val_loss did not improve from 0.00365
# Epoch 44/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0047
#
# Epoch 00044: val_loss did not improve from 0.00365
# Epoch 45/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0063
# Epoch 00045: val_loss did not improve from 0.00365
# Epoch 46/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0110
#
# Epoch 00046: val_loss did not improve from 0.00365
# Epoch 47/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0068
#
# Epoch 00047: val_loss did not improve from 0.00365
# Epoch 48/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0084
#
# Epoch 00048: val_loss did not improve from 0.00365
# Epoch 49/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0119
#
# Epoch 00049: val_loss did not improve from 0.00365
# Epoch 50/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0051
#
# Epoch 00050: val_loss did not improve from 0.00365
# Epoch 51/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0064
#
# Epoch 00051: val_loss did not improve from 0.00365
# Epoch 52/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0050
#
# Epoch 00052: val_loss did not improve from 0.00365
# Epoch 53/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0106
#
# Epoch 00053: val_loss did not improve from 0.00365
# Epoch 54/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0056
#
# Epoch 00054: val_loss did not improve from 0.00365
# Epoch 55/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0068
#
# Epoch 00055: val_loss did not improve from 0.00365
# Epoch 56/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0098
#
# Epoch 00056: val_loss did not improve from 0.00365
# Epoch 57/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0118
#
# Epoch 00057: val_loss did not improve from 0.00365
# Epoch 58/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0119
#
# Epoch 00058: val_loss did not improve from 0.00365
# Epoch 59/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0117
#
# Epoch 00059: val_loss did not improve from 0.00365
# Epoch 60/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0071
#
# Epoch 00060: val_loss did not improve from 0.00365
# Epoch 61/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0046
#
# Epoch 00061: val_loss did not improve from 0.00365
# Epoch 62/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0111
#
# Epoch 00062: val_loss did not improve from 0.00365
# Epoch 63/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0072
#
# Epoch 00063: val_loss did not improve from 0.00365
# Epoch 64/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0084
#
# Epoch 00064: val_loss did not improve from 0.00365
# Epoch 65/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0093
#
# Epoch 00065: val_loss did not improve from 0.00365
# Epoch 66/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0064
#
# Epoch 00066: val_loss did not improve from 0.00365
# Epoch 67/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0079
#
# Epoch 00067: val_loss did not improve from 0.00365
# Epoch 68/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0056
#
# Epoch 00068: val_loss did not improve from 0.00365
# Epoch 69/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0079
#
# Epoch 00069: val_loss did not improve from 0.00365
# Epoch 70/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0076
#
# Epoch 00070: val_loss did not improve from 0.00365
# Epoch 71/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0066
#
# Epoch 00071: val_loss did not improve from 0.00365
# Epoch 72/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0039
#
# Epoch 00072: val_loss did not improve from 0.00365
# Epoch 73/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0091
#
# Epoch 00073: val_loss did not improve from 0.00365
# Epoch 74/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0129
#
# Epoch 00074: val_loss did not improve from 0.00365
# Epoch 75/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0076
#
# Epoch 00075: val_loss did not improve from 0.00365
# Epoch 76/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0055
#
# Epoch 00076: val_loss did not improve from 0.00365
# Epoch 77/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0055
#
# Epoch 00077: val_loss did not improve from 0.00365
# Epoch 78/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0051
#
# Epoch 00078: val_loss did not improve from 0.00365
# Epoch 79/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0048
#
# Epoch 00079: val_loss did not improve from 0.00365
# Epoch 80/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0096
#
# Epoch 00080: val_loss did not improve from 0.00365
# Epoch 81/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0087
#
# Epoch 00081: val_loss did not improve from 0.00365
# Epoch 82/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0076
#
# Epoch 00082: val_loss did not improve from 0.00365
# Epoch 83/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0078
#
# Epoch 00083: val_loss did not improve from 0.00365
# Epoch 84/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0069
#
# Epoch 00084: val_loss did not improve from 0.00365
# Epoch 85/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0034
#
# Epoch 00085: val_loss improved from 0.00365 to 0.00342, saving model to ./TimeSeries/LSTM/Songpa-gu/val_loss-0.003423.hdf5
# Epoch 86/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0089
#
# Epoch 00086: val_loss did not improve from 0.00342
# Epoch 87/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0101
#
# Epoch 00087: val_loss did not improve from 0.00342
# Epoch 88/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0066
#
# Epoch 00088: val_loss did not improve from 0.00342
# Epoch 89/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0082
#
# Epoch 00089: val_loss did not improve from 0.00342
# Epoch 90/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0036
#
# Epoch 00090: val_loss did not improve from 0.00342
# Epoch 91/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0074
#
# Epoch 00091: val_loss did not improve from 0.00342
# Epoch 92/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0094
#
# Epoch 00092: val_loss did not improve from 0.00342
# Epoch 93/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0101
#
# Epoch 00093: val_loss did not improve from 0.00342
# Epoch 94/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0064
#
# Epoch 00094: val_loss did not improve from 0.00342
# Epoch 95/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0056
#
# Epoch 00095: val_loss did not improve from 0.00342
# Epoch 96/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0114
#
# Epoch 00096: val_loss did not improve from 0.00342
# Epoch 97/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0061
#
# Epoch 00097: val_loss did not improve from 0.00342
# Epoch 98/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0057
#
# Epoch 00098: val_loss did not improve from 0.00342
# Epoch 99/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0080
#
# Epoch 00099: val_loss did not improve from 0.00342
# Epoch 100/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0103
#
# Epoch 00100: val_loss did not improve from 0.00342
# Epoch 101/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0063
#
# Epoch 00101: val_loss did not improve from 0.00342
# Epoch 102/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0101
#
# Epoch 00102: val_loss did not improve from 0.00342
# Epoch 103/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0061
#
# Epoch 00103: val_loss did not improve from 0.00342
# Epoch 104/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0055
#
# Epoch 00104: val_loss did not improve from 0.00342
# Epoch 105/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0041
#
# Epoch 00105: val_loss did not improve from 0.00342
# Epoch 106/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0056
#
# Epoch 00106: val_loss did not improve from 0.00342
# Epoch 107/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0055
#
# Epoch 00107: val_loss did not improve from 0.00342
# Epoch 108/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0063
#
# Epoch 00108: val_loss did not improve from 0.00342
# Epoch 109/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0069
#
# Epoch 00109: val_loss did not improve from 0.00342
# Epoch 110/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0082
#
# Epoch 00110: val_loss did not improve from 0.00342
# Epoch 111/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0082
#
# Epoch 00111: val_loss did not improve from 0.00342
# Epoch 112/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0055
#
# Epoch 00112: val_loss did not improve from 0.00342
# Epoch 113/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0032
#
# Epoch 00113: val_loss improved from 0.00342 to 0.00323, saving model to ./TimeSeries/LSTM/Songpa-gu/val_loss-0.003230.hdf5
# Epoch 114/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0055
#
# Epoch 00114: val_loss did not improve from 0.00323
# Epoch 115/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0040
#
# Epoch 00115: val_loss did not improve from 0.00323
# Epoch 116/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0131
#
# Epoch 00116: val_loss did not improve from 0.00323
# Epoch 117/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0034
#
# Epoch 00117: val_loss did not improve from 0.00323
# Epoch 118/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0070
#
# Epoch 00118: val_loss did not improve from 0.00323
# Epoch 119/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0060
#
# Epoch 00119: val_loss did not improve from 0.00323
# Epoch 120/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0109
#
# Epoch 00120: val_loss did not improve from 0.00323
# Epoch 121/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0049
#
# Epoch 00121: val_loss did not improve from 0.00323
# Epoch 122/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0093
#
# Epoch 00122: val_loss did not improve from 0.00323
# Epoch 123/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0045
#
# Epoch 00123: val_loss did not improve from 0.00323
# Epoch 124/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0053
#
# Epoch 00124: val_loss did not improve from 0.00323
# Epoch 125/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0069
#
# Epoch 00125: val_loss did not improve from 0.00323
# Epoch 126/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0056
#
# Epoch 00126: val_loss did not improve from 0.00323
# Epoch 127/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0056
#
# Epoch 00127: val_loss did not improve from 0.00323
# Epoch 128/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0083
#
# Epoch 00128: val_loss did not improve from 0.00323
# Epoch 129/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0073
#
# Epoch 00129: val_loss did not improve from 0.00323
# Epoch 130/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0080
#
# Epoch 00130: val_loss did not improve from 0.00323
# Epoch 131/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0113
#
# Epoch 00131: val_loss did not improve from 0.00323
# Epoch 132/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0075
#
# Epoch 00132: val_loss did not improve from 0.00323
# Epoch 133/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0045
#
# Epoch 00133: val_loss did not improve from 0.00323
# Epoch 134/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0087
#
# Epoch 00134: val_loss did not improve from 0.00323
# Epoch 135/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0094
#
# Epoch 00135: val_loss did not improve from 0.00323
# Epoch 136/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0045
#
# Epoch 00136: val_loss did not improve from 0.00323
# Epoch 137/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0068
#
# Epoch 00137: val_loss did not improve from 0.00323
# Epoch 138/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0044
#
# Epoch 00138: val_loss did not improve from 0.00323
# Epoch 139/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0041
#
# Epoch 00139: val_loss did not improve from 0.00323
# Epoch 140/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0048
#
# Epoch 00140: val_loss did not improve from 0.00323
# Epoch 141/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0049
#
# Epoch 00141: val_loss did not improve from 0.00323
# Epoch 142/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0070
#
# Epoch 00142: val_loss did not improve from 0.00323
# Epoch 143/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0065
#
# Epoch 00143: val_loss did not improve from 0.00323
# Epoch 144/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0063
#
# Epoch 00144: val_loss did not improve from 0.00323
# Epoch 145/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0065
#
# Epoch 00145: val_loss did not improve from 0.00323
# Epoch 146/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0051
#
# Epoch 00146: val_loss did not improve from 0.00323
# Epoch 147/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0090
#
# Epoch 00147: val_loss did not improve from 0.00323
# Epoch 148/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0055
#
# Epoch 00148: val_loss did not improve from 0.00323
# Epoch 149/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0072
#
# Epoch 00149: val_loss did not improve from 0.00323
# Epoch 150/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0043
#
# Epoch 00150: val_loss did not improve from 0.00323
# Epoch 151/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0075
#
# Epoch 00151: val_loss did not improve from 0.00323
# Epoch 152/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0053
#
# Epoch 00152: val_loss did not improve from 0.00323
# Epoch 153/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0089
#
# Epoch 00153: val_loss did not improve from 0.00323
# Epoch 154/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0041
#
# Epoch 00154: val_loss did not improve from 0.00323
# Epoch 155/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0062
#
# Epoch 00155: val_loss did not improve from 0.00323
# Epoch 156/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0055
#
# Epoch 00156: val_loss did not improve from 0.00323
# Epoch 157/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0081
#
# Epoch 00157: val_loss did not improve from 0.00323
# Epoch 158/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0065
#
# Epoch 00158: val_loss did not improve from 0.00323
# Epoch 159/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0068
#
# Epoch 00159: val_loss did not improve from 0.00323
# Epoch 160/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0107
#
# Epoch 00160: val_loss did not improve from 0.00323
# Epoch 161/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0071
#
# Epoch 00161: val_loss did not improve from 0.00323
# Epoch 162/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0072
#
# Epoch 00162: val_loss did not improve from 0.00323
# Epoch 163/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0054
#
# Epoch 00163: val_loss did not improve from 0.00323

# %%
rmse_train, train_predict, train_orig = predict_and_score(model[0], train_X, train_Y)
rmse_test, test_predict, test_orig = predict_and_score(model[0], test_X, test_Y)

whole_test, whole_predict, whole_orig = predict_and_score(model[0], whole_X, whole_Y)

print("Training data score: %.2f RMSE" % rmse_train)
print("Test data score: %.2f RMSE" % rmse_test)
print("Whole data score: %.2f RMSE " % whole_test)
# Out:
# 78
# 78
# 16
# 16
# 99
# 99
# Training data score: 0.23 RMSE
# Test data score: 0.60 RMSE
# Whole data score: 0.33 RMSE

# %%
mean_absolute_percentage_error(whole_orig[0], whole_predict[:, 0])
# Out:
# 341.9335434667246

# %%
start_predict_n_plot(dataset, train_predict, test_predict)
# Out:
# window_size:  4
# (104, 1)
# (99, 1)
