# %% [markdown]
# ### import module

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.action_chains import ActionChains
import os
import time
import pickle

# %%
curr_path = os.getcwd()
sub_path = curr_path +"/Dataset/Information"

# %%
# %load executionTimeCheck.py
# from time import time, strftime, localtime
from datetime import timedelta


class checkExecution:
    def __init__(self):
        self.startTime = ''

    def secondsToStr(self, elapsed=None):
        if elapsed is None:
            return strftime("%Y-%m-%d %H:%M:%S", localtime())
        else:
            return str(timedelta(seconds=elapsed))

    def log(self, s, elapsed=None):
        line = "=" * 40
        print()
        print(line)
        print(self.secondsToStr(), '-', s)
        if elapsed:
            print("Elapsed time:", elapsed)
        print(line)
        print()

    def startLog(self):
        self.startTime = time()
        self.log("Start Program")

    def endLog(self):
        end = time()
        elapsed = end - self.startTime
        self.log("End Program", self.secondsToStr(elapsed))

# %%
e = checkExecution()

# %% [markdown]
# ### def webdriver

# %%
def start(url):
    driver = webdriver.Chrome('/Users/tax_k/Downloads/chromedriver')
    driver.get(url)
    return driver

# %% [markdown]
# ### set default module

# %%
url = "http://nland.kbstar.com/quics?page=B046948"
driver = start(url)
driver.find_element_by_xpath("//a[@title = '시/도 선택']").click()

# %%
def getSiGunGu(name_id):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    sigungu_list = []
    for li in soup.select("#"+name_id+" li"):
        sigungu_list.append(li.text)
        
    return sigungu_list

# %%
def geteupMyeonDong(name_id):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    eupMyeonDong_list = []
    
    print("from eupmyendong")
    for li in soup.select("#"+name_id+" li"):
        eupMyeonDong_list.append(li.text)
        
    return eupMyeonDong_list

# %%
def getDanji(name_id):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    danji_list = []
    
    print("from danji")
    for li in soup.select("#"+name_id+" li"):
        danji_list.append(li.text)
        
    return danji_list

# %%
si_id = "siGunGu"
sigungu_list = getSiGunGu(si_id)
len(sigungu_list)
# Out:
# 25

# %%
# e.startLog()

for (index, value) in enumerate(sigungu_list):
    sigungu_path = sub_path + "/" + str(index+1)
    
    driver.find_element_by_xpath("//a[@title = '시/군/구 선택']").click()
    time.sleep(1)
    driver.find_element_by_xpath("//ul[@id='"+si_id+"']/li["+str(index+1)+"]").click()
    time.sleep(2)
    dong_id = "eupMyeonDong"
    eupMyeonDong_list = geteupMyeonDong(dong_id)
    
    for (index, value) in enumerate(eupMyeonDong_list):
        dong_path = sigungu_path+"/"+str(index+1)
        print(dong_path)
        
        driver.find_element_by_xpath("//a[@title = '읍/면/동 선택']").click()
        time.sleep(1)
    
        driver.find_element_by_xpath("//ul[@id='"+dong_id+"']/li["+str(index+1)+"]").click()
        time.sleep(2)
        danji_id = "danji"
        danji_list = getDanji(danji_id)
        
        for (index, value) in enumerate(danji_list):
            file_path = dong_path+'/'+value+'.txt'
            
            print("-"*20 + str(index+1) + "/" + str(len(danji_list)))
            
            if not os.path.exists(os.path.dirname(file_path)):
                try:
                    os.makedirs(os.path.dirname(file_path))
                except OSError as exc:
                    if exc.errno != errno.EEXIST:
                        raise
            
            print(file_path)
            subway_list = []
            driver.find_element_by_xpath("//a[@title = '단지 선택']").click()
            time.sleep(1)
            driver.find_element_by_xpath("//ul[@id='"+danji_id+"']/li["+str(index+1)+"]").click()
            time.sleep(2)
            driver.find_element_by_xpath('//div[@class="tab_type"]/ul/li[3]').click()
            time.sleep(2)
            
            apt_name_element = driver.find_element_by_class_name("slide_tit")
            
            
            apt_jibun_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_info > dl:nth-child(1)")
            apt_area_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_info > dl:nth-child(2)")
            #select element
            subway_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(1)")
            conv_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(2)")
            road_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(3)")
            edu_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(4)")
            medi_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(5)")
            park_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(6)")
            etc_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(7)")
            
            
            
            apt_name = apt_name_element.text
            apt_jibun = apt_jibun_element.find_element_by_xpath("./dt[.='지번']/following-sibling::dd").text
            apt_area = apt_area_element.find_element_by_xpath("./dt[.='면적']/following-sibling::dd").text
            
            apt_area_lists = apt_area.split(", ")
            #subway list
            subway_element_list = subway_element.find_elements_by_xpath("./dt[.='지하철']/following-sibling::dd/span")
            for lists in subway_element_list:
                subway_list.append(lists.text)   
            
            #conv_list
            conv_list = conv_element.find_element_by_xpath("./dt[.='편의정보']/following-sibling::dd").text
            conv_lists = conv_list.split(",")
            
            #road_list 
            road_list = road_element.find_element_by_xpath("./dt[.='도로시설']/following-sibling::dd").text
            road_lists = road_list.split(",")
            #edu_list
            edu_list = edu_element.find_element_by_xpath("./dt[.='교육시설']/following-sibling::dd").text
            edu_lists = edu_list.split(",")
            
            medi_list = medi_element.find_element_by_xpath("./dt[.='의료시설']/following-sibling::dd").text
            medi_lists = medi_list.split(",")
            
            park_list = park_element.find_element_by_xpath("./dt[.='공원']/following-sibling::dd").text
            park_lists = park_list.split(",")
            
            etc_list = etc_element.find_element_by_xpath("./dt[.='기타시설']/following-sibling::dd").text
            etc_lists = etc_list.split(",")
            
            basic_info_table = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div:nth-child(5) > table")
            
            rows = basic_info_table.find_elements_by_tag_name("tr")
                
            
            apt_internal_info_dic = {}
            basic_info_list = []
            th_list = []
            for row in rows:      
                cols = row.find_elements_by_xpath("./th/following-sibling::td")
                ths = row.find_elements_by_xpath("./th")
                for th in ths:
                    th_list.append(th.text)
                
                for col in cols:
                    basic_info_list.append(col.text)
                                                     
            for (index, value) in enumerate(th_list):
                apt_internal_info_dic[value] = basic_info_list[index]
            
            apt_external_info_dic = {
                "apt_name": apt_name,
                "apt_jibun": apt_jibun,
                "apt_area" : apt_area_lists,
                "subway_list": subway_list,
                "conv_lists" : conv_lists,
                "road_lists": road_lists,
                "edu_lists" : edu_lists,
                "medi_lists": medi_lists,
                "park_lists": park_lists,
                "etc_lists" : etc_lists,
                "apt_internal_info" : apt_internal_info_dic 
            }
            
            with open(file_path, 'wb') as f:
                pickle.dump(apt_external_info_dic, f)
            
            #end and wait (2)
            time.sleep(2)            
# e.endLog()
# Out:
# from eupmyendong
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1
# from danji
# --------------------1/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/LG개포자이.txt
# --------------------2/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/개포1차지구(주공1단지).txt
# --------------------3/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/개포6차우성.txt
# --------------------4/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/개포상지리츠빌.txt
# --------------------5/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/개포시영.txt
# --------------------6/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/개포주공(4단지).txt
# --------------------7/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/개포현대(200동).txt
# --------------------8/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/개포현대5차.txt
# --------------------9/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/경남(1차).txt
# --------------------10/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/경남(2차).txt
# --------------------11/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/뉴현대파크빌.txt
# --------------------12/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/대청.txt
# --------------------13/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/대치.txt
# --------------------14/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/더샵그린.txt
# --------------------15/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/렉스힐.txt
# --------------------16/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/리더스.txt
# --------------------17/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/새롬.txt
# --------------------18/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/쌍용개포.txt
# --------------------19/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/우성(3차).txt
# --------------------20/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/우성(8차).txt
# --------------------21/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/우성9차..txt
# --------------------22/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/우찬현대(101).txt
# --------------------23/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/우찬현대(102).txt
# --------------------24/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/우찬현대(103).txt
# --------------------25/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/잠실전화국주택조합(220동).txt
# --------------------26/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/주공고층5단지..txt
# --------------------27/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/주공고층6단지..txt
# --------------------28/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/주공고층7단지..txt
# --------------------29/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/포이벨리.txt
# --------------------30/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/포이현대.txt
# --------------------31/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/한림.txt
# --------------------32/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/현대(1차).txt
# --------------------33/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/현대(2차).txt
# --------------------34/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/현대(3차).txt
# --------------------35/35
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/1/현대빌라트.txt
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2
# from danji
# --------------------1/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/강남파라곤.txt
# --------------------2/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/거평프리젠.txt
# --------------------3/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/경남논현.txt
# --------------------4/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/골든캐슬.txt
# --------------------5/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/그랑디오스.txt
# --------------------6/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현(신동아).txt
# --------------------7/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현e-편한세상.txt
# --------------------8/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현대우멤버스카운티.txt
# --------------------9/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현동 월드메르디앙.txt
# --------------------10/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현동동부센트레빌.txt
# --------------------11/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현동동양파라곤.txt
# --------------------12/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현동한진로즈힐.txt
# --------------------13/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현동한화꿈에그린.txt
# --------------------14/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현두산위브.txt
# --------------------15/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현라폴리움.txt
# --------------------16/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현멤버스카운티.txt
# --------------------17/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현베르빌.txt
# --------------------18/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현브라운스톤로얄스위트.txt
# --------------------19/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현아테나니케.txt
# --------------------20/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현아트빌.txt
# --------------------21/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현아펠바움1차.txt
# --------------------22/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현아펠바움2차.txt
# --------------------23/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현웰스톤.txt
# --------------------24/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현인텔리전트하우스.txt
# --------------------25/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현테크노빌.txt
# --------------------26/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현프라임(192-3).txt
# --------------------27/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현한가람.txt
# --------------------28/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현한화꿈에그린2차.txt
# --------------------29/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/논현힐스빌6차.txt
# --------------------30/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/더그레이스.txt
# --------------------31/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/더원센트럴.txt
# --------------------32/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/더케이(도시형).txt
# --------------------33/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/더클래식논현(도시형).txt
# --------------------34/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/동광팰리스(도시형).txt
# --------------------35/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/동현.txt
# --------------------36/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/동화(도시형).txt
# --------------------37/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/두영.txt
# --------------------38/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/라디안.txt
# --------------------39/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/라이헤스빌.txt
# --------------------40/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/로체샤르캐슬.txt
# --------------------41/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/리더스빌.txt
# --------------------42/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/리츠하우스.txt
# --------------------43/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/마블하우스.txt
# --------------------44/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/마일스디오빌.txt
# --------------------45/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/벨러스빌.txt
# --------------------46/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/보노체아(도시형).txt
# --------------------47/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/비쥬힐.txt
# --------------------48/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/삼성빌라트.txt
# --------------------49/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/세호시티라이프.txt
# --------------------50/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/스위트캐슬.txt
# --------------------51/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/스위트케슬레지던스.txt
# --------------------52/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/신동아.txt
# --------------------53/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/쌍용.txt
# --------------------54/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/아크로힐스논현.txt
# --------------------55/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/알파임하우스Ⅱ.txt
# --------------------56/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/애플타운.txt
# --------------------57/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/예원베스트빌.txt
# --------------------58/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/우민.txt
# --------------------59/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/우성.txt
# --------------------60/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/월드노블레스빌.txt
# --------------------61/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/월드쉐르빌.txt
# --------------------62/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/은탑리더스카운티.txt
# --------------------63/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/이산.txt
# --------------------64/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/이움.txt
# --------------------65/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/제이빌.txt
# --------------------66/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/지고하임.txt
# --------------------67/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/청학.txt
# --------------------68/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/케럿스테이트.txt
# --------------------69/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/케이씨빌.txt
# --------------------70/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/테크노빌라트.txt
# --------------------71/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/토미빌(228-9).txt
# --------------------72/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/프라임(196-4).txt
# --------------------73/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/프라임(80-13).txt
# --------------------74/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/학동참진.txt
# --------------------75/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/한양빌라트.txt
# --------------------76/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/한양수자인어반게이트(도시형).txt
# --------------------77/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/현대넥서스(261-7).txt
# --------------------78/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/현대넥서스(261-8).txt
# --------------------79/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/현대인텔렉스.txt
# --------------------80/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/휴먼스페이스.txt
# --------------------81/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/힐스빌7차.txt
# --------------------82/82
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/2/힐타워.txt
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3
# from danji
# --------------------1/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/S-타워.txt
# --------------------2/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/개포우성1차.txt
# --------------------3/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/개포우성2차.txt
# --------------------4/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/노빌리티빌리지.txt
# --------------------5/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치SK뷰.txt
# --------------------6/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치더블유타워(도시형).txt
# --------------------7/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치동3차풍림아이원.txt
# --------------------8/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치동대우아이빌멤버스.txt
# --------------------9/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치동대우아이빌명문가.txt
# --------------------10/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치동삼성3차.txt
# --------------------11/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치동우정에쉐르1.txt
# --------------------12/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치삼성(래미안).txt
# --------------------13/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치삼성2차.txt
# --------------------14/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치상지리츠빌카일룸.txt
# --------------------15/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치아이파크.txt
# --------------------16/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치우정에쉐르2.txt
# --------------------17/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치주성.txt
# --------------------18/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치풍림아이원4차.txt
# --------------------19/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치하나빌.txt
# --------------------20/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치한신휴플러스.txt
# --------------------21/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치현대.txt
# --------------------22/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/대치효성.txt
# --------------------23/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/더힐하우스(도시형).txt
# --------------------24/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/도성.txt
# --------------------25/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/동민맥스빌(A동).txt
# --------------------26/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/동민맥스빌(B동).txt
# --------------------27/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/동부센트레빌.txt
# --------------------28/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/동양.txt
# --------------------29/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/래미안대치팰리스1단지.txt
# --------------------30/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/래미안대치팰리스2단지.txt
# --------------------31/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/래미안대치하이스턴(우성2차).txt
# --------------------32/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/롯데캐슬.txt
# --------------------33/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/롯데캐슬리베.txt
# --------------------34/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/메트로.txt
# --------------------35/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/미소시티.txt
# --------------------36/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/삼환SOGOOD.txt
# --------------------37/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/선경(1차).txt
# --------------------38/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/선경(2차).txt
# --------------------39/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/선경(3차).txt
# --------------------40/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/선릉역대우아이빌.txt
# --------------------41/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/선릉역풍림아이원레몬.txt
# --------------------42/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/세연파크뷰.txt
# --------------------43/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/세영팔레스타운.txt
# --------------------44/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/쌍용2차..txt
# --------------------45/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/쌍용대치(1차).txt
# --------------------46/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/아름빌.txt
# --------------------47/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/아크로빌.txt
# --------------------48/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/우성(1차).txt
# --------------------49/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/우정에쉐르3.txt
# --------------------50/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/월드빌.txt
# --------------------51/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/은마.txt
# --------------------52/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/청암빌라트.txt
# --------------------53/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/청원.txt
# --------------------54/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/테헤란로대우아이빌.txt
# --------------------55/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/포스코더샵.txt
# --------------------56/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/풍림아이원.txt
# --------------------57/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/하이캐슬(101동).txt
# --------------------58/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/한보미도맨션(1차).txt
# --------------------59/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/한보미도맨션(2차).txt
# --------------------60/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/한보미도맨션3차.txt
# --------------------61/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/한양팰리스.txt
# --------------------62/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/한티.txt
# --------------------63/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/현대(1차).txt
# --------------------64/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/현대썬앤빌테헤란(도시형).txt
# --------------------65/65
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/3/화인하이빌.txt
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4
# from danji
# --------------------1/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/개포4차우성(양재우성).txt
# --------------------2/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/개포5차우성.txt
# --------------------3/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/개포럭키.txt
# --------------------4/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/개포한신.txt
# --------------------5/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/경남.txt
# --------------------6/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/그랜빌캐슬.txt
# --------------------7/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/극동스타클래스.txt
# --------------------8/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/대림.txt
# --------------------9/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/대림아크로빌.txt
# --------------------10/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/대명비발디.txt
# --------------------11/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/대우양재디오빌.txt
# --------------------12/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡1차아이파크.txt
# --------------------13/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡2차아이파크.txt
# --------------------14/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡3차아이파크.txt
# --------------------15/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡그린빌.txt
# --------------------16/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡동삼성래미안.txt
# --------------------17/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡렉슬.txt
# --------------------18/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡스타빌.txt
# --------------------19/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡쌍용예가.txt
# --------------------20/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡월드메르디앙.txt
# --------------------21/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡조이너스.txt
# --------------------22/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡지웰카운티.txt
# --------------------23/67
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/1/4/도곡푸르지오1차.txt
