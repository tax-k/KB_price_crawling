# %% [markdown]
# ### import module

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.action_chains import ActionChains
import os
import time
import pickle

# %%
curr_path = os.getcwd()
sub_path = curr_path +"/Dataset/Information"

# %%
# %load executionTimeCheck.py
# from time import time, strftime, localtime
from datetime import timedelta


class checkExecution:
    def __init__(self):
        self.startTime = ''

    def secondsToStr(self, elapsed=None):
        if elapsed is None:
            return strftime("%Y-%m-%d %H:%M:%S", localtime())
        else:
            return str(timedelta(seconds=elapsed))

    def log(self, s, elapsed=None):
        line = "=" * 40
        print()
        print(line)
        print(self.secondsToStr(), '-', s)
        if elapsed:
            print("Elapsed time:", elapsed)
        print(line)
        print()

    def startLog(self):
        self.startTime = time()
        self.log("Start Program")

    def endLog(self):
        end = time()
        elapsed = end - self.startTime
        self.log("End Program", self.secondsToStr(elapsed))

# %%
e = checkExecution()

# %% [markdown]
# ### def webdriver

# %%
def start(url):
    driver = webdriver.Chrome('/Users/tax_k/Downloads/chromedriver')
    driver.get(url)
    return driver

# %% [markdown]
# ### set default module

# %%
url = "http://nland.kbstar.com/quics?page=B046948"
driver = start(url)
driver.find_element_by_xpath("//a[@title = '시/도 선택']").click()

# %%
def getSiGunGu(name_id):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    sigungu_list = []
    for li in soup.select("#"+name_id+" li"):
        sigungu_list.append(li.text)
        
    return sigungu_list

# %%
def geteupMyeonDong(name_id):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    eupMyeonDong_list = []
    
    print("from eupmyendong")
    for li in soup.select("#"+name_id+" li"):
        eupMyeonDong_list.append(li.text)
        
    return eupMyeonDong_list

# %%
def getDanji(name_id):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    danji_list = []
    
    print("from danji")
    for li in soup.select("#"+name_id+" li"):
        danji_list.append(li.text)
        
    return danji_list

# %%
si_id = "siGunGu"
sigungu_list = getSiGunGu(si_id)
len(sigungu_list)
# Out:
# 25

# %%
# e.startLog()

# for i in range(1, len(sigungu_list)):
for i in range(1, 2):
    sigungu_path = sub_path + "/" + str(i+1)
    
    driver.find_element_by_xpath("//a[@title = '시/군/구 선택']").click()
    time.sleep(1)
    driver.find_element_by_xpath("//ul[@id='"+si_id+"']/li["+str(i+1)+"]").click()
    time.sleep(2)
    dong_id = "eupMyeonDong"
    eupMyeonDong_list = geteupMyeonDong(dong_id)
    
    for j in range(0, len(eupMyeonDong_list)):
        dong_path = sigungu_path+"/"+str(j+1)
        print(dong_path)
        
        
        print("동 리스트"+"-"*20 + str(j+1) + "/" + str(len(eupMyeonDong_list)))
        driver.find_element_by_xpath("//a[@title = '읍/면/동 선택']").click()
        time.sleep(1)
    
        driver.find_element_by_xpath("//ul[@id='"+dong_id+"']/li["+str(j+1)+"]").click()
        time.sleep(2)
        danji_id = "danji"
        danji_list = getDanji(danji_id)
        
        for k in range(0, len(danji_list)):
            file_path = dong_path+'/'+danji_list[k]+'.txt'
            
            print("아파트 리스트"+"-"*20 + str(k+1) + "/" + str(len(danji_list)))
            
            if not os.path.exists(os.path.dirname(file_path)):
                try:
                    os.makedirs(os.path.dirname(file_path))
                except OSError as exc:
                    if exc.errno != errno.EEXIST:
                        raise
            
            print(file_path)
            subway_list = []
            driver.find_element_by_xpath("//a[@title = '단지 선택']").click()
            time.sleep(1)
            driver.find_element_by_xpath("//ul[@id='"+danji_id+"']/li["+str(k+1)+"]").click()
            time.sleep(2)
            driver.find_element_by_xpath('//div[@class="tab_type"]/ul/li[3]').click()
            time.sleep(2)
            
            apt_name_element = driver.find_element_by_class_name("slide_tit")
            
            
            apt_jibun_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_info > dl:nth-child(1)")
            apt_area_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_info > dl:nth-child(2)")
            #select element
            subway_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(1)")
            conv_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(2)")
            road_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(3)")
            edu_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(4)")
            medi_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(5)")
            park_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(6)")
            etc_element = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div.apt_cpx_box > div.apt_cpx_info.tp2 > dl:nth-child(7)")
            
            
            
            apt_name = apt_name_element.text
            apt_jibun = apt_jibun_element.find_element_by_xpath("./dt[.='지번']/following-sibling::dd").text
            apt_area = apt_area_element.find_element_by_xpath("./dt[.='면적']/following-sibling::dd").text
            
            apt_area_lists = apt_area.split(", ")
            #subway list
            subway_element_list = subway_element.find_elements_by_xpath("./dt[.='지하철']/following-sibling::dd/span")
            for lists in subway_element_list:
                subway_list.append(lists.text)   
            
            #conv_list
            conv_list = conv_element.find_element_by_xpath("./dt[.='편의정보']/following-sibling::dd").text
            conv_lists = conv_list.split(",")
            
            #road_list 
            road_list = road_element.find_element_by_xpath("./dt[.='도로시설']/following-sibling::dd").text
            road_lists = road_list.split(",")
            #edu_list
            edu_list = edu_element.find_element_by_xpath("./dt[.='교육시설']/following-sibling::dd").text
            edu_lists = edu_list.split(",")
            
            medi_list = medi_element.find_element_by_xpath("./dt[.='의료시설']/following-sibling::dd").text
            medi_lists = medi_list.split(",")
            
            park_list = park_element.find_element_by_xpath("./dt[.='공원']/following-sibling::dd").text
            park_lists = park_list.split(",")
            
            etc_list = etc_element.find_element_by_xpath("./dt[.='기타시설']/following-sibling::dd").text
            etc_lists = etc_list.split(",")
            
            basic_info_table = driver.find_element_by_css_selector("#b056891 > div.sub.content.sale > div.apt_cpx > div:nth-child(5) > table")
            
            rows = basic_info_table.find_elements_by_tag_name("tr")
                
            
            apt_internal_info_dic = {}
            basic_info_list = []
            th_list = []
            for row in rows:      
                cols = row.find_elements_by_xpath("./th/following-sibling::td")
                ths = row.find_elements_by_xpath("./th")
                for th in ths:
                    th_list.append(th.text)
                
                for col in cols:
                    basic_info_list.append(col.text)
                                                     
            for (index, value) in enumerate(th_list):
                apt_internal_info_dic[value] = basic_info_list[index]
            
            apt_external_info_dic = {
                "apt_name": apt_name,
                "apt_jibun": apt_jibun,
                "apt_area" : apt_area_lists,
                "subway_list": subway_list,
                "conv_lists" : conv_lists,
                "road_lists": road_lists,
                "edu_lists" : edu_lists,
                "medi_lists": medi_lists,
                "park_lists": park_lists,
                "etc_lists" : etc_lists,
                "apt_internal_info" : apt_internal_info_dic 
            }
            
            with open(file_path, 'wb') as f:
                pickle.dump(apt_external_info_dic, f)
            
            #end and wait (2)
            time.sleep(2)            
# e.endLog()
# Out:
# from eupmyendong
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8
# 동 리스트--------------------8/9
# from danji
# 아파트 리스트--------------------1/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/SM해그린.txt
# 아파트 리스트--------------------2/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/강동롯데캐슬퍼스트.txt
# 아파트 리스트--------------------3/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/강동현대홈타운.txt
# 아파트 리스트--------------------4/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/경지리버캐슬.txt
# 아파트 리스트--------------------5/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/금정우리가.txt
# 아파트 리스트--------------------6/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/까사806(도시형).txt
# 아파트 리스트--------------------7/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/다성리버빌.txt
# 아파트 리스트--------------------8/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/다성이즈빌(459-1).txt
# 아파트 리스트--------------------9/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/다성이즈빌(488-10).txt
# 아파트 리스트--------------------10/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/다성이즈빌(488-3).txt
# 아파트 리스트--------------------11/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/대명.txt
# 아파트 리스트--------------------12/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/대송.txt
# 아파트 리스트--------------------13/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/대원.txt
# 아파트 리스트--------------------14/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/대은팰리스뷰.txt
# 아파트 리스트--------------------15/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/대의아름누리.txt
# 아파트 리스트--------------------16/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/동원베네스트.txt
# 아파트 리스트--------------------17/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/동진.txt
# 아파트 리스트--------------------18/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/드림하우스(도시형).txt
# 아파트 리스트--------------------19/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/라움A동.txt
# 아파트 리스트--------------------20/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/라움B동.txt
# 아파트 리스트--------------------21/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/라인.txt
# 아파트 리스트--------------------22/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/로뎀하우스(도시형).txt
# 아파트 리스트--------------------23/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/메이저.txt
# 아파트 리스트--------------------24/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/삼성광나루.txt
# 아파트 리스트--------------------25/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/삼화그린.txt
# 아파트 리스트--------------------26/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/새롬.txt
# 아파트 리스트--------------------27/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/선사현대.txt
# 아파트 리스트--------------------28/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/신동아빌라트.txt
# 아파트 리스트--------------------29/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/아키스.txt
# 아파트 리스트--------------------30/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/암사e-편한세상.txt
# 아파트 리스트--------------------31/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/암사동양덱스빌.txt
# 아파트 리스트--------------------32/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/암사동한솔.txt
# 아파트 리스트--------------------33/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/양지벨로스.txt
# 아파트 리스트--------------------34/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/영상.txt
# 아파트 리스트--------------------35/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/영진해가든.txt
# 아파트 리스트--------------------36/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/우암쎈스뷰.txt
# 아파트 리스트--------------------37/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/유진.txt
# 아파트 리스트--------------------38/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/정산(1,2,3차).txt
# 아파트 리스트--------------------39/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/주은.txt
# 아파트 리스트--------------------40/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/중앙하이츠.txt
# 아파트 리스트--------------------41/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/평대정원.txt
# 아파트 리스트--------------------42/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/풍천.txt
# 아파트 리스트--------------------43/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/프라이어팰리스.txt
# 아파트 리스트--------------------44/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/한강리치팰리스.txt
# 아파트 리스트--------------------45/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/한강포스파크.txt
# 아파트 리스트--------------------46/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/한강현대.txt
# 아파트 리스트--------------------47/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/한건브리앙.txt
# 아파트 리스트--------------------48/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/한건새봄.txt
# 아파트 리스트--------------------49/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/한솔솔파크더리버.txt
# 아파트 리스트--------------------50/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/한양그린.txt
# 아파트 리스트--------------------51/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/현진빌리지(469-26,도시형).txt
# 아파트 리스트--------------------52/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/현진빌리지(513-43,도시형).txt
# 아파트 리스트--------------------53/53
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/8/효정하나플러스.txt
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9
# 동 리스트--------------------9/9
# from danji
# 아파트 리스트--------------------1/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/sm이로빌.txt
# 아파트 리스트--------------------2/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/가원(도시형).txt
# 아파트 리스트--------------------3/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/강동상떼빌.txt
# 아파트 리스트--------------------4/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/강동역두산위브센티움.txt
# 아파트 리스트--------------------5/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/강동역신동아파밀리에.txt
# 아파트 리스트--------------------6/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/강동이루미.txt
# 아파트 리스트--------------------7/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/강동파크빌.txt
# 아파트 리스트--------------------8/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/강변그대가갤럭시.txt
# 아파트 리스트--------------------9/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/강변그대가리버뷰.txt
# 아파트 리스트--------------------10/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/고려.txt
# 아파트 리스트--------------------11/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/골드하임.txt
# 아파트 리스트--------------------12/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/광남벨라스2차.txt
# 아파트 리스트--------------------13/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/광남벨라스643V(A).txt
# 아파트 리스트--------------------14/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/광남벨라스643V(B).txt
# 아파트 리스트--------------------15/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/광남캐스빌.txt
# 아파트 리스트--------------------16/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/그랜드.txt
# 아파트 리스트--------------------17/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/그린파크빌(도시형).txt
# 아파트 리스트--------------------18/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/금성타운.txt
# 아파트 리스트--------------------19/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/금호.txt
# 아파트 리스트--------------------20/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/늘푸른.txt
# 아파트 리스트--------------------21/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성시티(358-4).txt
# 아파트 리스트--------------------22/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성씨티(340-6).txt
# 아파트 리스트--------------------23/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성씨티(53-9).txt
# 아파트 리스트--------------------24/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌.txt
# 아파트 리스트--------------------25/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(121-32).txt
# 아파트 리스트--------------------26/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(163-5,도시형).txt
# 아파트 리스트--------------------27/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(167-102,도시형).txt
# 아파트 리스트--------------------28/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(167-153,도시형).txt
# 아파트 리스트--------------------29/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(167-17).txt
# 아파트 리스트--------------------30/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(167-2,도시형).txt
# 아파트 리스트--------------------31/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(167-97).txt
# 아파트 리스트--------------------32/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(169-9,도시형).txt
# 아파트 리스트--------------------33/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(437-22).txt
# 아파트 리스트--------------------34/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(50-11).txt
# 아파트 리스트--------------------35/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(55-20,도시형).txt
# 아파트 리스트--------------------36/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/다성이즈빌(55-25).txt
# 아파트 리스트--------------------37/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/대명사이버.txt
# 아파트 리스트--------------------38/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/대명에버빌.txt
# 아파트 리스트--------------------39/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/대우한강베네시티.txt
# 아파트 리스트--------------------40/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/더존예가(167-120,도시형).txt
# 아파트 리스트--------------------41/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/더존캐슬(도시형).txt
# 아파트 리스트--------------------42/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/동구햇살.txt
# 아파트 리스트--------------------43/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/동아하이빌.txt
# 아파트 리스트--------------------44/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/동인씨엘로(도시형).txt
# 아파트 리스트--------------------45/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/두산위브센티움(천호).txt
# 아파트 리스트--------------------46/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/드림하우스.txt
# 아파트 리스트--------------------47/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/래미안강동팰리스.txt
# 아파트 리스트--------------------48/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/로뎀.txt
# 아파트 리스트--------------------49/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/리버하임.txt
# 아파트 리스트--------------------50/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/베네캐슬.txt
# 아파트 리스트--------------------51/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/베스트빌.txt
# 아파트 리스트--------------------52/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/보람.txt
# 아파트 리스트--------------------53/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/부강.txt
# 아파트 리스트--------------------54/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/브라운스톤암사.txt
# 아파트 리스트--------------------55/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/삼익.txt
# 아파트 리스트--------------------56/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/새롬트윈스.txt
# 아파트 리스트--------------------57/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/샤인트리움(도시형).txt
# 아파트 리스트--------------------58/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/성우스타팰리스(도시형).txt
# 아파트 리스트--------------------59/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/성원.txt
# 아파트 리스트--------------------60/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/성인.txt
# 아파트 리스트--------------------61/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/시티빌.txt
# 아파트 리스트--------------------62/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/신동양빛여울.txt
# 아파트 리스트--------------------63/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/신주.txt
# 아파트 리스트--------------------64/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/신주(27-6).txt
# 아파트 리스트--------------------65/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/썬팰리스.txt
# 아파트 리스트--------------------66/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/아크로파크.txt
# 아파트 리스트--------------------67/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/엘림스퀘어1(도시형).txt
# 아파트 리스트--------------------68/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/엘크루.txt
# 아파트 리스트--------------------69/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/용명브릿지.txt
# 아파트 리스트--------------------70/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/우정.txt
# 아파트 리스트--------------------71/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/우정에쉐르.txt
# 아파트 리스트--------------------72/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/유원.txt
# 아파트 리스트--------------------73/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/유한.txt
# 아파트 리스트--------------------74/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/율전에버그린.txt
# 아파트 리스트--------------------75/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/이연아마빌레.txt
# 아파트 리스트--------------------76/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/장방.txt
# 아파트 리스트--------------------77/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/제일.txt
# 아파트 리스트--------------------78/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/주성아파텔(도시형).txt
# 아파트 리스트--------------------79/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/중앙하이츠(천호).txt
# 아파트 리스트--------------------80/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/즈믄촌.txt
# 아파트 리스트--------------------81/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/지원G델타.txt
# 아파트 리스트--------------------82/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/지원골드.txt
# 아파트 리스트--------------------83/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/진넥스빌Ⅲ.txt
# 아파트 리스트--------------------84/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/창대캐슬.txt
# 아파트 리스트--------------------85/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호(동성).txt
# 아파트 리스트--------------------86/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호1차우림루미아트.txt
# 아파트 리스트--------------------87/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호2차우림루미아트.txt
# 아파트 리스트--------------------88/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호e-편한세상.txt
# 아파트 리스트--------------------89/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호네스빌.txt
# 아파트 리스트--------------------90/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호동삼성.txt
# 아파트 리스트--------------------91/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호동아(동아코아).txt
# 아파트 리스트--------------------92/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호롯데.txt
# 아파트 리스트--------------------93/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호예전이룸1차.txt
# 아파트 리스트--------------------94/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호우성.txt
# 아파트 리스트--------------------95/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호이룸2차.txt
# 아파트 리스트--------------------96/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호이연아마빌레.txt
# 아파트 리스트--------------------97/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호케이엔피.txt
# 아파트 리스트--------------------98/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호코오롱상가.txt
# 아파트 리스트--------------------99/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/천호태영.txt
# 아파트 리스트--------------------100/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/태천(35-12).txt
# 아파트 리스트--------------------101/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/태천와이드빌.txt
# 아파트 리스트--------------------102/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/태천해오름.txt
# 아파트 리스트--------------------103/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/평대미진.txt
# 아파트 리스트--------------------104/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/평대보민.txt
# 아파트 리스트--------------------105/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/프라임(도시형).txt
# 아파트 리스트--------------------106/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/플러스빌(도시형).txt
# 아파트 리스트--------------------107/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/하이브(도시형).txt
# 아파트 리스트--------------------108/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/한건브리앙.txt
# 아파트 리스트--------------------109/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/한신.txt
# 아파트 리스트--------------------110/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/현대.txt
# 아파트 리스트--------------------111/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/현대코아(타워).txt
# 아파트 리스트--------------------112/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/현대프라자.txt
# 아파트 리스트--------------------113/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/현진리버파크.txt
# 아파트 리스트--------------------114/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/현진에스페랑스.txt
# 아파트 리스트--------------------115/115
# /Users/tax_k/Projects/AI-DL/KB/Dataset/Information/2/9/형인허브빌.txt
